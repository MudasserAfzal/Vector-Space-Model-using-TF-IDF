# %%
import glob 
import os
from nltk.corpus import stopwords     # NLTK library is used to remove stop words and punctuations marks
from nltk.tokenize import word_tokenize 
from collections import Counter
import numpy as np
from collections import OrderedDict

# %%
'''Overall in this block of code we read every file in the dataset folder and by using nested loop
each line in a text file is appended into the headers dictionary along with keys'''
def Initializedata(filepaths):
    
    headers = {}   #A dictionary which stores all words along with keys
    count = 0
     # iterate for each file path in the list
    for i in filepaths :
        #Open the file in read mode
        with open(i, 'r') as f:
            #words = list(f) #help to read file line by line
            while True:
                theline = f.read()             # try to read next line
                if len(theline) == 0:               # if there are no more lines
                    break
                headers[count] = theline
        count = count + 1            
    return headers

# %%
def stringconversion(headers):
    
    word_list = [] #An empty list which is used to store strings
    for doc in headers.values(): #go through each line in a dictionary
        for word in doc.split(): #go through each word in the current line
            word_list.append(word) #this will give list of strings in all 20k text files
                
    return word_list

# %%
'''As we have to remove stopwords and punctuation marks so this block of code simply select each line 
in a dictionary and by using splitting method it split into single word and by appending those 
single words in a list we make a long list of all strings in all documents'''

def stopwordandsymbols(word_list):
    
    new_text = []
    updated_list = []  #empty lists to store the finalize list which has no stopword and punctuation marks

    symbols = "!\"#$%&()*+-./:;<=>?@[\]^_`{|}~\n"
    stop_words = set(stopwords.words('english')) #NLTK library function
    for word in word_list:
        #this loop will remove all symbols from the list of strings we have
        if word not in symbols:
            new_text.append(word)
    for word in new_text:
        #this loop work on the list with removed punctuation marks and it will remove stopwords now
        if word not in stop_words:
            updated_list.append(word) #here is the refined list of strings
            
    return updated_list

# %%
#count = 0
def vacabulary(updated_list):
    
    corpus = []  #this corpus contain the vacabulary, it adds all the words in the list we have above and exclude all repeating words
    for word in updated_list: #go through each word in the current doc
        #print(count)    
        if not word in corpus: 
                corpus.append(word)
        #count = count + 1
        
    return corpus

# %%
'''To find the document frequency here is the piece of code which works and store all document frequency
and how many documents the word repeats''' 
def documentfreq(headers, corpus):
    
    df_corpus = {} #document frequency for every word in corpus

    for word in corpus:
        k = 0 #initial document frequency set to 0
        for doc in headers.values(): #iterate through documents
            if word in doc.split(): #check if word in doc
                k+=1 
        df_corpus[word] = k
    
    return df_corpus

# %%
def inversedocumentfreq(headers, corpus, df_corpus):
    M = len(headers) #number of documents in the collection
    idf_corpus = {} #inverse_document frequency for every word in corpus
    for word in corpus:
        idf_corpus[word] = np.log2((M+1) / df_corpus[word]) #log_2 ((M+1)/k) i.e inverse document frequency
    
    return idf_corpus

# %%
def termfrequency(headers, corpus):
    
    tf_corpus = {} #empty dictionary
    
    for doc_id in headers.keys(): #iterate through doc# (d1,d2,...,d5)
        tf_corpus[doc_id] = {} #create empty dictionary for each doc# key
    for word in corpus: #iterate through words in the corpus
        for doc_id,doc in headers.items(): #iterate through documents dictionary
            tf_corpus[doc_id][word] = doc.count(word) #store term-frequency for the word in each doc
    
    return tf_corpus

# %%
def tfidf_corpus(corpus, tf_corpus, idf_corpus, headers):
    tf_idf = {} #will store tf_idf scores for document words
    for doc_id in headers.keys():
        tf_idf[doc_id] = {} #initialize empty dictionary for each doc_id
    for word in corpus:
        for doc_id,doc in headers.items(): #iterate through key,value pairs where key = doc_id and value = doc content
            tf_idf[doc_id][word] = tf_corpus[doc_id][word] * idf_corpus[word] #C(W_i,doc) * IDF(W_i)
    return tf_idf

# %%
def vectorSpaceModel(query, headers, tf_idf):
    query_vocab = [] # will store the unique words that occur in the query
    for word in query.split():
        if word not in query_vocab:
            query_vocab.append(word)

    query_dic = {} # a dictionary to store count of a word in the query (i.e x_i according to lecture slides terminology)
    for word in query_vocab:
        query_dic[word] = query.split().count(word)
    
    relevance_scores = {} # a dictionary that will store the relevance score for each doc
                            # doc_id will be the key and relevance score the value for this dictionary
    for doc_id in headers.keys():
        score = 0 #initialze the score for the doc to 0 at the start
        for word in query_vocab:
            score += query_dic[word] * tf_idf[doc_id][word] # count of word in query * term_freq of the word
        relevance_scores[doc_id] = score
    sorted_value = OrderedDict(sorted(relevance_scores.items(), key=lambda x: x[1], reverse = True))
    top_5 = {k: sorted_value[k] for k in list(sorted_value)[:5]}
    return top_5

# %%
#Folder contain the path of our ACL text folder located in your system
folder = r"C:\Users\Mudasser Afzal\Desktop\IR Assignment\ACL txt"  #

# Get filepaths for all files which end with ".txt" :
filepaths = glob.glob(os.path.join(folder, '*.txt'))


d = Initializedata(filepaths)  #give the dataset in form of list of strings in files
s = stringconversion(d)
s   #display strings
# Out:
# ['Association',
#  'for',
#  'Computational',
#  'Linguistics',
#  '6',
#  'th',
#  'Applied',
#  'Natural',
#  'Language',
#  'Processing',
#  'Conference',
#  'Proceedings',
#  'of',
#  'the',
#  'Conference',
#  'April',
#  '29--May',
#  '4,',
#  '2000',
#  'Seattle,',
#  'Washington,',
#  'USA',
#  'ANLP',
#  '2000-PREFACE',
#  '131',
#  'papers',
#  'were',
#  'submitted',
#  'to',
#  'ANLP-2000.',
#  '46',
#  'were',
#  'accepted',
#  'for',
#  'presentation',
#  'at',
#  'the',
#  'conference.',
#  'Papers',
#  'came',
#  'from',
#  '24',
#  'countries:',
#  'fifty',
#  'eight',
#  'from',
#  'the',
#  'United',
#  'States',
#  'of',
#  'America,',
#  'eleven',
#  'each',
#  'from',
#  'Germany',
#  'and',
#  'United',
#  'Kingdom,',
#  'nine',
#  'from',
#  'Canada,',
#  'eight',
#  'from',
#  'Japan,',
#  'four',
#  'each',
#  'from',
#  'Italy',
#  'and',
#  'Spain,',
#  'three',
#  'ach',
#  'from',
#  'France,',
#  'Korea',
#  'and',
#  'Switzerland,',
#  'two',
#  'each',
#  'from',
#  'Australia,',
#  'China,',
#  'The',
#  'Netherlands',
#  'and',
#  'Sweden',
#  'and',
#  'one',
#  'each',
#  'from',
#  'Czech',
#  'Republic,',
#  'Denmark,',
#  'Finland,',
#  'Greece,',
#  'India,',
#  'Hong',
#  'Kong,',
#  'Malaysia,',
#  'Norway,',
#  'Russia',
#  'and',
#  'Taiwan.',
#  '40',
#  'papers',
#  'were',
#  'submitted',
#  'from',
#  'industry.',
#  '85',
#  'papers',
#  'came',
#  'from',
#  'academia.',
#  '2',
#  'papers',
#  'were',
#  'submitted',
#  'from',
#  'government',
#  'organizations',
#  'and',
#  'four',
#  'submissions',
#  'were',
#  'combined.',
#  'The',
#  'reviewing',
#  'process',
#  'was',
#  'supported',
#  'by',
#  'a',
#  'web-based',
#  'reviewer',
#  'interface',
#  'developed',
#  'by',
#  'Elisha',
#  'Kane',
#  'at',
#  'New',
#  'Mexico',
#  'State',
#  "University's",
#  'Computing',
#  'Research',
#  'Lab.',
#  'Linda',
#  'Fresques',
#  'of',
#  'CRL',
#  'coordinated',
#  'the',
#  'refereeing',
#  'process.',
#  'I',
#  'would',
#  'like',
#  'to',
#  'express',
#  'my',
#  'gratitude',
#  'to',
#  'and',
#  'appreciation',
#  'fthe',
#  'Program',
#  'Committee',
#  'members',
#  'responsible',
#  'for',
#  'the',
#  'six',
#  'areas:',
#  'Lynn',
#  'Carlson,',
#  'Tools',
#  'and',
#  'Resources',
#  'for',
#  'Developing',
#  'NLP',
#  'Systems',
#  'Subcommittee',
#  'Eduard',
#  'Hovy,',
#  'Integrated',
#  'NLP',
#  'Systems',
#  'Subcommittee',
#  'Richard',
#  'Kittredge,',
#  'Multilingual',
#  'Text',
#  'Processing',
#  'Subcommittee',
#  'Ray',
#  'Perrault,',
#  'Spoken',
#  'Language',
#  'Systems',
#  'Subcommittee',
#  'Oliviero',
#  'Stock,',
#  'Monolingual',
#  'Text',
#  'Processing',
#  'Systems',
#  'Subcommittee',
#  'John',
#  'White,',
#  'Evaluation',
#  'Subcommittee',
#  'The',
#  'following',
#  'colleagues',
#  'did',
#  'Doug',
#  'Appelt',
#  'Fabio',
#  'Ciravegna',
#  'Robert',
#  'Dale',
#  'Michael',
#  'Elhadad',
#  'Ralph',
#  'G-rishman',
#  'Lynette',
#  'Hirschman',
#  'Yuval',
#  'Krymolowski',
#  'Inderjeet',
#  'Mani',
#  'Zvi',
#  'Marx',
#  'Martha',
#  'Palmer',
#  'Harold',
#  'Somers',
#  'Toshiyuki',
#  'Takezawa',
#  'Takehito',
#  'Utsuro',
#  'Dekai',
#  'Wu',
#  'the',
#  'bulk',
#  'of',
#  'the',
#  'reviewing:',
#  'Igor',
#  'Boguslavsky',
#  'Jim',
#  'Cowie',
#  'John',
#  'Dowding',
#  'Jim',
#  'Glass',
#  'Jan',
#  'Haji~',
#  'Pierre',
#  'IsabeIIe',
#  'Alberto',
#  'Lavelli',
#  'Daniel',
#  'Marcu',
#  'David',
#  'McDonald',
#  'Owen',
#  'Rainbow',
#  'Tomek',
#  'Strzalkowski',
#  'Kathryn',
#  'B.',
#  'Taylor',
#  'Pick',
#  'Vossen',
#  'R6mi',
#  'Zajac',
#  'David',
#  'Carter',
#  'Ido',
#  'Dagan',
#  'Andreas',
#  'Eiscle',
#  'Oren',
#  'Glikman',
#  'Donna',
#  'Harman',
#  'Tanya',
#  'Korelsky',
#  'Chin-Yew',
#  'Lin',
#  'Paul',
#  'Martin',
#  'Teruko',
#  'Mitamura',
#  'Norbert',
#  'Reithinger',
#  'Beth',
#  'Sundheim',
#  'Hans',
#  'Uszkoreit',
#  'Ralph',
#  'Weischedel',
#  'We',
#  'believe',
#  'that',
#  'he',
#  'quality',
#  'of',
#  'the',
#  'papers',
#  'elected',
#  'israther',
#  'high',
#  'and',
#  'hope',
#  'that',
#  'he',
#  'conference',
#  'will',
#  'be',
#  'a',
#  'success.',
#  'Sergei',
#  'Nirenburg',
#  'Chair,',
#  'Program',
#  'Committee',
#  'ANLP-2000',
#  'ANLPi',
#  'ANLP',
#  'Table',
#  'of',
#  'Contents',
#  'Section',
#  '1:',
#  'Applied',
#  'Natural',
#  'Language',
#  'Processing',
#  'Conference',
#  '(ANLP)',
#  'ANLP',
#  'Preface',
#  'and',
#  'List',
#  'of',
#  'Reviewers',
#  'Sergei',
#  'Nirenburg,',
#  'Program',
#  'Committee',
#  'Chair',
#  '...............................................................',
#  'ANLPi',
#  'BusTUC--A',
#  'Natural',
#  'Language',
#  'Bus',
#  'Route',
#  'Oracle',
#  'Tore',
#  'Amble',
#  '..............................................................................................................................',
#  '1',
#  'Machine',
#  'Translation',
#  'of',
#  'Very',
#  'Close',
#  'Languages',
#  'Jan',
#  'Haji~,',
#  'Jan',
#  'Hric,',
#  'Vladislav',
#  'Kubofi',
#  '.......................................................................................',
#  '7',
#  'Cross-Language',
#  'Multimedia',
#  'Information',
#  'Retrieval',
#  'Sharon',
#  'Flank',
#  '..........................................................................................................................',
#  '13',
#  'Automatic',
#  'Construction',
#  'of',
#  'Parallel',
#  'English-Chinese',
#  'Corpus',
#  'for',
#  'Cross-Language',
#  'Information',
#  'Retrieval',
#  'Jiang',
#  'Chen,',
#  'Jian-Yun',
#  'Nie',
#  '......................................................................................................',
#  '21',
#  'PartslD:',
#  'A',
#  'Dialogue-Based',
#  'System',
#  'for',
#  'Identifying',
#  'Parts',
#  'for',
#  'Medical',
#  'Systems',
#  'Amit',
#  'Bagga,',
#  'Tomek',
#  'Strzalkowski,',
#  'G.',
#  'Bowden',
#  'Wise',
#  '...........................................................',
#  '29',
#  'Translation',
#  'Using',
#  'Information',
#  'on',
#  'Dialogue',
#  'Participants',
#  'Setsuo',
#  'Yamada,',
#  'Eiichiro',
#  'Sumita,',
#  'Hideki',
#  'Kashioka',
#  '..............................................................',
#  '37',
#  'Distilling',
#  'Dialogues--A',
#  'Method',
#  'Using',
#  'Natural',
#  'Dialogue',
#  'Corpora',
#  'for',
#  'Dialogue',
#  'Systems',
#  'Development',
#  'Arne',
#  'J6nsson,',
#  'Nils',
#  'Dahlb~ick',
#  '.................................................................................................',
#  '44',
#  'Plan-Based',
#  'Dialogue',
#  'Management',
#  'ina',
#  'Physics',
#  'Tour',
#  'Reva',
#  'Freedman',
#  '......................................................................................................................',
#  '52',
#  'A',
#  'Framework',
#  'for',
#  'MT',
#  'and',
#  'Multilingual',
#  'NLG',
#  'Systems',
#  'Based',
#  'on',
#  'Uniform',
#  'Lexico-Structural',
#  'Processing',
#  'Benoit',
#  'Lavoie,',
#  'Richard',
#  'Kittredge,',
#  'Tanya',
#  'Korelsky,',
#  'Owen',
#  'Rambow',
#  '...................................',
#  '60',
#  "Talk'N'Travel:",
#  'A',
#  'Conversational',
#  'System',
#  'for',
#  'Air',
#  'Travel',
#  'Planning',
#  'David',
#  'Stallard',
#  '........................................................................................................................',
#  '68',
#  'REES:',
#  'A',
#  'Large-Scale',
#  'Relation',
#  'and',
#  'Event',
#  'Extraction',
#  'System',
#  'Chinatsu',
#  'Aone,',
#  'Mila',
#  'Ramos-Santacruz',
#  '.................................................................................',
#  '76',
#  'Experiments',
#  'on',
#  'Sentence',
#  'Boundary',
#  'Detection',
#  'Mark',
#  'Stevenson,',
#  'Robert',
#  'Gaizauskas',
#  '.....................................................................................',
#  '84',
#  'DP:',
#  'A',
#  'Detector',
#  'for',
#  'Presuppositions',
#  'in',
#  'Survey',
#  'Questions',
#  'Katja',
#  'Wiemer-Hastings,',
#  'Peter',
#  'Wiemer-Hastings,',
#  'Sonya',
#  'Rajan,',
#  'Art',
#  'Graesser,',
#  'Roger',
#  'Kreuz,',
#  'Ashish',
#  'Karnavat',
#  '..............................................................................................',
#  '90',
#  'ANLPiii',
#  'MIMIC:',
#  'An',
#  'Adaptive',
#  'Mixed',
#  'Initiative',
#  'Spoken',
#  'Dialogue',
#  'System',
#  'for',
#  'Information',
#  'Queries',
#  'Jennifer',
#  'Chu-Carroll',
#  '..............................................................................................................',
#  '97',
#  'Javox:',
#  'A',
#  'Toolkit',
#  'for',
#  'Building',
#  'Speech-Enabled',
#  'Applications',
#  'Michael',
#  'S.',
#  'Fulkerson,',
#  'Alan',
#  'W.',
#  'Biermann',
#  '...........................................................................',
#  '105',
#  'A',
#  'Compact',
#  'Architecture',
#  'for',
#  'Dialogue',
#  'Management',
#  'Based',
#  'on',
#  'Scripts',
#  'and',
#  'Meta-Outputs',
#  'Manny',
#  'Rayner,',
#  'Beth',
#  'Ann',
#  'Hockey,',
#  'Frankie',
#  'James',
#  '..............................................................',
#  '112',
#  'A',
#  'Representation',
#  'for',
#  'Complex',
#  'and',
#  'Evolving',
#  'Data',
#  'Dependencies',
#  'in',
#  'Generation',
#  'C.',
#  'Mellish,',
#  'R.',
#  'Evans,',
#  'L.',
#  'Cahill,',
#  'C.',
#  'Doran,',
#  'D.',
#  'Paiva,',
#  'M.',
#  'Reape,',
#  'D.',
#  'Scott,',
#  'N.',
#  'Tipper',
#  '.............................................................................',
#  '119',
#  'An',
#  'Automatic',
#  'Reviser:',
#  'The',
#  'TransCheck',
#  'System',
#  'Jean-Marc',
#  'Jutras',
#  '..................................................................................................................',
#  '127',
#  'Unit',
#  'Completion',
#  'for',
#  'a',
#  'Computer-Aided',
#  'Translation',
#  'Typing',
#  'System',
#  'Philippe',
#  'Langlais,',
#  'George',
#  'Foster,',
#  'Guy',
#  'Lapalme',
#  '.................................................................',
#  '135',
#  'Multilingual',
#  'Coreference',
#  'Resolution',
#  'Sanda',
#  'M.',
#  'Harabagiu,',
#  'Steven',
#  'J.',
#  'Maiorano',
#  '...........................................................................',
#  '142',
#  'Ranking',
#  'Suspected',
#  'Answers',
#  'to',
#  'Natural',
#  'Language',
#  'Questions',
#  'Using',
#  'Predictive',
#  'Annotation',
#  'Dragomir',
#  'R.',
#  'Radev,',
#  'John',
#  'Prager,',
#  'Valerie',
#  'Samn',
#  '.................................................................',
#  '150',
#  'Message',
#  'Classification',
#  'i',
#  'the',
#  'Call',
#  'Center',
#  'Stephan',
#  'Busemann,',
#  'Sven',
#  'Schmeier,',
#  'Roman',
#  'G.',
#  'Arens',
#  '.......................................................',
#  '158',
#  'A',
#  'Question',
#  'Answering',
#  'System',
#  'Supported',
#  'by',
#  'Information',
#  'Extraction',
#  'Rohini',
#  'Srihari,',
#  'Wei',
#  'Li',
#  '........................................................................................................',
#  '166',
#  'Categorizing',
#  'Unknown',
#  'Words:',
#  'Using',
#  'Decision',
#  'Trees',
#  'to',
#  'Identify',
#  'Names',
#  'and',
#  'Misspellings',
#  'Janine',
#  'Toole',
#  '.........................................................................................................................',
#  '173',
#  'Examining',
#  'the',
#  'Role',
#  'of',
#  'Statistical',
#  'and',
#  'Linguistic',
#  'Knowledge',
#  'Sources',
#  'in',
#  'a',
#  'General-Knowledge',
#  'Question-Answering',
#  'System',
#  'Claire',
#  'Cardie,',
#  'Vincent',
#  'Ng,',
#  'David',
#  'Pierce,',
#  'Chris',
#  'Buckley',
#  '....................................................',
#  '180',
#  'Extracting',
#  'Molecular',
#  'Binding',
#  'Relationships',
#  'from',
#  'Biomedical',
#  'Text',
#  'Thomas',
#  'C.',
#  'Rindflesch,',
#  'Jayant',
#  'V.',
#  'Rajan,',
#  'Lawrence',
#  'Hunter',
#  '................................................',
#  '188',
#  'Compound',
#  'Noun',
#  'Segmentation',
#  'Based',
#  'on',
#  'Lexical',
#  'Data',
#  'Extracted',
#  'from',
#  'Corpus',
#  'Juntae',
#  'Yoon',
#  '.........................................................................................................................',
#  '196',
#  'Experiments',
#  'with',
#  'Corpus-Based',
#  'LFG',
#  'Specialization',
#  'Nicola',
#  'Cancedda,',
#  'Christer',
#  'Samuelsson',
#  '...............................................................................',
#  '204',
#  'A',
#  'Tool',
#  'for',
#  'Automated',
#  'Revision',
#  'of',
#  'Grammars',
#  'for',
#  'NLP',
#  'Systems',
#  'Nanda',
#  'Kambhatla,',
#  'Wlodek',
#  'Zadrozny',
#  '.................................................................................',
#  '210',
#  'ANLPiv',
#  'Aggressive',
#  'Morphology',
#  'for',
#  'Robust',
#  'Lexical',
#  'Coverage',
#  'William',
#  'A.',
#  'Woods',
#  '...............................................................................................................',
#  '218',
#  'TnT--A',
#  'Statistical',
#  'Part-of-Speech',
#  'Tagger',
#  'Thorsten',
#  'Brants',
#  '...................................................................................................................',
#  '224',
#  'Language',
#  'Independent',
#  'Morphological',
#  'Analysis',
#  'Tatsuo',
#  'Yamashita,',
#  'Yuji',
#  'Matsumoto',
#  '....................................................................................',
#  '232',
#  'A',
#  'Divide-and-Conquer',
#  'Strategy',
#  'for',
#  'Shallow',
#  'Parsing',
#  'of',
#  'German',
#  'Free',
#  'Texts',
#  'Giinter',
#  'Neumann,',
#  'Christian',
#  'Braun,',
#  'Jakub',
#  'Piskorski',
#  '...........................................................',
#  '239',
#  'A',
#  'Hybrid',
#  'Approach',
#  'for',
#  'Named',
#  'Entity',
#  'and',
#  'Sub-Type',
#  'Tagging',
#  'Rohini',
#  'Srihari,',
#  'Cheng',
#  'Niu,',
#  'Wei',
#  'Li',
#  '......................................................................................',
#  '247',
#  'Spelling',
#  'and',
#  'Grammar',
#  'Correction',
#  'for',
#  'Danish',
#  'in',
#  'SCARRIE',
#  'Patrizia',
#  'Paggio',
#  '.....................................................................................................................',
#  '255',
#  'Linguistic',
#  'Knowledge',
#  'Can',
#  'Improve',
#  'Information',
#  'Retrieval',
#  'William',
#  'A.',
#  'Woods,',
#  'Lawrence',
#  'A.',
#  'Bookman,',
#  'Ann',
#  'Houston,',
#  'Robert',
#  'J.',
#  'Kuhns,',
#  'Paul',
#  'Martin,',
#  'Stephen',
#  'Green',
#  '.................................................................................................',
#  '262',
#  'Domain-Specific',
#  'Knowledge',
#  'Acquisition',
#  'from',
#  'Text',
#  'Dan',
#  'Moldovan,',
#  'Roxana',
#  'Girju,',
#  'Vasile',
#  'Rus',
#  '..........................................................................',
#  '268',
#  'Large-Scale',
#  'Controlled',
#  'Vocabulary',
#  'Indexing',
#  'for',
#  'Named',
#  'Entities',
#  'Mark',
#  'Wasson',
#  '.......................................................................................................................',
#  '276',
#  'Unsupervised',
#  'Discovery',
#  'of',
#  'Scenario-Level',
#  'Patterns',
#  'for',
#  'Information',
#  'Extraction',
#  'Roman',
#  'Yangarber,',
#  'Ralph',
#  'Grishman,',
#  'Pasi',
#  'Tapanainen,',
#  'Silja',
#  'Huttunen',
#  '..............................',
#  '282',
#  'Using',
#  'Corpus-Derived',
#  'Name',
#  'Lists',
#  'for',
#  'Named',
#  'Entity',
#  'Recognition',
#  'Mark',
#  'Stevenson,',
#  'Robert',
#  'Gaizauskas',
#  '...................................................................................',
#  '290',
#  'Answer',
#  'Extraction',
#  'Steven',
#  'Abney,',
#  'Michael',
#  'Collins,',
#  'Amit',
#  'Singhal',
#  '....................................................................',
#  '296',
#  'Evaluation',
#  'of',
#  'Automatically',
#  'Identified',
#  'Index',
#  'Terms',
#  'for',
#  'Browsing',
#  'Electronic',
#  'Documents',
#  'Nina',
#  'Wacholder,',
#  'Judith',
#  'L.',
#  'Klavans,',
#  'David',
#  'K.',
#  'Evans',
#  '.........................................................',
#  '302',
#  'Sentence',
#  'Reduction',
#  'for',
#  'Automatic',
#  'Text',
#  ...]

# %%
z = stopwordandsymbols(s)  #remove stop words and punctuation marks from list of strings
z    #display list
# Out:
# ['Association',
#  'Computational',
#  'Linguistics',
#  '6',
#  'th',
#  'Applied',
#  'Natural',
#  'Language',
#  'Processing',
#  'Conference',
#  'Proceedings',
#  'Conference',
#  'April',
#  '29--May',
#  '4,',
#  '2000',
#  'Seattle,',
#  'Washington,',
#  'USA',
#  'ANLP',
#  '2000-PREFACE',
#  '131',
#  'papers',
#  'submitted',
#  'ANLP-2000.',
#  '46',
#  'accepted',
#  'presentation',
#  'conference.',
#  'Papers',
#  'came',
#  '24',
#  'countries:',
#  'fifty',
#  'eight',
#  'United',
#  'States',
#  'America,',
#  'eleven',
#  'Germany',
#  'United',
#  'Kingdom,',
#  'nine',
#  'Canada,',
#  'eight',
#  'Japan,',
#  'four',
#  'Italy',
#  'Spain,',
#  'three',
#  'ach',
#  'France,',
#  'Korea',
#  'Switzerland,',
#  'two',
#  'Australia,',
#  'China,',
#  'The',
#  'Netherlands',
#  'Sweden',
#  'one',
#  'Czech',
#  'Republic,',
#  'Denmark,',
#  'Finland,',
#  'Greece,',
#  'India,',
#  'Hong',
#  'Kong,',
#  'Malaysia,',
#  'Norway,',
#  'Russia',
#  'Taiwan.',
#  '40',
#  'papers',
#  'submitted',
#  'industry.',
#  '85',
#  'papers',
#  'came',
#  'academia.',
#  '2',
#  'papers',
#  'submitted',
#  'government',
#  'organizations',
#  'four',
#  'submissions',
#  'combined.',
#  'The',
#  'reviewing',
#  'process',
#  'supported',
#  'web-based',
#  'reviewer',
#  'interface',
#  'developed',
#  'Elisha',
#  'Kane',
#  'New',
#  'Mexico',
#  'State',
#  "University's",
#  'Computing',
#  'Research',
#  'Lab.',
#  'Linda',
#  'Fresques',
#  'CRL',
#  'coordinated',
#  'refereeing',
#  'process.',
#  'I',
#  'would',
#  'like',
#  'express',
#  'gratitude',
#  'appreciation',
#  'fthe',
#  'Program',
#  'Committee',
#  'members',
#  'responsible',
#  'six',
#  'areas:',
#  'Lynn',
#  'Carlson,',
#  'Tools',
#  'Resources',
#  'Developing',
#  'NLP',
#  'Systems',
#  'Subcommittee',
#  'Eduard',
#  'Hovy,',
#  'Integrated',
#  'NLP',
#  'Systems',
#  'Subcommittee',
#  'Richard',
#  'Kittredge,',
#  'Multilingual',
#  'Text',
#  'Processing',
#  'Subcommittee',
#  'Ray',
#  'Perrault,',
#  'Spoken',
#  'Language',
#  'Systems',
#  'Subcommittee',
#  'Oliviero',
#  'Stock,',
#  'Monolingual',
#  'Text',
#  'Processing',
#  'Systems',
#  'Subcommittee',
#  'John',
#  'White,',
#  'Evaluation',
#  'Subcommittee',
#  'The',
#  'following',
#  'colleagues',
#  'Doug',
#  'Appelt',
#  'Fabio',
#  'Ciravegna',
#  'Robert',
#  'Dale',
#  'Michael',
#  'Elhadad',
#  'Ralph',
#  'G-rishman',
#  'Lynette',
#  'Hirschman',
#  'Yuval',
#  'Krymolowski',
#  'Inderjeet',
#  'Mani',
#  'Zvi',
#  'Marx',
#  'Martha',
#  'Palmer',
#  'Harold',
#  'Somers',
#  'Toshiyuki',
#  'Takezawa',
#  'Takehito',
#  'Utsuro',
#  'Dekai',
#  'Wu',
#  'bulk',
#  'reviewing:',
#  'Igor',
#  'Boguslavsky',
#  'Jim',
#  'Cowie',
#  'John',
#  'Dowding',
#  'Jim',
#  'Glass',
#  'Jan',
#  'Haji~',
#  'Pierre',
#  'IsabeIIe',
#  'Alberto',
#  'Lavelli',
#  'Daniel',
#  'Marcu',
#  'David',
#  'McDonald',
#  'Owen',
#  'Rainbow',
#  'Tomek',
#  'Strzalkowski',
#  'Kathryn',
#  'B.',
#  'Taylor',
#  'Pick',
#  'Vossen',
#  'R6mi',
#  'Zajac',
#  'David',
#  'Carter',
#  'Ido',
#  'Dagan',
#  'Andreas',
#  'Eiscle',
#  'Oren',
#  'Glikman',
#  'Donna',
#  'Harman',
#  'Tanya',
#  'Korelsky',
#  'Chin-Yew',
#  'Lin',
#  'Paul',
#  'Martin',
#  'Teruko',
#  'Mitamura',
#  'Norbert',
#  'Reithinger',
#  'Beth',
#  'Sundheim',
#  'Hans',
#  'Uszkoreit',
#  'Ralph',
#  'Weischedel',
#  'We',
#  'believe',
#  'quality',
#  'papers',
#  'elected',
#  'israther',
#  'high',
#  'hope',
#  'conference',
#  'success.',
#  'Sergei',
#  'Nirenburg',
#  'Chair,',
#  'Program',
#  'Committee',
#  'ANLP-2000',
#  'ANLPi',
#  'ANLP',
#  'Table',
#  'Contents',
#  'Section',
#  '1:',
#  'Applied',
#  'Natural',
#  'Language',
#  'Processing',
#  'Conference',
#  '(ANLP)',
#  'ANLP',
#  'Preface',
#  'List',
#  'Reviewers',
#  'Sergei',
#  'Nirenburg,',
#  'Program',
#  'Committee',
#  'Chair',
#  '...............................................................',
#  'ANLPi',
#  'BusTUC--A',
#  'Natural',
#  'Language',
#  'Bus',
#  'Route',
#  'Oracle',
#  'Tore',
#  'Amble',
#  '..............................................................................................................................',
#  '1',
#  'Machine',
#  'Translation',
#  'Very',
#  'Close',
#  'Languages',
#  'Jan',
#  'Haji~,',
#  'Jan',
#  'Hric,',
#  'Vladislav',
#  'Kubofi',
#  '.......................................................................................',
#  '7',
#  'Cross-Language',
#  'Multimedia',
#  'Information',
#  'Retrieval',
#  'Sharon',
#  'Flank',
#  '..........................................................................................................................',
#  '13',
#  'Automatic',
#  'Construction',
#  'Parallel',
#  'English-Chinese',
#  'Corpus',
#  'Cross-Language',
#  'Information',
#  'Retrieval',
#  'Jiang',
#  'Chen,',
#  'Jian-Yun',
#  'Nie',
#  '......................................................................................................',
#  '21',
#  'PartslD:',
#  'A',
#  'Dialogue-Based',
#  'System',
#  'Identifying',
#  'Parts',
#  'Medical',
#  'Systems',
#  'Amit',
#  'Bagga,',
#  'Tomek',
#  'Strzalkowski,',
#  'G.',
#  'Bowden',
#  'Wise',
#  '...........................................................',
#  '29',
#  'Translation',
#  'Using',
#  'Information',
#  'Dialogue',
#  'Participants',
#  'Setsuo',
#  'Yamada,',
#  'Eiichiro',
#  'Sumita,',
#  'Hideki',
#  'Kashioka',
#  '..............................................................',
#  '37',
#  'Distilling',
#  'Dialogues--A',
#  'Method',
#  'Using',
#  'Natural',
#  'Dialogue',
#  'Corpora',
#  'Dialogue',
#  'Systems',
#  'Development',
#  'Arne',
#  'J6nsson,',
#  'Nils',
#  'Dahlb~ick',
#  '.................................................................................................',
#  '44',
#  'Plan-Based',
#  'Dialogue',
#  'Management',
#  'ina',
#  'Physics',
#  'Tour',
#  'Reva',
#  'Freedman',
#  '......................................................................................................................',
#  '52',
#  'A',
#  'Framework',
#  'MT',
#  'Multilingual',
#  'NLG',
#  'Systems',
#  'Based',
#  'Uniform',
#  'Lexico-Structural',
#  'Processing',
#  'Benoit',
#  'Lavoie,',
#  'Richard',
#  'Kittredge,',
#  'Tanya',
#  'Korelsky,',
#  'Owen',
#  'Rambow',
#  '...................................',
#  '60',
#  "Talk'N'Travel:",
#  'A',
#  'Conversational',
#  'System',
#  'Air',
#  'Travel',
#  'Planning',
#  'David',
#  'Stallard',
#  '........................................................................................................................',
#  '68',
#  'REES:',
#  'A',
#  'Large-Scale',
#  'Relation',
#  'Event',
#  'Extraction',
#  'System',
#  'Chinatsu',
#  'Aone,',
#  'Mila',
#  'Ramos-Santacruz',
#  '.................................................................................',
#  '76',
#  'Experiments',
#  'Sentence',
#  'Boundary',
#  'Detection',
#  'Mark',
#  'Stevenson,',
#  'Robert',
#  'Gaizauskas',
#  '.....................................................................................',
#  '84',
#  'DP:',
#  'A',
#  'Detector',
#  'Presuppositions',
#  'Survey',
#  'Questions',
#  'Katja',
#  'Wiemer-Hastings,',
#  'Peter',
#  'Wiemer-Hastings,',
#  'Sonya',
#  'Rajan,',
#  'Art',
#  'Graesser,',
#  'Roger',
#  'Kreuz,',
#  'Ashish',
#  'Karnavat',
#  '..............................................................................................',
#  '90',
#  'ANLPiii',
#  'MIMIC:',
#  'An',
#  'Adaptive',
#  'Mixed',
#  'Initiative',
#  'Spoken',
#  'Dialogue',
#  'System',
#  'Information',
#  'Queries',
#  'Jennifer',
#  'Chu-Carroll',
#  '..............................................................................................................',
#  '97',
#  'Javox:',
#  'A',
#  'Toolkit',
#  'Building',
#  'Speech-Enabled',
#  'Applications',
#  'Michael',
#  'S.',
#  'Fulkerson,',
#  'Alan',
#  'W.',
#  'Biermann',
#  '...........................................................................',
#  '105',
#  'A',
#  'Compact',
#  'Architecture',
#  'Dialogue',
#  'Management',
#  'Based',
#  'Scripts',
#  'Meta-Outputs',
#  'Manny',
#  'Rayner,',
#  'Beth',
#  'Ann',
#  'Hockey,',
#  'Frankie',
#  'James',
#  '..............................................................',
#  '112',
#  'A',
#  'Representation',
#  'Complex',
#  'Evolving',
#  'Data',
#  'Dependencies',
#  'Generation',
#  'C.',
#  'Mellish,',
#  'R.',
#  'Evans,',
#  'L.',
#  'Cahill,',
#  'C.',
#  'Doran,',
#  'D.',
#  'Paiva,',
#  'M.',
#  'Reape,',
#  'D.',
#  'Scott,',
#  'N.',
#  'Tipper',
#  '.............................................................................',
#  '119',
#  'An',
#  'Automatic',
#  'Reviser:',
#  'The',
#  'TransCheck',
#  'System',
#  'Jean-Marc',
#  'Jutras',
#  '..................................................................................................................',
#  '127',
#  'Unit',
#  'Completion',
#  'Computer-Aided',
#  'Translation',
#  'Typing',
#  'System',
#  'Philippe',
#  'Langlais,',
#  'George',
#  'Foster,',
#  'Guy',
#  'Lapalme',
#  '.................................................................',
#  '135',
#  'Multilingual',
#  'Coreference',
#  'Resolution',
#  'Sanda',
#  'M.',
#  'Harabagiu,',
#  'Steven',
#  'J.',
#  'Maiorano',
#  '...........................................................................',
#  '142',
#  'Ranking',
#  'Suspected',
#  'Answers',
#  'Natural',
#  'Language',
#  'Questions',
#  'Using',
#  'Predictive',
#  'Annotation',
#  'Dragomir',
#  'R.',
#  'Radev,',
#  'John',
#  'Prager,',
#  'Valerie',
#  'Samn',
#  '.................................................................',
#  '150',
#  'Message',
#  'Classification',
#  'Call',
#  'Center',
#  'Stephan',
#  'Busemann,',
#  'Sven',
#  'Schmeier,',
#  'Roman',
#  'G.',
#  'Arens',
#  '.......................................................',
#  '158',
#  'A',
#  'Question',
#  'Answering',
#  'System',
#  'Supported',
#  'Information',
#  'Extraction',
#  'Rohini',
#  'Srihari,',
#  'Wei',
#  'Li',
#  '........................................................................................................',
#  '166',
#  'Categorizing',
#  'Unknown',
#  'Words:',
#  'Using',
#  'Decision',
#  'Trees',
#  'Identify',
#  'Names',
#  'Misspellings',
#  'Janine',
#  'Toole',
#  '.........................................................................................................................',
#  '173',
#  'Examining',
#  'Role',
#  'Statistical',
#  'Linguistic',
#  'Knowledge',
#  'Sources',
#  'General-Knowledge',
#  'Question-Answering',
#  'System',
#  'Claire',
#  'Cardie,',
#  'Vincent',
#  'Ng,',
#  'David',
#  'Pierce,',
#  'Chris',
#  'Buckley',
#  '....................................................',
#  '180',
#  'Extracting',
#  'Molecular',
#  'Binding',
#  'Relationships',
#  'Biomedical',
#  'Text',
#  'Thomas',
#  'C.',
#  'Rindflesch,',
#  'Jayant',
#  'V.',
#  'Rajan,',
#  'Lawrence',
#  'Hunter',
#  '................................................',
#  '188',
#  'Compound',
#  'Noun',
#  'Segmentation',
#  'Based',
#  'Lexical',
#  'Data',
#  'Extracted',
#  'Corpus',
#  'Juntae',
#  'Yoon',
#  '.........................................................................................................................',
#  '196',
#  'Experiments',
#  'Corpus-Based',
#  'LFG',
#  'Specialization',
#  'Nicola',
#  'Cancedda,',
#  'Christer',
#  'Samuelsson',
#  '...............................................................................',
#  '204',
#  'A',
#  'Tool',
#  'Automated',
#  'Revision',
#  'Grammars',
#  'NLP',
#  'Systems',
#  'Nanda',
#  'Kambhatla,',
#  'Wlodek',
#  'Zadrozny',
#  '.................................................................................',
#  '210',
#  'ANLPiv',
#  'Aggressive',
#  'Morphology',
#  'Robust',
#  'Lexical',
#  'Coverage',
#  'William',
#  'A.',
#  'Woods',
#  '...............................................................................................................',
#  '218',
#  'TnT--A',
#  'Statistical',
#  'Part-of-Speech',
#  'Tagger',
#  'Thorsten',
#  'Brants',
#  '...................................................................................................................',
#  '224',
#  'Language',
#  'Independent',
#  'Morphological',
#  'Analysis',
#  'Tatsuo',
#  'Yamashita,',
#  'Yuji',
#  'Matsumoto',
#  '....................................................................................',
#  '232',
#  'A',
#  'Divide-and-Conquer',
#  'Strategy',
#  'Shallow',
#  'Parsing',
#  'German',
#  'Free',
#  'Texts',
#  'Giinter',
#  'Neumann,',
#  'Christian',
#  'Braun,',
#  'Jakub',
#  'Piskorski',
#  '...........................................................',
#  '239',
#  'A',
#  'Hybrid',
#  'Approach',
#  'Named',
#  'Entity',
#  'Sub-Type',
#  'Tagging',
#  'Rohini',
#  'Srihari,',
#  'Cheng',
#  'Niu,',
#  'Wei',
#  'Li',
#  '......................................................................................',
#  '247',
#  'Spelling',
#  'Grammar',
#  'Correction',
#  'Danish',
#  'SCARRIE',
#  'Patrizia',
#  'Paggio',
#  '.....................................................................................................................',
#  '255',
#  'Linguistic',
#  'Knowledge',
#  'Can',
#  'Improve',
#  'Information',
#  'Retrieval',
#  'William',
#  'A.',
#  'Woods,',
#  'Lawrence',
#  'A.',
#  'Bookman,',
#  'Ann',
#  'Houston,',
#  'Robert',
#  'J.',
#  'Kuhns,',
#  'Paul',
#  'Martin,',
#  'Stephen',
#  'Green',
#  '.................................................................................................',
#  '262',
#  'Domain-Specific',
#  'Knowledge',
#  'Acquisition',
#  'Text',
#  'Dan',
#  'Moldovan,',
#  'Roxana',
#  'Girju,',
#  'Vasile',
#  'Rus',
#  '..........................................................................',
#  '268',
#  'Large-Scale',
#  'Controlled',
#  'Vocabulary',
#  'Indexing',
#  'Named',
#  'Entities',
#  'Mark',
#  'Wasson',
#  '.......................................................................................................................',
#  '276',
#  'Unsupervised',
#  'Discovery',
#  'Scenario-Level',
#  'Patterns',
#  'Information',
#  'Extraction',
#  'Roman',
#  'Yangarber,',
#  'Ralph',
#  'Grishman,',
#  'Pasi',
#  'Tapanainen,',
#  'Silja',
#  'Huttunen',
#  '..............................',
#  '282',
#  'Using',
#  'Corpus-Derived',
#  'Name',
#  'Lists',
#  'Named',
#  'Entity',
#  'Recognition',
#  'Mark',
#  'Stevenson,',
#  'Robert',
#  'Gaizauskas',
#  '...................................................................................',
#  '290',
#  'Answer',
#  'Extraction',
#  'Steven',
#  'Abney,',
#  'Michael',
#  'Collins,',
#  'Amit',
#  'Singhal',
#  '....................................................................',
#  '296',
#  'Evaluation',
#  'Automatically',
#  'Identified',
#  'Index',
#  'Terms',
#  'Browsing',
#  'Electronic',
#  'Documents',
#  'Nina',
#  'Wacholder,',
#  'Judith',
#  'L.',
#  'Klavans,',
#  'David',
#  'K.',
#  'Evans',
#  '.........................................................',
#  '302',
#  'Sentence',
#  'Reduction',
#  'Automatic',
#  'Text',
#  'Summarization',
#  'Hongyan',
#  'Jing',
#  '.......................................................................................................................',
#  '310',
#  'Named',
#  'Entity',
#  'Extraction',
#  'Noisy',
#  'Input:',
#  'Speech',
#  'OCR',
#  'David',
#  'Miller,',
#  'Sean',
#  'Boisen,',
#  'Richard',
#  'Schwartz,',
#  'Rebecca',
#  'Stone,',
#  'Ralph',
#  'Weischedel',
#  '...........',
#  '316',
#  'Improving',
#  'Testsuites',
#  'via',
#  'Instrumentation',
#  'Norbert',
#  'Br6ker',
#  '.....................................................................................................................',
#  '325',
#  'The',
#  'Efficiency',
#  'Multimodal',
#  'Interaction',
#  'Map-Based',
#  'Task',
#  'Philip',
#  'Cohen,',
#  'David',
#  'McGee,',
#  'Josh',
#  'Clow',
#  '................................................................',
#  '331',
#  'ANLPv',
#  'BusTUC',
#  'A',
#  'natura',
#  'l',
#  'l',
#  'anguage',
#  'bus',
#  'route',
#  'rac',
#  'le',
#  'Tore',
#  'Amble',
#  'Dept.',
#  'computer',
#  'information',
#  'science',
#  'University',
#  'Trondheim',
#  'Norway,',
#  'N-7491',
#  'amble@idi,',
#  'ntnu.',
#  'Abstract',
#  'The',
#  'paper',
#  'describes',
#  'natural',
#  'anguage',
#  'based',
#  'expert',
#  'system',
#  'route',
#  'advisor',
#  'public',
#  'bus',
#  'transport',
#  'Trondheim,',
#  'Norway.',
#  'The',
#  'system',
#  'available',
#  'Internet,and',
#  'intstalled',
#  'bus',
#  'com-',
#  "pany's",
#  'web',
#  'server',
#  'since',
#  'beginning',
#  '1999.',
#  'The',
#  'system',
#  'bilingual,',
#  'relying',
#  'internal',
#  'anguage',
#  'independent',
#  'logic',
#  'representation.',
#  '1',
#  'Introduct',
#  'ion',
#  'A',
#  'natural',
#  'anguage',
#  'interface',
#  'computer',
#  'database',
#  'provides',
#  'users',
#  'capability',
#  'obtaining',
#  'in-',
#  'formation',
#  'stored',
#  'database',
#  'querying',
#  'system',
#  'natural',
#  'language',
#  ...]

# %%
v = vacabulary(z)  #it makes a vacabulary and avoid repeating same string
v  #dictionary display
# Out:
# ['Association',
#  'Computational',
#  'Linguistics',
#  '6',
#  'th',
#  'Applied',
#  'Natural',
#  'Language',
#  'Processing',
#  'Conference',
#  'Proceedings',
#  'April',
#  '29--May',
#  '4,',
#  '2000',
#  'Seattle,',
#  'Washington,',
#  'USA',
#  'ANLP',
#  '2000-PREFACE',
#  '131',
#  'papers',
#  'submitted',
#  'ANLP-2000.',
#  '46',
#  'accepted',
#  'presentation',
#  'conference.',
#  'Papers',
#  'came',
#  '24',
#  'countries:',
#  'fifty',
#  'eight',
#  'United',
#  'States',
#  'America,',
#  'eleven',
#  'Germany',
#  'Kingdom,',
#  'nine',
#  'Canada,',
#  'Japan,',
#  'four',
#  'Italy',
#  'Spain,',
#  'three',
#  'ach',
#  'France,',
#  'Korea',
#  'Switzerland,',
#  'two',
#  'Australia,',
#  'China,',
#  'The',
#  'Netherlands',
#  'Sweden',
#  'one',
#  'Czech',
#  'Republic,',
#  'Denmark,',
#  'Finland,',
#  'Greece,',
#  'India,',
#  'Hong',
#  'Kong,',
#  'Malaysia,',
#  'Norway,',
#  'Russia',
#  'Taiwan.',
#  '40',
#  'industry.',
#  '85',
#  'academia.',
#  '2',
#  'government',
#  'organizations',
#  'submissions',
#  'combined.',
#  'reviewing',
#  'process',
#  'supported',
#  'web-based',
#  'reviewer',
#  'interface',
#  'developed',
#  'Elisha',
#  'Kane',
#  'New',
#  'Mexico',
#  'State',
#  "University's",
#  'Computing',
#  'Research',
#  'Lab.',
#  'Linda',
#  'Fresques',
#  'CRL',
#  'coordinated',
#  'refereeing',
#  'process.',
#  'I',
#  'would',
#  'like',
#  'express',
#  'gratitude',
#  'appreciation',
#  'fthe',
#  'Program',
#  'Committee',
#  'members',
#  'responsible',
#  'six',
#  'areas:',
#  'Lynn',
#  'Carlson,',
#  'Tools',
#  'Resources',
#  'Developing',
#  'NLP',
#  'Systems',
#  'Subcommittee',
#  'Eduard',
#  'Hovy,',
#  'Integrated',
#  'Richard',
#  'Kittredge,',
#  'Multilingual',
#  'Text',
#  'Ray',
#  'Perrault,',
#  'Spoken',
#  'Oliviero',
#  'Stock,',
#  'Monolingual',
#  'John',
#  'White,',
#  'Evaluation',
#  'following',
#  'colleagues',
#  'Doug',
#  'Appelt',
#  'Fabio',
#  'Ciravegna',
#  'Robert',
#  'Dale',
#  'Michael',
#  'Elhadad',
#  'Ralph',
#  'G-rishman',
#  'Lynette',
#  'Hirschman',
#  'Yuval',
#  'Krymolowski',
#  'Inderjeet',
#  'Mani',
#  'Zvi',
#  'Marx',
#  'Martha',
#  'Palmer',
#  'Harold',
#  'Somers',
#  'Toshiyuki',
#  'Takezawa',
#  'Takehito',
#  'Utsuro',
#  'Dekai',
#  'Wu',
#  'bulk',
#  'reviewing:',
#  'Igor',
#  'Boguslavsky',
#  'Jim',
#  'Cowie',
#  'Dowding',
#  'Glass',
#  'Jan',
#  'Haji~',
#  'Pierre',
#  'IsabeIIe',
#  'Alberto',
#  'Lavelli',
#  'Daniel',
#  'Marcu',
#  'David',
#  'McDonald',
#  'Owen',
#  'Rainbow',
#  'Tomek',
#  'Strzalkowski',
#  'Kathryn',
#  'B.',
#  'Taylor',
#  'Pick',
#  'Vossen',
#  'R6mi',
#  'Zajac',
#  'Carter',
#  'Ido',
#  'Dagan',
#  'Andreas',
#  'Eiscle',
#  'Oren',
#  'Glikman',
#  'Donna',
#  'Harman',
#  'Tanya',
#  'Korelsky',
#  'Chin-Yew',
#  'Lin',
#  'Paul',
#  'Martin',
#  'Teruko',
#  'Mitamura',
#  'Norbert',
#  'Reithinger',
#  'Beth',
#  'Sundheim',
#  'Hans',
#  'Uszkoreit',
#  'Weischedel',
#  'We',
#  'believe',
#  'quality',
#  'elected',
#  'israther',
#  'high',
#  'hope',
#  'conference',
#  'success.',
#  'Sergei',
#  'Nirenburg',
#  'Chair,',
#  'ANLP-2000',
#  'ANLPi',
#  'Table',
#  'Contents',
#  'Section',
#  '1:',
#  '(ANLP)',
#  'Preface',
#  'List',
#  'Reviewers',
#  'Nirenburg,',
#  'Chair',
#  '...............................................................',
#  'BusTUC--A',
#  'Bus',
#  'Route',
#  'Oracle',
#  'Tore',
#  'Amble',
#  '..............................................................................................................................',
#  '1',
#  'Machine',
#  'Translation',
#  'Very',
#  'Close',
#  'Languages',
#  'Haji~,',
#  'Hric,',
#  'Vladislav',
#  'Kubofi',
#  '.......................................................................................',
#  '7',
#  'Cross-Language',
#  'Multimedia',
#  'Information',
#  'Retrieval',
#  'Sharon',
#  'Flank',
#  '..........................................................................................................................',
#  '13',
#  'Automatic',
#  'Construction',
#  'Parallel',
#  'English-Chinese',
#  'Corpus',
#  'Jiang',
#  'Chen,',
#  'Jian-Yun',
#  'Nie',
#  '......................................................................................................',
#  '21',
#  'PartslD:',
#  'A',
#  'Dialogue-Based',
#  'System',
#  'Identifying',
#  'Parts',
#  'Medical',
#  'Amit',
#  'Bagga,',
#  'Strzalkowski,',
#  'G.',
#  'Bowden',
#  'Wise',
#  '...........................................................',
#  '29',
#  'Using',
#  'Dialogue',
#  'Participants',
#  'Setsuo',
#  'Yamada,',
#  'Eiichiro',
#  'Sumita,',
#  'Hideki',
#  'Kashioka',
#  '..............................................................',
#  '37',
#  'Distilling',
#  'Dialogues--A',
#  'Method',
#  'Corpora',
#  'Development',
#  'Arne',
#  'J6nsson,',
#  'Nils',
#  'Dahlb~ick',
#  '.................................................................................................',
#  '44',
#  'Plan-Based',
#  'Management',
#  'ina',
#  'Physics',
#  'Tour',
#  'Reva',
#  'Freedman',
#  '......................................................................................................................',
#  '52',
#  'Framework',
#  'MT',
#  'NLG',
#  'Based',
#  'Uniform',
#  'Lexico-Structural',
#  'Benoit',
#  'Lavoie,',
#  'Korelsky,',
#  'Rambow',
#  '...................................',
#  '60',
#  "Talk'N'Travel:",
#  'Conversational',
#  'Air',
#  'Travel',
#  'Planning',
#  'Stallard',
#  '........................................................................................................................',
#  '68',
#  'REES:',
#  'Large-Scale',
#  'Relation',
#  'Event',
#  'Extraction',
#  'Chinatsu',
#  'Aone,',
#  'Mila',
#  'Ramos-Santacruz',
#  '.................................................................................',
#  '76',
#  'Experiments',
#  'Sentence',
#  'Boundary',
#  'Detection',
#  'Mark',
#  'Stevenson,',
#  'Gaizauskas',
#  '.....................................................................................',
#  '84',
#  'DP:',
#  'Detector',
#  'Presuppositions',
#  'Survey',
#  'Questions',
#  'Katja',
#  'Wiemer-Hastings,',
#  'Peter',
#  'Sonya',
#  'Rajan,',
#  'Art',
#  'Graesser,',
#  'Roger',
#  'Kreuz,',
#  'Ashish',
#  'Karnavat',
#  '..............................................................................................',
#  '90',
#  'ANLPiii',
#  'MIMIC:',
#  'An',
#  'Adaptive',
#  'Mixed',
#  'Initiative',
#  'Queries',
#  'Jennifer',
#  'Chu-Carroll',
#  '..............................................................................................................',
#  '97',
#  'Javox:',
#  'Toolkit',
#  'Building',
#  'Speech-Enabled',
#  'Applications',
#  'S.',
#  'Fulkerson,',
#  'Alan',
#  'W.',
#  'Biermann',
#  '...........................................................................',
#  '105',
#  'Compact',
#  'Architecture',
#  'Scripts',
#  'Meta-Outputs',
#  'Manny',
#  'Rayner,',
#  'Ann',
#  'Hockey,',
#  'Frankie',
#  'James',
#  '112',
#  'Representation',
#  'Complex',
#  'Evolving',
#  'Data',
#  'Dependencies',
#  'Generation',
#  'C.',
#  'Mellish,',
#  'R.',
#  'Evans,',
#  'L.',
#  'Cahill,',
#  'Doran,',
#  'D.',
#  'Paiva,',
#  'M.',
#  'Reape,',
#  'Scott,',
#  'N.',
#  'Tipper',
#  '.............................................................................',
#  '119',
#  'Reviser:',
#  'TransCheck',
#  'Jean-Marc',
#  'Jutras',
#  '..................................................................................................................',
#  '127',
#  'Unit',
#  'Completion',
#  'Computer-Aided',
#  'Typing',
#  'Philippe',
#  'Langlais,',
#  'George',
#  'Foster,',
#  'Guy',
#  'Lapalme',
#  '.................................................................',
#  '135',
#  'Coreference',
#  'Resolution',
#  'Sanda',
#  'Harabagiu,',
#  'Steven',
#  'J.',
#  'Maiorano',
#  '142',
#  'Ranking',
#  'Suspected',
#  'Answers',
#  'Predictive',
#  'Annotation',
#  'Dragomir',
#  'Radev,',
#  'Prager,',
#  'Valerie',
#  'Samn',
#  '150',
#  'Message',
#  'Classification',
#  'Call',
#  'Center',
#  'Stephan',
#  'Busemann,',
#  'Sven',
#  'Schmeier,',
#  'Roman',
#  'Arens',
#  '.......................................................',
#  '158',
#  'Question',
#  'Answering',
#  'Supported',
#  'Rohini',
#  'Srihari,',
#  'Wei',
#  'Li',
#  '........................................................................................................',
#  '166',
#  'Categorizing',
#  'Unknown',
#  'Words:',
#  'Decision',
#  'Trees',
#  'Identify',
#  'Names',
#  'Misspellings',
#  'Janine',
#  'Toole',
#  '.........................................................................................................................',
#  '173',
#  'Examining',
#  'Role',
#  'Statistical',
#  'Linguistic',
#  'Knowledge',
#  'Sources',
#  'General-Knowledge',
#  'Question-Answering',
#  'Claire',
#  'Cardie,',
#  'Vincent',
#  'Ng,',
#  'Pierce,',
#  'Chris',
#  'Buckley',
#  '....................................................',
#  '180',
#  'Extracting',
#  'Molecular',
#  'Binding',
#  'Relationships',
#  'Biomedical',
#  'Thomas',
#  'Rindflesch,',
#  'Jayant',
#  'V.',
#  'Lawrence',
#  'Hunter',
#  '................................................',
#  '188',
#  'Compound',
#  'Noun',
#  'Segmentation',
#  'Lexical',
#  'Extracted',
#  'Juntae',
#  'Yoon',
#  '196',
#  'Corpus-Based',
#  'LFG',
#  'Specialization',
#  'Nicola',
#  'Cancedda,',
#  'Christer',
#  'Samuelsson',
#  '...............................................................................',
#  '204',
#  'Tool',
#  'Automated',
#  'Revision',
#  'Grammars',
#  'Nanda',
#  'Kambhatla,',
#  'Wlodek',
#  'Zadrozny',
#  '210',
#  'ANLPiv',
#  'Aggressive',
#  'Morphology',
#  'Robust',
#  'Coverage',
#  'William',
#  'A.',
#  'Woods',
#  '...............................................................................................................',
#  '218',
#  'TnT--A',
#  'Part-of-Speech',
#  'Tagger',
#  'Thorsten',
#  'Brants',
#  '...................................................................................................................',
#  '224',
#  'Independent',
#  'Morphological',
#  'Analysis',
#  'Tatsuo',
#  'Yamashita,',
#  'Yuji',
#  'Matsumoto',
#  '....................................................................................',
#  '232',
#  'Divide-and-Conquer',
#  'Strategy',
#  'Shallow',
#  'Parsing',
#  'German',
#  'Free',
#  'Texts',
#  'Giinter',
#  'Neumann,',
#  'Christian',
#  'Braun,',
#  'Jakub',
#  'Piskorski',
#  '239',
#  'Hybrid',
#  'Approach',
#  'Named',
#  'Entity',
#  'Sub-Type',
#  'Tagging',
#  'Cheng',
#  'Niu,',
#  '......................................................................................',
#  '247',
#  'Spelling',
#  'Grammar',
#  'Correction',
#  'Danish',
#  'SCARRIE',
#  'Patrizia',
#  'Paggio',
#  '.....................................................................................................................',
#  '255',
#  'Can',
#  'Improve',
#  'Woods,',
#  'Bookman,',
#  'Houston,',
#  'Kuhns,',
#  'Martin,',
#  'Stephen',
#  'Green',
#  '262',
#  'Domain-Specific',
#  'Acquisition',
#  'Dan',
#  'Moldovan,',
#  'Roxana',
#  'Girju,',
#  'Vasile',
#  'Rus',
#  '..........................................................................',
#  '268',
#  'Controlled',
#  'Vocabulary',
#  'Indexing',
#  'Entities',
#  'Wasson',
#  '.......................................................................................................................',
#  '276',
#  'Unsupervised',
#  'Discovery',
#  'Scenario-Level',
#  'Patterns',
#  'Yangarber,',
#  'Grishman,',
#  'Pasi',
#  'Tapanainen,',
#  'Silja',
#  'Huttunen',
#  '..............................',
#  '282',
#  'Corpus-Derived',
#  'Name',
#  'Lists',
#  'Recognition',
#  '...................................................................................',
#  '290',
#  'Answer',
#  'Abney,',
#  'Collins,',
#  'Singhal',
#  '....................................................................',
#  '296',
#  'Automatically',
#  'Identified',
#  'Index',
#  'Terms',
#  'Browsing',
#  'Electronic',
#  'Documents',
#  'Nina',
#  'Wacholder,',
#  'Judith',
#  'Klavans,',
#  'K.',
#  'Evans',
#  '.........................................................',
#  '302',
#  'Reduction',
#  'Summarization',
#  'Hongyan',
#  'Jing',
#  '310',
#  'Noisy',
#  'Input:',
#  'Speech',
#  'OCR',
#  'Miller,',
#  'Sean',
#  'Boisen,',
#  'Schwartz,',
#  'Rebecca',
#  'Stone,',
#  '...........',
#  '316',
#  'Improving',
#  'Testsuites',
#  'via',
#  'Instrumentation',
#  'Br6ker',
#  '325',
#  'Efficiency',
#  'Multimodal',
#  'Interaction',
#  'Map-Based',
#  'Task',
#  'Philip',
#  'Cohen,',
#  'McGee,',
#  'Josh',
#  'Clow',
#  '................................................................',
#  '331',
#  'ANLPv',
#  'BusTUC',
#  'natura',
#  'l',
#  'anguage',
#  'bus',
#  'route',
#  'rac',
#  'le',
#  'Dept.',
#  'computer',
#  'information',
#  'science',
#  'University',
#  'Trondheim',
#  'N-7491',
#  'amble@idi,',
#  'ntnu.',
#  'Abstract',
#  'paper',
#  'describes',
#  'natural',
#  'based',
#  'expert',
#  'system',
#  'advisor',
#  'public',
#  'transport',
#  'Trondheim,',
#  'Norway.',
#  'available',
#  'Internet,and',
#  'intstalled',
#  'com-',
#  "pany's",
#  'web',
#  'server',
#  'since',
#  'beginning',
#  '1999.',
#  'bilingual,',
#  'relying',
#  'internal',
#  'independent',
#  'logic',
#  'representation.',
#  'Introduct',
#  'ion',
#  'database',
#  'provides',
#  'users',
#  'capability',
#  'obtaining',
#  'in-',
#  'formation',
#  'stored',
#  'querying',
#  'language',
#  '(NL).',
#  'With',
#  'means',
#  'communication',
#  'puter',
#  'system,',
#  'make',
#  'question',
#  'statement',
#  'way',
#  'normally',
#  'think',
#  'discussed,',
#  'freeing',
#  'hav-',
#  'ing',
#  'know',
#  'stores',
#  'processes',
#  'information.',
#  'present',
#  'implementation',
#  'represents',
#  'major',
#  'effort',
#  'bringing',
#  'practical',
#  'use.',
#  'answer',
#  'queries',
#  'routes,',
#  'stated',
#  'texts,',
#  'made',
#  'Internet',
#  'World',
#  'Wide',
#  'Web',
#  'http',
#  '//www.',
#  'idi.',
#  'no/bustuc/).',
#  'small',
#  'city',
#  'university',
#  '140000',
#  'inhabitants.',
#  'Its',
#  'central',
#  'systems',
#  '42',
#  'lines,',
#  'serving',
#  '590',
#  'stations,',
#  '1900',
#  'depar-',
#  'tures',
#  'per',
#  'day',
#  '(in',
#  'average).',
#  'That',
#  'gives',
#  'approximately',
#  '60000',
#  'scheduled',
#  'station',
#  'passings',
#  'day,',
#  'somehow',
#  'represented',
#  'data',
#  'base.',
#  'starting',
#  'point',
#  'automate',
#  'function',
#  'agent.',
#  'example',
#  'response',
#  'using',
#  'actual',
#  'request',
#  'telephone',
#  'local',
#  'company:',
#  'Hi,',
#  'live',
#  'Nidarvoll',
#  'tonight',
#  'must',
#  'reach',
#  'train',
#  'Oslo',
#  'oclock.',
#  'typical',
#  'follow',
#  'quickly:',
#  'number',
#  '54',
#  'passes',
#  'skole',
#  '1710',
#  'arrives',
#  'Railway',
#  'Station',
#  '1725.',
#  'In',
#  'pro-',
#  'cess',
#  'lexical',
#  'analysis,',
#  'syntax',
#  'semantic',
#  'pragmatic',
#  'reasoning',
#  'query',
#  'processing.',
#  'One',
#  'could',
#  'argue',
#  'content',
#  'solved',
#  'interrogation,',
#  'whereby',
#  'customer',
#  'asked',
#  'produce',
#  '4',
#  'items:',
#  'ta',
#  'departure,',
#  'arrival,',
#  'earliest',
#  'departure',
#  'timeand/or',
#  'latest',
#  'arrival',
#  'time.',
#  'It',
#  'myth',
#  'better',
#  '"natural',
#  'language".',
#  'challenge',
#  'prove',
#  'demonstration',
#  'NL',
#  'preferred',
#  'interrogative',
#  'mode.',
#  'To',
#  'that,',
#  'correct,',
#  'user',
#  'friendly',
#  'almost',
#  'complete',
#  'within',
#  'domain.',
#  'Previous',
#  'Efforts,',
#  'CHAT-80,',
#  'PRAT-89',
#  'HSQL',
#  'called',
#  'built',
#  'upon',
#  'clas-',
#  'sical',
#  'CHAT-80',
#  '(Warren',
#  'Pereira,',
#  '1982).',
#  'state',
#  'art',
#  'sys-',
#  'tem',
#  'impressive',
#  'merits,',
#  'also',
#  'established',
#  'Prolog',
#  'viable',
#  'competitive',
#  'lan-',
#  'guage',
#  'Artificial',
#  'Intelligence',
#  'general.',
#  'brilliant',
#  'masterpiece',
#  'software,',
#  'efficient',
#  'sophisticated.',
#  'connected',
#  'international',
#  'geography.',
#  'analysed',
#  'answered',
#  'split',
#  'second:',
#  'Which',
#  'country',
#  'bordering',
#  'Mediterranean',
#  'borders',
#  'bordered',
#  'whose',
#  'population',
#  'exceeds',
#  ...]

# %%
df = documentfreq(d, v) #document frequency of corpus by using dictionary and vacabulary
df
# Out:
# {'Association': 22,
#  'Computational': 35,
#  'Linguistics': 18,
#  '6': 38,
#  'th': 11,
#  'Applied': 20,
#  'Natural': 40,
#  'Language': 43,
#  'Processing': 24,
#  'Conference': 44,
#  'Proceedings': 47,
#  'April': 2,
#  '29--May': 2,
#  '4,': 17,
#  '2000': 7,
#  'Seattle,': 4,
#  'Washington,': 15,
#  'USA': 10,
#  'ANLP': 4,
#  '2000-PREFACE': 2,
#  '131': 3,
#  'papers': 2,
#  'submitted': 7,
#  'ANLP-2000.': 1,
#  '46': 3,
#  'accepted': 9,
#  'presentation': 6,
#  'conference.': 3,
#  'Papers': 1,
#  'came': 5,
#  '24': 7,
#  'countries:': 1,
#  'fifty': 3,
#  'eight': 10,
#  'United': 9,
#  'States': 6,
#  'America,': 1,
#  'eleven': 2,
#  'Germany': 4,
#  'Kingdom,': 1,
#  'nine': 4,
#  'Canada,': 10,
#  'Japan,': 2,
#  'four': 25,
#  'Italy': 1,
#  'Spain,': 1,
#  'three': 40,
#  'ach': 4,
#  'France,': 3,
#  'Korea': 1,
#  'Switzerland,': 1,
#  'two': 50,
#  'Australia,': 2,
#  'China,': 1,
#  'The': 50,
#  'Netherlands': 1,
#  'Sweden': 1,
#  'one': 49,
#  'Czech': 3,
#  'Republic,': 2,
#  'Denmark,': 3,
#  'Finland,': 2,
#  'Greece,': 1,
#  'India,': 1,
#  'Hong': 3,
#  'Kong,': 1,
#  'Malaysia,': 2,
#  'Norway,': 2,
#  'Russia': 1,
#  'Taiwan.': 1,
#  '40': 9,
#  'industry.': 2,
#  '85': 6,
#  'academia.': 1,
#  '2': 49,
#  'government': 6,
#  'organizations': 3,
#  'submissions': 2,
#  'combined.': 3,
#  'reviewing': 1,
#  'process': 31,
#  'supported': 18,
#  'web-based': 2,
#  'reviewer': 1,
#  'interface': 11,
#  'developed': 32,
#  'Elisha': 1,
#  'Kane': 2,
#  'New': 28,
#  'Mexico': 3,
#  'State': 12,
#  "University's": 1,
#  'Computing': 11,
#  'Research': 30,
#  'Lab.': 1,
#  'Linda': 2,
#  'Fresques': 2,
#  'CRL': 1,
#  'coordinated': 1,
#  'refereeing': 1,
#  'process.': 16,
#  'I': 43,
#  'would': 48,
#  'like': 39,
#  'express': 10,
#  'gratitude': 2,
#  'appreciation': 1,
#  'fthe': 1,
#  'Program': 7,
#  'Committee': 3,
#  'members': 4,
#  'responsible': 9,
#  'six': 8,
#  'areas:': 1,
#  'Lynn': 3,
#  'Carlson,': 2,
#  'Tools': 4,
#  'Resources': 6,
#  'Developing': 4,
#  'NLP': 18,
#  'Systems': 16,
#  'Subcommittee': 1,
#  'Eduard': 1,
#  'Hovy,': 2,
#  'Integrated': 4,
#  'Richard': 10,
#  'Kittredge,': 2,
#  'Multilingual': 7,
#  'Text': 25,
#  'Ray': 2,
#  'Perrault,': 1,
#  'Spoken': 10,
#  'Oliviero': 1,
#  'Stock,': 2,
#  'Monolingual': 1,
#  'John': 16,
#  'White,': 3,
#  'Evaluation': 17,
#  'following': 42,
#  'colleagues': 6,
#  'Doug': 4,
#  'Appelt': 4,
#  'Fabio': 2,
#  'Ciravegna': 1,
#  'Robert': 7,
#  'Dale': 1,
#  'Michael': 9,
#  'Elhadad': 1,
#  'Ralph': 6,
#  'G-rishman': 1,
#  'Lynette': 3,
#  'Hirschman': 2,
#  'Yuval': 2,
#  'Krymolowski': 1,
#  'Inderjeet': 3,
#  'Mani': 1,
#  'Zvi': 2,
#  'Marx': 1,
#  'Martha': 2,
#  'Palmer': 5,
#  'Harold': 1,
#  'Somers': 1,
#  'Toshiyuki': 3,
#  'Takezawa': 2,
#  'Takehito': 2,
#  'Utsuro': 1,
#  'Dekai': 3,
#  'Wu': 4,
#  'bulk': 1,
#  'reviewing:': 1,
#  'Igor': 1,
#  'Boguslavsky': 1,
#  'Jim': 3,
#  'Cowie': 1,
#  'Dowding': 1,
#  'Glass': 2,
#  'Jan': 5,
#  'Haji~': 3,
#  'Pierre': 3,
#  'IsabeIIe': 1,
#  'Alberto': 2,
#  'Lavelli': 1,
#  'Daniel': 4,
#  'Marcu': 2,
#  'David': 22,
#  'McDonald': 3,
#  'Owen': 3,
#  'Rainbow': 1,
#  'Tomek': 2,
#  'Strzalkowski': 2,
#  'Kathryn': 1,
#  'B.': 19,
#  'Taylor': 2,
#  'Pick': 3,
#  'Vossen': 1,
#  'R6mi': 1,
#  'Zajac': 1,
#  'Carter': 2,
#  'Ido': 4,
#  'Dagan': 3,
#  'Andreas': 2,
#  'Eiscle': 1,
#  'Oren': 2,
#  'Glikman': 1,
#  'Donna': 2,
#  'Harman': 3,
#  'Tanya': 2,
#  'Korelsky': 2,
#  'Chin-Yew': 1,
#  'Lin': 2,
#  'Paul': 7,
#  'Martin': 6,
#  'Teruko': 2,
#  'Mitamura': 2,
#  'Norbert': 1,
#  'Reithinger': 1,
#  'Beth': 3,
#  'Sundheim': 1,
#  'Hans': 4,
#  'Uszkoreit': 2,
#  'Weischedel': 4,
#  'We': 50,
#  'believe': 14,
#  'quality': 18,
#  'elected': 4,
#  'israther': 1,
#  'high': 31,
#  'hope': 5,
#  'conference': 4,
#  'success.': 1,
#  'Sergei': 1,
#  'Nirenburg': 1,
#  'Chair,': 1,
#  'ANLP-2000': 1,
#  'ANLPi': 1,
#  'Table': 28,
#  'Contents': 2,
#  'Section': 26,
#  '1:': 36,
#  '(ANLP)': 1,
#  'Preface': 2,
#  'List': 6,
#  'Reviewers': 2,
#  'Nirenburg,': 1,
#  'Chair': 2,
#  '...............................................................': 1,
#  'BusTUC--A': 1,
#  'Bus': 2,
#  'Route': 1,
#  'Oracle': 1,
#  'Tore': 2,
#  'Amble': 2,
#  '..............................................................................................................................': 1,
#  '1': 48,
#  'Machine': 15,
#  'Translation': 12,
#  'Very': 11,
#  'Close': 4,
#  'Languages': 4,
#  'Haji~,': 3,
#  'Hric,': 1,
#  'Vladislav': 4,
#  'Kubofi': 2,
#  '.......................................................................................': 2,
#  '7': 26,
#  'Cross-Language': 2,
#  'Multimedia': 3,
#  'Information': 33,
#  'Retrieval': 14,
#  'Sharon': 4,
#  'Flank': 2,
#  '..........................................................................................................................': 1,
#  '13': 9,
#  'Automatic': 18,
#  'Construction': 2,
#  'Parallel': 3,
#  'English-Chinese': 2,
#  'Corpus': 15,
#  'Jiang': 1,
#  'Chen,': 5,
#  'Jian-Yun': 1,
#  'Nie': 1,
#  '......................................................................................................': 1,
#  '21': 9,
#  'PartslD:': 2,
#  'A': 50,
#  'Dialogue-Based': 3,
#  'System': 25,
#  'Identifying': 9,
#  'Parts': 3,
#  'Medical': 4,
#  'Amit': 3,
#  'Bagga,': 2,
#  'Strzalkowski,': 3,
#  'G.': 21,
#  'Bowden': 2,
#  'Wise': 1,
#  '...........................................................': 1,
#  '29': 7,
#  'Using': 31,
#  'Dialogue': 10,
#  'Participants': 3,
#  'Setsuo': 2,
#  'Yamada,': 2,
#  'Eiichiro': 2,
#  'Sumita,': 2,
#  'Hideki': 2,
#  'Kashioka': 2,
#  '..............................................................': 1,
#  '37': 8,
#  'Distilling': 2,
#  'Dialogues--A': 1,
#  'Method': 7,
#  'Corpora': 4,
#  'Development': 10,
#  'Arne': 3,
#  'J6nsson,': 1,
#  'Nils': 2,
#  'Dahlb~ick': 2,
#  '.................................................................................................': 2,
#  '44': 6,
#  'Plan-Based': 2,
#  'Management': 5,
#  'ina': 2,
#  'Physics': 2,
#  'Tour': 1,
#  'Reva': 2,
#  'Freedman': 2,
#  '......................................................................................................................': 1,
#  '52': 4,
#  'Framework': 6,
#  'MT': 6,
#  'NLG': 3,
#  'Based': 17,
#  'Uniform': 2,
#  'Lexico-Structural': 2,
#  'Benoit': 2,
#  'Lavoie,': 2,
#  'Korelsky,': 2,
#  'Rambow': 2,
#  '...................................': 1,
#  '60': 13,
#  "Talk'N'Travel:": 1,
#  'Conversational': 4,
#  'Air': 4,
#  'Travel': 2,
#  'Planning': 4,
#  'Stallard': 2,
#  '........................................................................................................................': 1,
#  '68': 5,
#  'REES:': 2,
#  'Large-Scale': 2,
#  'Relation': 3,
#  'Event': 6,
#  'Extraction': 12,
#  'Chinatsu': 3,
#  'Aone,': 4,
#  'Mila': 2,
#  'Ramos-Santacruz': 2,
#  '.................................................................................': 1,
#  '76': 5,
#  'Experiments': 12,
#  'Sentence': 9,
#  'Boundary': 2,
#  'Detection': 6,
#  'Mark': 10,
#  'Stevenson,': 3,
#  'Gaizauskas': 1,
#  '.....................................................................................': 1,
#  '84': 4,
#  'DP:': 2,
#  'Detector': 2,
#  'Presuppositions': 2,
#  'Survey': 4,
#  'Questions': 3,
#  'Katja': 2,
#  'Wiemer-Hastings,': 2,
#  'Peter': 10,
#  'Sonya': 2,
#  'Rajan,': 1,
#  'Art': 5,
#  'Graesser,': 2,
#  'Roger': 5,
#  'Kreuz,': 2,
#  'Ashish': 2,
#  'Karnavat': 1,
#  '..............................................................................................': 2,
#  '90': 8,
#  'ANLPiii': 1,
#  'MIMIC:': 2,
#  'An': 38,
#  'Adaptive': 4,
#  'Mixed': 4,
#  'Initiative': 3,
#  'Queries': 5,
#  'Jennifer': 3,
#  'Chu-Carroll': 3,
#  '..............................................................................................................': 1,
#  '97': 7,
#  'Javox:': 1,
#  'Toolkit': 2,
#  'Building': 9,
#  'Speech-Enabled': 2,
#  'Applications': 6,
#  'S.': 28,
#  'Fulkerson,': 2,
#  'Alan': 5,
#  'W.': 24,
#  'Biermann': 1,
#  '...........................................................................': 1,
#  '105': 2,
#  'Compact': 2,
#  'Architecture': 10,
#  'Scripts': 2,
#  'Meta-Outputs': 2,
#  'Manny': 4,
#  'Rayner,': 3,
#  'Ann': 6,
#  'Hockey,': 2,
#  'Frankie': 1,
#  'James': 5,
#  '112': 3,
#  'Representation': 7,
#  'Complex': 3,
#  'Evolving': 2,
#  'Data': 14,
#  'Dependencies': 3,
#  'Generation': 8,
#  'C.': 24,
#  'Mellish,': 2,
#  'R.': 32,
#  'Evans,': 3,
#  'L.': 23,
#  'Cahill,': 2,
#  'Doran,': 3,
#  'D.': 25,
#  'Paiva,': 2,
#  'M.': 27,
#  'Reape,': 2,
#  'Scott,': 4,
#  'N.': 16,
#  'Tipper': 1,
#  '.............................................................................': 1,
#  '119': 2,
#  'Reviser:': 2,
#  'TransCheck': 2,
#  'Jean-Marc': 2,
#  'Jutras': 2,
#  '..................................................................................................................': 2,
#  '127': 3,
#  'Unit': 4,
#  'Completion': 2,
#  'Computer-Aided': 1,
#  'Typing': 2,
#  'Philippe': 1,
#  'Langlais,': 2,
#  'George': 7,
#  'Foster,': 3,
#  'Guy': 3,
#  'Lapalme': 2,
#  '.................................................................': 1,
#  '135': 3,
#  'Coreference': 3,
#  'Resolution': 4,
#  'Sanda': 3,
#  'Harabagiu,': 2,
#  'Steven': 7,
#  'J.': 41,
#  'Maiorano': 1,
#  '142': 2,
#  'Ranking': 5,
#  'Suspected': 1,
#  'Answers': 2,
#  'Predictive': 4,
#  'Annotation': 4,
#  'Dragomir': 3,
#  'Radev,': 4,
#  'Prager,': 3,
#  'Valerie': 2,
#  'Samn': 1,
#  '150': 4,
#  'Message': 11,
#  'Classification': 5,
#  'Call': 3,
#  'Center': 10,
#  'Stephan': 3,
#  'Busemann,': 2,
#  'Sven': 2,
#  'Schmeier,': 2,
#  'Roman': 6,
#  'Arens': 2,
#  '.......................................................': 1,
#  '158': 2,
#  'Question': 7,
#  'Answering': 5,
#  'Supported': 3,
#  'Rohini': 3,
#  'Srihari,': 4,
#  'Wei': 3,
#  'Li': 5,
#  '........................................................................................................': 2,
#  '166': 7,
#  'Categorizing': 2,
#  'Unknown': 4,
#  'Words:': 2,
#  'Decision': 4,
#  'Trees': 2,
#  'Identify': 5,
#  'Names': 4,
#  'Misspellings': 2,
#  'Janine': 1,
#  'Toole': 2,
#  '.........................................................................................................................': 2,
#  '173': 2,
#  'Examining': 3,
#  'Role': 6,
#  'Statistical': 14,
#  'Linguistic': 11,
#  'Knowledge': 10,
#  'Sources': 2,
#  'General-Knowledge': 2,
#  'Question-Answering': 2,
#  'Claire': 3,
#  'Cardie,': 4,
#  'Vincent': 2,
#  'Ng,': 2,
#  'Pierce,': 2,
#  'Chris': 7,
#  'Buckley': 3,
#  '....................................................': 1,
#  '180': 4,
#  'Extracting': 4,
#  'Molecular': 2,
#  'Binding': 2,
#  'Relationships': 3,
#  'Biomedical': 2,
#  'Thomas': 5,
#  'Rindflesch,': 1,
#  'Jayant': 2,
#  'V.': 11,
#  'Lawrence': 7,
#  'Hunter': 2,
#  '................................................': 1,
#  '188': 2,
#  'Compound': 2,
#  'Noun': 8,
#  'Segmentation': 5,
#  'Lexical': 12,
#  'Extracted': 2,
#  'Juntae': 1,
#  'Yoon': 2,
#  '196': 1,
#  'Corpus-Based': 3,
#  'LFG': 3,
#  'Specialization': 2,
#  'Nicola': 1,
#  'Cancedda,': 1,
#  'Christer': 3,
#  'Samuelsson': 2,
#  '...............................................................................': 1,
#  '204': 2,
#  'Tool': 5,
#  'Automated': 4,
#  'Revision': 2,
#  'Grammars': 6,
#  'Nanda': 2,
#  'Kambhatla,': 1,
#  'Wlodek': 3,
#  'Zadrozny': 3,
#  '210': 3,
#  'ANLPiv': 1,
#  'Aggressive': 3,
#  'Morphology': 5,
#  'Robust': 11,
#  'Coverage': 5,
#  'William': 11,
#  'A.': 34,
#  'Woods': 4,
#  '...............................................................................................................': 1,
#  '218': 3,
#  'TnT--A': 1,
#  'Part-of-Speech': 3,
#  'Tagger': 2,
#  'Thorsten': 3,
#  'Brants': 2,
#  '...................................................................................................................': 2,
#  '224': 2,
#  'Independent': 5,
#  'Morphological': 8,
#  'Analysis': 12,
#  'Tatsuo': 2,
#  'Yamashita,': 2,
#  'Yuji': 3,
#  'Matsumoto': 2,
#  '....................................................................................': 2,
#  '232': 2,
#  'Divide-and-Conquer': 2,
#  'Strategy': 4,
#  'Shallow': 4,
#  'Parsing': 9,
#  'German': 9,
#  'Free': 2,
#  'Texts': 3,
#  'Giinter': 2,
#  'Neumann,': 3,
#  'Christian': 2,
#  'Braun,': 1,
#  'Jakub': 3,
#  'Piskorski': 2,
#  '239': 2,
#  'Hybrid': 3,
#  'Approach': 14,
#  'Named': 10,
#  'Entity': 11,
#  'Sub-Type': 2,
#  'Tagging': 10,
#  'Cheng': 2,
#  'Niu,': 1,
#  '......................................................................................': 2,
#  '247': 2,
#  'Spelling': 5,
#  'Grammar': 8,
#  'Correction': 3,
#  'Danish': 3,
#  'SCARRIE': 2,
#  'Patrizia': 2,
#  'Paggio': 2,
#  '.....................................................................................................................': 2,
#  '255': 2,
#  'Can': 3,
#  'Improve': 3,
#  'Woods,': 3,
#  'Bookman,': 2,
#  'Houston,': 2,
#  'Kuhns,': 2,
#  'Martin,': 7,
#  'Stephen': 7,
#  'Green': 3,
#  '262': 2,
#  'Domain-Specific': 4,
#  'Acquisition': 4,
#  'Dan': 6,
#  'Moldovan,': 2,
#  'Roxana': 2,
#  'Girju,': 2,
#  'Vasile': 1,
#  'Rus': 2,
#  '..........................................................................': 1,
#  '268': 2,
#  'Controlled': 2,
#  'Vocabulary': 3,
#  'Indexing': 4,
#  'Entities': 2,
#  'Wasson': 2,
#  '.......................................................................................................................': 2,
#  '276': 2,
#  'Unsupervised': 3,
#  'Discovery': 3,
#  'Scenario-Level': 2,
#  'Patterns': 4,
#  'Yangarber,': 2,
#  'Grishman,': 3,
#  'Pasi': 2,
#  'Tapanainen,': 2,
#  'Silja': 1,
#  'Huttunen': 1,
#  '..............................': 1,
#  '282': 3,
#  'Corpus-Derived': 1,
#  'Name': 9,
#  'Lists': 3,
#  'Recognition': 9,
#  '...................................................................................': 1,
#  '290': 2,
#  'Answer': 6,
#  'Abney,': 4,
#  'Collins,': 4,
#  'Singhal': 1,
#  '....................................................................': 2,
#  '296': 3,
#  'Automatically': 4,
#  'Identified': 2,
#  'Index': 3,
#  'Terms': 3,
#  'Browsing': 3,
#  'Electronic': 5,
#  'Documents': 6,
#  'Nina': 3,
#  'Wacholder,': 3,
#  'Judith': 4,
#  'Klavans,': 3,
#  'K.': 22,
#  'Evans': 5,
#  '.........................................................': 2,
#  '302': 1,
#  'Reduction': 3,
#  'Summarization': 3,
#  'Hongyan': 3,
#  'Jing': 2,
#  '310': 3,
#  'Noisy': 2,
#  'Input:': 3,
#  'Speech': 16,
#  'OCR': 2,
#  'Miller,': 8,
#  'Sean': 1,
#  'Boisen,': 2,
#  'Schwartz,': 5,
#  'Rebecca': 4,
#  'Stone,': 4,
#  '...........': 2,
#  '316': 2,
#  'Improving': 6,
#  'Testsuites': 2,
#  'via': 16,
#  'Instrumentation': 2,
#  'Br6ker': 1,
#  '325': 2,
#  'Efficiency': 2,
#  'Multimodal': 2,
#  'Interaction': 3,
#  'Map-Based': 1,
#  'Task': 9,
#  'Philip': 8,
#  'Cohen,': 7,
#  'McGee,': 2,
#  'Josh': 2,
#  'Clow': 1,
#  '................................................................': 1,
#  '331': 3,
#  'ANLPv': 1,
#  'BusTUC': 1,
#  'natura': 1,
#  'l': 38,
#  'anguage': 21,
#  'bus': 3,
#  'route': 3,
#  'rac': 16,
#  'le': 17,
#  'Dept.': 3,
#  'computer': 10,
#  'information': 47,
#  'science': 2,
#  'University': 34,
#  'Trondheim': 1,
#  'N-7491': 1,
#  'amble@idi,': 1,
#  'ntnu.': 1,
#  'Abstract': 29,
#  'paper': 42,
#  'describes': 27,
#  'natural': 34,
#  'based': 45,
#  'expert': 6,
#  'system': 48,
#  'advisor': 1,
#  'public': 6,
#  'transport': 1,
#  'Trondheim,': 1,
#  'Norway.': 3,
#  'available': 25,
#  'Internet,and': 1,
#  'intstalled': 1,
#  'com-': 26,
#  "pany's": 1,
#  'web': 4,
#  'server': 6,
#  'since': 38,
#  'beginning': 12,
#  '1999.': 32,
#  'bilingual,': 1,
#  'relying': 7,
#  'internal': 12,
#  'independent': 19,
#  'logic': 4,
#  'representation.': 9,
#  'Introduct': 1,
#  'ion': 37,
#  'database': 18,
#  'provides': 26,
#  'users': 17,
#  'capability': 8,
#  'obtaining': 2,
#  'in-': 32,
#  'formation': 12,
#  'stored': 11,
#  'querying': 3,
#  'language': 44,
#  '(NL).': 1,
#  'With': 13,
#  'means': 23,
#  'communication': 6,
#  'puter': 3,
#  'system,': 30,
#  'make': 40,
#  'question': 20,
#  'statement': 1,
#  'way': 35,
#  'normally': 8,
#  'think': 6,
#  'discussed,': 1,
#  'freeing': 1,
#  'hav-': 2,
#  'ing': 35,
#  'know': 8,
#  'stores': 3,
#  'processes': 10,
#  'information.': 27,
#  'present': 32,
#  'implementation': 17,
#  'represents': 22,
#  'major': 21,
#  'effort': 15,
#  'bringing': 1,
#  'practical': 15,
#  'use.': 5,
#  'answer': 16,
#  'queries': 13,
#  'routes,': 1,
#  'stated': 5,
#  'texts,': 10,
#  'made': 31,
#  'Internet': 2,
#  'World': 3,
#  'Wide': 1,
#  'Web': 3,
#  'http': 8,
#  '//www.': 1,
#  'idi.': 1,
#  'no/bustuc/).': 1,
#  'small': 23,
#  'city': 7,
#  'university': 2,
#  '140000': 1,
#  'inhabitants.': 1,
#  'Its': 7,
#  'central': 9,
#  'systems': 38,
#  '42': 6,
#  'lines,': 2,
#  'serving': 2,
#  '590': 1,
#  'stations,': 1,
#  '1900': 1,
#  'depar-': 1,
#  'tures': 10,
#  'per': 21,
#  'day': 7,
#  '(in': 18,
#  'average).': 1,
#  'That': 11,
#  'gives': 16,
#  'approximately': 14,
#  '60000': 1,
#  'scheduled': 2,
#  'station': 2,
#  'passings': 1,
#  'day,': 1,
#  'somehow': 2,
#  'represented': 19,
#  'data': 33,
#  'base.': 4,
#  'starting': 14,
#  'point': 25,
#  'automate': 6,
#  'function': 18,
#  'agent.': 3,
#  'example': 36,
#  'response': 9,
#  'using': 47,
#  'actual': 18,
#  'request': 8,
#  'telephone': 5,
#  'local': 14,
#  'company:': 1,
#  'Hi,': 1,
#  'live': 4,
#  'Nidarvoll': 1,
#  'tonight': 1,
#  'must': 26,
#  'reach': 8,
#  'train': 9,
#  'Oslo': 1,
#  'oclock.': 1,
#  'typical': 19,
#  'follow': 14,
#  'quickly:': 1,
#  'number': 46,
#  '54': 5,
#  'passes': 3,
#  'skole': 1,
#  '1710': 1,
#  'arrives': 4,
#  'Railway': 1,
#  'Station': 1,
#  '1725.': 1,
#  'In': 49,
#  'pro-': 26,
#  'cess': 10,
#  'lexical': 28,
#  'analysis,': 11,
#  'syntax': 9,
#  'semantic': 32,
#  'pragmatic': 4,
#  'reasoning': 3,
#  'query': 13,
#  'processing.': 20,
#  'One': 26,
#  'could': 31,
#  'argue': 6,
#  'content': 11,
#  'solved': 3,
#  'interrogation,': 1,
#  'whereby': 3,
#  'customer': 4,
#  'asked': 14,
#  'produce': 22,
#  '4': 46,
#  'items:': 2,
#  'ta': 6,
#  'departure,': 2,
#  'arrival,': 1,
#  'earliest': 1,
#  'departure': 3,
#  'timeand/or': 1,
#  'latest': 6,
#  'arrival': 3,
#  'time.': 18,
#  'It': 45,
#  'myth': 1,
#  'better': 28,
#  '"natural': 1,
#  'language".': 1,
#  'challenge': 4,
#  'prove': 4,
#  'demonstration': 2,
#  'NL': 6,
#  'preferred': 5,
#  'interrogative': 3,
#  'mode.': 4,
#  'To': 38,
#  'that,': 11,
#  'correct,': 4,
#  'user': 26,
#  'friendly': 1,
#  'almost': 14,
#  'complete': 20,
#  'within': 26,
#  'domain.': 10,
#  'Previous': 5,
#  'Efforts,': 1,
#  'CHAT-80,': 1,
#  'PRAT-89': 1,
#  'HSQL': 1,
#  'called': 29,
#  'built': 21,
#  'upon': 11,
#  'clas-': 8,
#  'sical': 1,
#  'CHAT-80': 1,
#  '(Warren': 1,
#  'Pereira,': 3,
#  '1982).': 1,
#  'state': 24,
#  'art': 4,
#  'sys-': 28,
#  'tem': 22,
#  'impressive': 3,
#  'merits,': 1,
#  'also': 49,
#  'established': 6,
#  'Prolog': 4,
#  'viable': 4,
#  'competitive': 2,
#  'lan-': 11,
#  'guage': 15,
#  'Artificial': 15,
#  'Intelligence': 8,
#  'general.': 3,
#  'brilliant': 1,
#  'masterpiece': 1,
#  'software,': 1,
#  'efficient': 14,
#  'sophisticated.': 1,
#  'connected': 6,
#  'international': 2,
#  'geography.': 1,
#  'analysed': 3,
#  'answered': 7,
#  'split': 9,
#  'second:': 1,
#  'Which': 7,
#  'country': 6,
#  'bordering': 1,
#  'Mediterranean': 1,
#  'borders': 1,
#  'bordered': 1,
#  'whose': 22,
#  'population': 3,
#  'exceeds': 5,
#  ...}

# %%
i = inversedocumentfreq(d, v, df) #inverse document frequency for documents by using dictionary and vacabulary
i
# Out:
# {'Association': 1.2129937233341985,
#  'Computational': 0.543142325026529,
#  'Linguistics': 1.5025003405291832,
#  '6': 0.42449782852791007,
#  'th': 2.2129937233341983,
#  'Applied': 1.3504972470841332,
#  'Natural': 0.35049724708413316,
#  'Language': 0.2461605872693978,
#  'Processing': 1.0874628412503393,
#  'Conference': 0.21299372333419844,
#  'Proceedings': 0.11783649029385809,
#  'April': 4.672425341971495,
#  '29--May': 4.672425341971495,
#  '4,': 1.584962500721156,
#  '2000': 2.8650704199138914,
#  'Seattle,': 3.6724253419714956,
#  'Washington,': 1.765534746362977,
#  'USA': 2.350497247084133,
#  'ANLP': 3.6724253419714956,
#  '2000-PREFACE': 4.672425341971495,
#  '131': 4.087462841250339,
#  'papers': 4.672425341971495,
#  'submitted': 2.8650704199138914,
#  'ANLP-2000.': 5.672425341971495,
#  '46': 4.087462841250339,
#  'accepted': 2.5025003405291835,
#  'presentation': 3.0874628412503395,
#  'conference.': 4.087462841250339,
#  'Papers': 5.672425341971495,
#  'came': 3.350497247084133,
#  '24': 2.8650704199138914,
#  'countries:': 5.672425341971495,
#  'fifty': 4.087462841250339,
#  'eight': 2.350497247084133,
#  'United': 2.5025003405291835,
#  'States': 3.0874628412503395,
#  'America,': 5.672425341971495,
#  'eleven': 4.672425341971495,
#  'Germany': 3.6724253419714956,
#  'Kingdom,': 5.672425341971495,
#  'nine': 3.6724253419714956,
#  'Canada,': 2.350497247084133,
#  'Japan,': 4.672425341971495,
#  'four': 1.0285691521967708,
#  'Italy': 5.672425341971495,
#  'Spain,': 5.672425341971495,
#  'three': 0.35049724708413316,
#  'ach': 3.6724253419714956,
#  'France,': 4.087462841250339,
#  'Korea': 5.672425341971495,
#  'Switzerland,': 5.672425341971495,
#  'two': 0.02856915219677092,
#  'Australia,': 4.672425341971495,
#  'China,': 5.672425341971495,
#  'The': 0.02856915219677092,
#  'Netherlands': 5.672425341971495,
#  'Sweden': 5.672425341971495,
#  'one': 0.057715497856287434,
#  'Czech': 4.087462841250339,
#  'Republic,': 4.672425341971495,
#  'Denmark,': 4.087462841250339,
#  'Finland,': 4.672425341971495,
#  'Greece,': 5.672425341971495,
#  'India,': 5.672425341971495,
#  'Hong': 4.087462841250339,
#  'Kong,': 5.672425341971495,
#  'Malaysia,': 4.672425341971495,
#  'Norway,': 4.672425341971495,
#  'Russia': 5.672425341971495,
#  'Taiwan.': 5.672425341971495,
#  '40': 2.5025003405291835,
#  'industry.': 4.672425341971495,
#  '85': 3.0874628412503395,
#  'academia.': 5.672425341971495,
#  '2': 0.057715497856287434,
#  'government': 3.0874628412503395,
#  'organizations': 4.087462841250339,
#  'submissions': 4.672425341971495,
#  'combined.': 4.087462841250339,
#  'reviewing': 5.672425341971495,
#  'process': 0.7182290315846205,
#  'supported': 1.5025003405291832,
#  'web-based': 4.672425341971495,
#  'reviewer': 5.672425341971495,
#  'interface': 2.2129937233341983,
#  'developed': 0.6724253419714956,
#  'Elisha': 5.672425341971495,
#  'Kane': 4.672425341971495,
#  'New': 0.8650704199138914,
#  'Mexico': 4.087462841250339,
#  'State': 2.0874628412503395,
#  "University's": 5.672425341971495,
#  'Computing': 2.2129937233341983,
#  'Research': 0.765534746362977,
#  'Lab.': 5.672425341971495,
#  'Linda': 4.672425341971495,
#  'Fresques': 4.672425341971495,
#  'CRL': 5.672425341971495,
#  'coordinated': 5.672425341971495,
#  'refereeing': 5.672425341971495,
#  'process.': 1.6724253419714956,
#  'I': 0.2461605872693978,
#  'would': 0.0874628412503394,
#  'like': 0.38702312310924725,
#  'express': 2.350497247084133,
#  'gratitude': 4.672425341971495,
#  'appreciation': 5.672425341971495,
#  'fthe': 5.672425341971495,
#  'Program': 2.8650704199138914,
#  'Committee': 4.087462841250339,
#  'members': 3.6724253419714956,
#  'responsible': 2.5025003405291835,
#  'six': 2.6724253419714956,
#  'areas:': 5.672425341971495,
#  'Lynn': 4.087462841250339,
#  'Carlson,': 4.672425341971495,
#  'Tools': 3.6724253419714956,
#  'Resources': 3.0874628412503395,
#  'Developing': 3.6724253419714956,
#  'NLP': 1.5025003405291832,
#  'Systems': 1.6724253419714956,
#  'Subcommittee': 5.672425341971495,
#  'Eduard': 5.672425341971495,
#  'Hovy,': 4.672425341971495,
#  'Integrated': 3.6724253419714956,
#  'Richard': 2.350497247084133,
#  'Kittredge,': 4.672425341971495,
#  'Multilingual': 2.8650704199138914,
#  'Text': 1.0285691521967708,
#  'Ray': 4.672425341971495,
#  'Perrault,': 5.672425341971495,
#  'Spoken': 2.350497247084133,
#  'Oliviero': 5.672425341971495,
#  'Stock,': 4.672425341971495,
#  'Monolingual': 5.672425341971495,
#  'John': 1.6724253419714956,
#  'White,': 4.087462841250339,
#  'Evaluation': 1.584962500721156,
#  'following': 0.2801079191927352,
#  'colleagues': 3.0874628412503395,
#  'Doug': 3.6724253419714956,
#  'Appelt': 3.6724253419714956,
#  'Fabio': 4.672425341971495,
#  'Ciravegna': 5.672425341971495,
#  'Robert': 2.8650704199138914,
#  'Dale': 5.672425341971495,
#  'Michael': 2.5025003405291835,
#  'Elhadad': 5.672425341971495,
#  'Ralph': 3.0874628412503395,
#  'G-rishman': 5.672425341971495,
#  'Lynette': 4.087462841250339,
#  'Hirschman': 4.672425341971495,
#  'Yuval': 4.672425341971495,
#  'Krymolowski': 5.672425341971495,
#  'Inderjeet': 4.087462841250339,
#  'Mani': 5.672425341971495,
#  'Zvi': 4.672425341971495,
#  'Marx': 5.672425341971495,
#  'Martha': 4.672425341971495,
#  'Palmer': 3.350497247084133,
#  'Harold': 5.672425341971495,
#  'Somers': 5.672425341971495,
#  'Toshiyuki': 4.087462841250339,
#  'Takezawa': 4.672425341971495,
#  'Takehito': 4.672425341971495,
#  'Utsuro': 5.672425341971495,
#  'Dekai': 4.087462841250339,
#  'Wu': 3.6724253419714956,
#  'bulk': 5.672425341971495,
#  'reviewing:': 5.672425341971495,
#  'Igor': 5.672425341971495,
#  'Boguslavsky': 5.672425341971495,
#  'Jim': 4.087462841250339,
#  'Cowie': 5.672425341971495,
#  'Dowding': 5.672425341971495,
#  'Glass': 4.672425341971495,
#  'Jan': 3.350497247084133,
#  'Haji~': 4.087462841250339,
#  'Pierre': 4.087462841250339,
#  'IsabeIIe': 5.672425341971495,
#  'Alberto': 4.672425341971495,
#  'Lavelli': 5.672425341971495,
#  'Daniel': 3.6724253419714956,
#  'Marcu': 4.672425341971495,
#  'David': 1.2129937233341985,
#  'McDonald': 4.087462841250339,
#  'Owen': 4.087462841250339,
#  'Rainbow': 5.672425341971495,
#  'Tomek': 4.672425341971495,
#  'Strzalkowski': 4.672425341971495,
#  'Kathryn': 5.672425341971495,
#  'B.': 1.42449782852791,
#  'Taylor': 4.672425341971495,
#  'Pick': 4.087462841250339,
#  'Vossen': 5.672425341971495,
#  'R6mi': 5.672425341971495,
#  'Zajac': 5.672425341971495,
#  'Carter': 4.672425341971495,
#  'Ido': 3.6724253419714956,
#  'Dagan': 4.087462841250339,
#  'Andreas': 4.672425341971495,
#  'Eiscle': 5.672425341971495,
#  'Oren': 4.672425341971495,
#  'Glikman': 5.672425341971495,
#  'Donna': 4.672425341971495,
#  'Harman': 4.087462841250339,
#  'Tanya': 4.672425341971495,
#  'Korelsky': 4.672425341971495,
#  'Chin-Yew': 5.672425341971495,
#  'Lin': 4.672425341971495,
#  'Paul': 2.8650704199138914,
#  'Martin': 3.0874628412503395,
#  'Teruko': 4.672425341971495,
#  'Mitamura': 4.672425341971495,
#  'Norbert': 5.672425341971495,
#  'Reithinger': 5.672425341971495,
#  'Beth': 4.087462841250339,
#  'Sundheim': 5.672425341971495,
#  'Hans': 3.6724253419714956,
#  'Uszkoreit': 4.672425341971495,
#  'Weischedel': 3.6724253419714956,
#  'We': 0.02856915219677092,
#  'believe': 1.8650704199138914,
#  'quality': 1.5025003405291832,
#  'elected': 3.6724253419714956,
#  'israther': 5.672425341971495,
#  'high': 0.7182290315846205,
#  'hope': 3.350497247084133,
#  'conference': 3.6724253419714956,
#  'success.': 5.672425341971495,
#  'Sergei': 5.672425341971495,
#  'Nirenburg': 5.672425341971495,
#  'Chair,': 5.672425341971495,
#  'ANLP-2000': 5.672425341971495,
#  'ANLPi': 5.672425341971495,
#  'Table': 0.8650704199138914,
#  'Contents': 4.672425341971495,
#  'Section': 0.9719856238304033,
#  '1:': 0.5025003405291834,
#  '(ANLP)': 5.672425341971495,
#  'Preface': 4.672425341971495,
#  'List': 3.0874628412503395,
#  'Reviewers': 4.672425341971495,
#  'Nirenburg,': 5.672425341971495,
#  'Chair': 4.672425341971495,
#  '...............................................................': 5.672425341971495,
#  'BusTUC--A': 5.672425341971495,
#  'Bus': 4.672425341971495,
#  'Route': 5.672425341971495,
#  'Oracle': 5.672425341971495,
#  'Tore': 4.672425341971495,
#  'Amble': 4.672425341971495,
#  '..............................................................................................................................': 5.672425341971495,
#  '1': 0.0874628412503394,
#  'Machine': 1.765534746362977,
#  'Translation': 2.0874628412503395,
#  'Very': 2.2129937233341983,
#  'Close': 3.6724253419714956,
#  'Languages': 3.6724253419714956,
#  'Haji~,': 4.087462841250339,
#  'Hric,': 5.672425341971495,
#  'Vladislav': 3.6724253419714956,
#  'Kubofi': 4.672425341971495,
#  '.......................................................................................': 4.672425341971495,
#  '7': 0.9719856238304033,
#  'Cross-Language': 4.672425341971495,
#  'Multimedia': 4.087462841250339,
#  'Information': 0.6280312226130421,
#  'Retrieval': 1.8650704199138914,
#  'Sharon': 3.6724253419714956,
#  'Flank': 4.672425341971495,
#  '..........................................................................................................................': 5.672425341971495,
#  '13': 2.5025003405291835,
#  'Automatic': 1.5025003405291832,
#  'Construction': 4.672425341971495,
#  'Parallel': 4.087462841250339,
#  'English-Chinese': 4.672425341971495,
#  'Corpus': 1.765534746362977,
#  'Jiang': 5.672425341971495,
#  'Chen,': 3.350497247084133,
#  'Jian-Yun': 5.672425341971495,
#  'Nie': 5.672425341971495,
#  '......................................................................................................': 5.672425341971495,
#  '21': 2.5025003405291835,
#  'PartslD:': 4.672425341971495,
#  'A': 0.02856915219677092,
#  'Dialogue-Based': 4.087462841250339,
#  'System': 1.0285691521967708,
#  'Identifying': 2.5025003405291835,
#  'Parts': 4.087462841250339,
#  'Medical': 3.6724253419714956,
#  'Amit': 4.087462841250339,
#  'Bagga,': 4.672425341971495,
#  'Strzalkowski,': 4.087462841250339,
#  'G.': 1.2801079191927351,
#  'Bowden': 4.672425341971495,
#  'Wise': 5.672425341971495,
#  '...........................................................': 5.672425341971495,
#  '29': 2.8650704199138914,
#  'Using': 0.7182290315846205,
#  'Dialogue': 2.350497247084133,
#  'Participants': 4.087462841250339,
#  'Setsuo': 4.672425341971495,
#  'Yamada,': 4.672425341971495,
#  'Eiichiro': 4.672425341971495,
#  'Sumita,': 4.672425341971495,
#  'Hideki': 4.672425341971495,
#  'Kashioka': 4.672425341971495,
#  '..............................................................': 5.672425341971495,
#  '37': 2.6724253419714956,
#  'Distilling': 4.672425341971495,
#  'Dialogues--A': 5.672425341971495,
#  'Method': 2.8650704199138914,
#  'Corpora': 3.6724253419714956,
#  'Development': 2.350497247084133,
#  'Arne': 4.087462841250339,
#  'J6nsson,': 5.672425341971495,
#  'Nils': 4.672425341971495,
#  'Dahlb~ick': 4.672425341971495,
#  '.................................................................................................': 4.672425341971495,
#  '44': 3.0874628412503395,
#  'Plan-Based': 4.672425341971495,
#  'Management': 3.350497247084133,
#  'ina': 4.672425341971495,
#  'Physics': 4.672425341971495,
#  'Tour': 5.672425341971495,
#  'Reva': 4.672425341971495,
#  'Freedman': 4.672425341971495,
#  '......................................................................................................................': 5.672425341971495,
#  '52': 3.6724253419714956,
#  'Framework': 3.0874628412503395,
#  'MT': 3.0874628412503395,
#  'NLG': 4.087462841250339,
#  'Based': 1.584962500721156,
#  'Uniform': 4.672425341971495,
#  'Lexico-Structural': 4.672425341971495,
#  'Benoit': 4.672425341971495,
#  'Lavoie,': 4.672425341971495,
#  'Korelsky,': 4.672425341971495,
#  'Rambow': 4.672425341971495,
#  '...................................': 5.672425341971495,
#  '60': 1.9719856238304034,
#  "Talk'N'Travel:": 5.672425341971495,
#  'Conversational': 3.6724253419714956,
#  'Air': 3.6724253419714956,
#  'Travel': 4.672425341971495,
#  'Planning': 3.6724253419714956,
#  'Stallard': 4.672425341971495,
#  '........................................................................................................................': 5.672425341971495,
#  '68': 3.350497247084133,
#  'REES:': 4.672425341971495,
#  'Large-Scale': 4.672425341971495,
#  'Relation': 4.087462841250339,
#  'Event': 3.0874628412503395,
#  'Extraction': 2.0874628412503395,
#  'Chinatsu': 4.087462841250339,
#  'Aone,': 3.6724253419714956,
#  'Mila': 4.672425341971495,
#  'Ramos-Santacruz': 4.672425341971495,
#  '.................................................................................': 5.672425341971495,
#  '76': 3.350497247084133,
#  'Experiments': 2.0874628412503395,
#  'Sentence': 2.5025003405291835,
#  'Boundary': 4.672425341971495,
#  'Detection': 3.0874628412503395,
#  'Mark': 2.350497247084133,
#  'Stevenson,': 4.087462841250339,
#  'Gaizauskas': 5.672425341971495,
#  '.....................................................................................': 5.672425341971495,
#  '84': 3.6724253419714956,
#  'DP:': 4.672425341971495,
#  'Detector': 4.672425341971495,
#  'Presuppositions': 4.672425341971495,
#  'Survey': 3.6724253419714956,
#  'Questions': 4.087462841250339,
#  'Katja': 4.672425341971495,
#  'Wiemer-Hastings,': 4.672425341971495,
#  'Peter': 2.350497247084133,
#  'Sonya': 4.672425341971495,
#  'Rajan,': 5.672425341971495,
#  'Art': 3.350497247084133,
#  'Graesser,': 4.672425341971495,
#  'Roger': 3.350497247084133,
#  'Kreuz,': 4.672425341971495,
#  'Ashish': 4.672425341971495,
#  'Karnavat': 5.672425341971495,
#  '..............................................................................................': 4.672425341971495,
#  '90': 2.6724253419714956,
#  'ANLPiii': 5.672425341971495,
#  'MIMIC:': 4.672425341971495,
#  'An': 0.42449782852791007,
#  'Adaptive': 3.6724253419714956,
#  'Mixed': 3.6724253419714956,
#  'Initiative': 4.087462841250339,
#  'Queries': 3.350497247084133,
#  'Jennifer': 4.087462841250339,
#  'Chu-Carroll': 4.087462841250339,
#  '..............................................................................................................': 5.672425341971495,
#  '97': 2.8650704199138914,
#  'Javox:': 5.672425341971495,
#  'Toolkit': 4.672425341971495,
#  'Building': 2.5025003405291835,
#  'Speech-Enabled': 4.672425341971495,
#  'Applications': 3.0874628412503395,
#  'S.': 0.8650704199138914,
#  'Fulkerson,': 4.672425341971495,
#  'Alan': 3.350497247084133,
#  'W.': 1.0874628412503393,
#  'Biermann': 5.672425341971495,
#  '...........................................................................': 5.672425341971495,
#  '105': 4.672425341971495,
#  'Compact': 4.672425341971495,
#  'Architecture': 2.350497247084133,
#  'Scripts': 4.672425341971495,
#  'Meta-Outputs': 4.672425341971495,
#  'Manny': 3.6724253419714956,
#  'Rayner,': 4.087462841250339,
#  'Ann': 3.0874628412503395,
#  'Hockey,': 4.672425341971495,
#  'Frankie': 5.672425341971495,
#  'James': 3.350497247084133,
#  '112': 4.087462841250339,
#  'Representation': 2.8650704199138914,
#  'Complex': 4.087462841250339,
#  'Evolving': 4.672425341971495,
#  'Data': 1.8650704199138914,
#  'Dependencies': 4.087462841250339,
#  'Generation': 2.6724253419714956,
#  'C.': 1.0874628412503393,
#  'Mellish,': 4.672425341971495,
#  'R.': 0.6724253419714956,
#  'Evans,': 4.087462841250339,
#  'L.': 1.1488633859144828,
#  'Cahill,': 4.672425341971495,
#  'Doran,': 4.087462841250339,
#  'D.': 1.0285691521967708,
#  'Paiva,': 4.672425341971495,
#  'M.': 0.9175378398080271,
#  'Reape,': 4.672425341971495,
#  'Scott,': 3.6724253419714956,
#  'N.': 1.6724253419714956,
#  'Tipper': 5.672425341971495,
#  '.............................................................................': 5.672425341971495,
#  '119': 4.672425341971495,
#  'Reviser:': 4.672425341971495,
#  'TransCheck': 4.672425341971495,
#  'Jean-Marc': 4.672425341971495,
#  'Jutras': 4.672425341971495,
#  '..................................................................................................................': 4.672425341971495,
#  '127': 4.087462841250339,
#  'Unit': 3.6724253419714956,
#  'Completion': 4.672425341971495,
#  'Computer-Aided': 5.672425341971495,
#  'Typing': 4.672425341971495,
#  'Philippe': 5.672425341971495,
#  'Langlais,': 4.672425341971495,
#  'George': 2.8650704199138914,
#  'Foster,': 4.087462841250339,
#  'Guy': 4.087462841250339,
#  'Lapalme': 4.672425341971495,
#  '.................................................................': 5.672425341971495,
#  '135': 4.087462841250339,
#  'Coreference': 4.087462841250339,
#  'Resolution': 3.6724253419714956,
#  'Sanda': 4.087462841250339,
#  'Harabagiu,': 4.672425341971495,
#  'Steven': 2.8650704199138914,
#  'J.': 0.3148733373534119,
#  'Maiorano': 5.672425341971495,
#  '142': 4.672425341971495,
#  'Ranking': 3.350497247084133,
#  'Suspected': 5.672425341971495,
#  'Answers': 4.672425341971495,
#  'Predictive': 3.6724253419714956,
#  'Annotation': 3.6724253419714956,
#  'Dragomir': 4.087462841250339,
#  'Radev,': 3.6724253419714956,
#  'Prager,': 4.087462841250339,
#  'Valerie': 4.672425341971495,
#  'Samn': 5.672425341971495,
#  '150': 3.6724253419714956,
#  'Message': 2.2129937233341983,
#  'Classification': 3.350497247084133,
#  'Call': 4.087462841250339,
#  'Center': 2.350497247084133,
#  'Stephan': 4.087462841250339,
#  'Busemann,': 4.672425341971495,
#  'Sven': 4.672425341971495,
#  'Schmeier,': 4.672425341971495,
#  'Roman': 3.0874628412503395,
#  'Arens': 4.672425341971495,
#  '.......................................................': 5.672425341971495,
#  '158': 4.672425341971495,
#  'Question': 2.8650704199138914,
#  'Answering': 3.350497247084133,
#  'Supported': 4.087462841250339,
#  'Rohini': 4.087462841250339,
#  'Srihari,': 3.6724253419714956,
#  'Wei': 4.087462841250339,
#  'Li': 3.350497247084133,
#  '........................................................................................................': 4.672425341971495,
#  '166': 2.8650704199138914,
#  'Categorizing': 4.672425341971495,
#  'Unknown': 3.6724253419714956,
#  'Words:': 4.672425341971495,
#  'Decision': 3.6724253419714956,
#  'Trees': 4.672425341971495,
#  'Identify': 3.350497247084133,
#  'Names': 3.6724253419714956,
#  'Misspellings': 4.672425341971495,
#  'Janine': 5.672425341971495,
#  'Toole': 4.672425341971495,
#  '.........................................................................................................................': 4.672425341971495,
#  '173': 4.672425341971495,
#  'Examining': 4.087462841250339,
#  'Role': 3.0874628412503395,
#  'Statistical': 1.8650704199138914,
#  'Linguistic': 2.2129937233341983,
#  'Knowledge': 2.350497247084133,
#  'Sources': 4.672425341971495,
#  'General-Knowledge': 4.672425341971495,
#  'Question-Answering': 4.672425341971495,
#  'Claire': 4.087462841250339,
#  'Cardie,': 3.6724253419714956,
#  'Vincent': 4.672425341971495,
#  'Ng,': 4.672425341971495,
#  'Pierce,': 4.672425341971495,
#  'Chris': 2.8650704199138914,
#  'Buckley': 4.087462841250339,
#  '....................................................': 5.672425341971495,
#  '180': 3.6724253419714956,
#  'Extracting': 3.6724253419714956,
#  'Molecular': 4.672425341971495,
#  'Binding': 4.672425341971495,
#  'Relationships': 4.087462841250339,
#  'Biomedical': 4.672425341971495,
#  'Thomas': 3.350497247084133,
#  'Rindflesch,': 5.672425341971495,
#  'Jayant': 4.672425341971495,
#  'V.': 2.2129937233341983,
#  'Lawrence': 2.8650704199138914,
#  'Hunter': 4.672425341971495,
#  '................................................': 5.672425341971495,
#  '188': 4.672425341971495,
#  'Compound': 4.672425341971495,
#  'Noun': 2.6724253419714956,
#  'Segmentation': 3.350497247084133,
#  'Lexical': 2.0874628412503395,
#  'Extracted': 4.672425341971495,
#  'Juntae': 5.672425341971495,
#  'Yoon': 4.672425341971495,
#  '196': 5.672425341971495,
#  'Corpus-Based': 4.087462841250339,
#  'LFG': 4.087462841250339,
#  'Specialization': 4.672425341971495,
#  'Nicola': 5.672425341971495,
#  'Cancedda,': 5.672425341971495,
#  'Christer': 4.087462841250339,
#  'Samuelsson': 4.672425341971495,
#  '...............................................................................': 5.672425341971495,
#  '204': 4.672425341971495,
#  'Tool': 3.350497247084133,
#  'Automated': 3.6724253419714956,
#  'Revision': 4.672425341971495,
#  'Grammars': 3.0874628412503395,
#  'Nanda': 4.672425341971495,
#  'Kambhatla,': 5.672425341971495,
#  'Wlodek': 4.087462841250339,
#  'Zadrozny': 4.087462841250339,
#  '210': 4.087462841250339,
#  'ANLPiv': 5.672425341971495,
#  'Aggressive': 4.087462841250339,
#  'Morphology': 3.350497247084133,
#  'Robust': 2.2129937233341983,
#  'Coverage': 3.350497247084133,
#  'William': 2.2129937233341983,
#  'A.': 0.5849625007211562,
#  'Woods': 3.6724253419714956,
#  '...............................................................................................................': 5.672425341971495,
#  '218': 4.087462841250339,
#  'TnT--A': 5.672425341971495,
#  'Part-of-Speech': 4.087462841250339,
#  'Tagger': 4.672425341971495,
#  'Thorsten': 4.087462841250339,
#  'Brants': 4.672425341971495,
#  '...................................................................................................................': 4.672425341971495,
#  '224': 4.672425341971495,
#  'Independent': 3.350497247084133,
#  'Morphological': 2.6724253419714956,
#  'Analysis': 2.0874628412503395,
#  'Tatsuo': 4.672425341971495,
#  'Yamashita,': 4.672425341971495,
#  'Yuji': 4.087462841250339,
#  'Matsumoto': 4.672425341971495,
#  '....................................................................................': 4.672425341971495,
#  '232': 4.672425341971495,
#  'Divide-and-Conquer': 4.672425341971495,
#  'Strategy': 3.6724253419714956,
#  'Shallow': 3.6724253419714956,
#  'Parsing': 2.5025003405291835,
#  'German': 2.5025003405291835,
#  'Free': 4.672425341971495,
#  'Texts': 4.087462841250339,
#  'Giinter': 4.672425341971495,
#  'Neumann,': 4.087462841250339,
#  'Christian': 4.672425341971495,
#  'Braun,': 5.672425341971495,
#  'Jakub': 4.087462841250339,
#  'Piskorski': 4.672425341971495,
#  '239': 4.672425341971495,
#  'Hybrid': 4.087462841250339,
#  'Approach': 1.8650704199138914,
#  'Named': 2.350497247084133,
#  'Entity': 2.2129937233341983,
#  'Sub-Type': 4.672425341971495,
#  'Tagging': 2.350497247084133,
#  'Cheng': 4.672425341971495,
#  'Niu,': 5.672425341971495,
#  '......................................................................................': 4.672425341971495,
#  '247': 4.672425341971495,
#  'Spelling': 3.350497247084133,
#  'Grammar': 2.6724253419714956,
#  'Correction': 4.087462841250339,
#  'Danish': 4.087462841250339,
#  'SCARRIE': 4.672425341971495,
#  'Patrizia': 4.672425341971495,
#  'Paggio': 4.672425341971495,
#  '.....................................................................................................................': 4.672425341971495,
#  '255': 4.672425341971495,
#  'Can': 4.087462841250339,
#  'Improve': 4.087462841250339,
#  'Woods,': 4.087462841250339,
#  'Bookman,': 4.672425341971495,
#  'Houston,': 4.672425341971495,
#  'Kuhns,': 4.672425341971495,
#  'Martin,': 2.8650704199138914,
#  'Stephen': 2.8650704199138914,
#  'Green': 4.087462841250339,
#  '262': 4.672425341971495,
#  'Domain-Specific': 3.6724253419714956,
#  'Acquisition': 3.6724253419714956,
#  'Dan': 3.0874628412503395,
#  'Moldovan,': 4.672425341971495,
#  'Roxana': 4.672425341971495,
#  'Girju,': 4.672425341971495,
#  'Vasile': 5.672425341971495,
#  'Rus': 4.672425341971495,
#  '..........................................................................': 5.672425341971495,
#  '268': 4.672425341971495,
#  'Controlled': 4.672425341971495,
#  'Vocabulary': 4.087462841250339,
#  'Indexing': 3.6724253419714956,
#  'Entities': 4.672425341971495,
#  'Wasson': 4.672425341971495,
#  '.......................................................................................................................': 4.672425341971495,
#  '276': 4.672425341971495,
#  'Unsupervised': 4.087462841250339,
#  'Discovery': 4.087462841250339,
#  'Scenario-Level': 4.672425341971495,
#  'Patterns': 3.6724253419714956,
#  'Yangarber,': 4.672425341971495,
#  'Grishman,': 4.087462841250339,
#  'Pasi': 4.672425341971495,
#  'Tapanainen,': 4.672425341971495,
#  'Silja': 5.672425341971495,
#  'Huttunen': 5.672425341971495,
#  '..............................': 5.672425341971495,
#  '282': 4.087462841250339,
#  'Corpus-Derived': 5.672425341971495,
#  'Name': 2.5025003405291835,
#  'Lists': 4.087462841250339,
#  'Recognition': 2.5025003405291835,
#  '...................................................................................': 5.672425341971495,
#  '290': 4.672425341971495,
#  'Answer': 3.0874628412503395,
#  'Abney,': 3.6724253419714956,
#  'Collins,': 3.6724253419714956,
#  'Singhal': 5.672425341971495,
#  '....................................................................': 4.672425341971495,
#  '296': 4.087462841250339,
#  'Automatically': 3.6724253419714956,
#  'Identified': 4.672425341971495,
#  'Index': 4.087462841250339,
#  'Terms': 4.087462841250339,
#  'Browsing': 4.087462841250339,
#  'Electronic': 3.350497247084133,
#  'Documents': 3.0874628412503395,
#  'Nina': 4.087462841250339,
#  'Wacholder,': 4.087462841250339,
#  'Judith': 3.6724253419714956,
#  'Klavans,': 4.087462841250339,
#  'K.': 1.2129937233341985,
#  'Evans': 3.350497247084133,
#  '.........................................................': 4.672425341971495,
#  '302': 5.672425341971495,
#  'Reduction': 4.087462841250339,
#  'Summarization': 4.087462841250339,
#  'Hongyan': 4.087462841250339,
#  'Jing': 4.672425341971495,
#  '310': 4.087462841250339,
#  'Noisy': 4.672425341971495,
#  'Input:': 4.087462841250339,
#  'Speech': 1.6724253419714956,
#  'OCR': 4.672425341971495,
#  'Miller,': 2.6724253419714956,
#  'Sean': 5.672425341971495,
#  'Boisen,': 4.672425341971495,
#  'Schwartz,': 3.350497247084133,
#  'Rebecca': 3.6724253419714956,
#  'Stone,': 3.6724253419714956,
#  '...........': 4.672425341971495,
#  '316': 4.672425341971495,
#  'Improving': 3.0874628412503395,
#  'Testsuites': 4.672425341971495,
#  'via': 1.6724253419714956,
#  'Instrumentation': 4.672425341971495,
#  'Br6ker': 5.672425341971495,
#  '325': 4.672425341971495,
#  'Efficiency': 4.672425341971495,
#  'Multimodal': 4.672425341971495,
#  'Interaction': 4.087462841250339,
#  'Map-Based': 5.672425341971495,
#  'Task': 2.5025003405291835,
#  'Philip': 2.6724253419714956,
#  'Cohen,': 2.8650704199138914,
#  'McGee,': 4.672425341971495,
#  'Josh': 4.672425341971495,
#  'Clow': 5.672425341971495,
#  '................................................................': 5.672425341971495,
#  '331': 4.087462841250339,
#  'ANLPv': 5.672425341971495,
#  'BusTUC': 5.672425341971495,
#  'natura': 5.672425341971495,
#  'l': 0.42449782852791007,
#  'anguage': 1.2801079191927351,
#  'bus': 4.087462841250339,
#  'route': 4.087462841250339,
#  'rac': 1.6724253419714956,
#  'le': 1.584962500721156,
#  'Dept.': 4.087462841250339,
#  'computer': 2.350497247084133,
#  'information': 0.11783649029385809,
#  'science': 4.672425341971495,
#  'University': 0.5849625007211562,
#  'Trondheim': 5.672425341971495,
#  'N-7491': 5.672425341971495,
#  'amble@idi,': 5.672425341971495,
#  'ntnu.': 5.672425341971495,
#  'Abstract': 0.8144443468439234,
#  'paper': 0.2801079191927352,
#  'describes': 0.9175378398080271,
#  'natural': 0.5849625007211562,
#  'based': 0.18057224564182084,
#  'expert': 3.0874628412503395,
#  'system': 0.0874628412503394,
#  'advisor': 5.672425341971495,
#  'public': 3.0874628412503395,
#  'transport': 5.672425341971495,
#  'Trondheim,': 5.672425341971495,
#  'Norway.': 4.087462841250339,
#  'available': 1.0285691521967708,
#  'Internet,and': 5.672425341971495,
#  'intstalled': 5.672425341971495,
#  'com-': 0.9719856238304033,
#  "pany's": 5.672425341971495,
#  'web': 3.6724253419714956,
#  'server': 3.0874628412503395,
#  'since': 0.42449782852791007,
#  'beginning': 2.0874628412503395,
#  '1999.': 0.6724253419714956,
#  'bilingual,': 5.672425341971495,
#  'relying': 2.8650704199138914,
#  'internal': 2.0874628412503395,
#  'independent': 1.42449782852791,
#  'logic': 3.6724253419714956,
#  'representation.': 2.5025003405291835,
#  'Introduct': 5.672425341971495,
#  'ion': 0.4629719763425457,
#  'database': 1.5025003405291832,
#  'provides': 0.9719856238304033,
#  'users': 1.584962500721156,
#  'capability': 2.6724253419714956,
#  'obtaining': 4.672425341971495,
#  'in-': 0.6724253419714956,
#  'formation': 2.0874628412503395,
#  'stored': 2.2129937233341983,
#  'querying': 4.087462841250339,
#  'language': 0.21299372333419844,
#  '(NL).': 5.672425341971495,
#  'With': 1.9719856238304034,
#  'means': 1.1488633859144828,
#  'communication': 3.0874628412503395,
#  'puter': 4.087462841250339,
#  'system,': 0.765534746362977,
#  'make': 0.35049724708413316,
#  'question': 1.3504972470841332,
#  'statement': 5.672425341971495,
#  'way': 0.543142325026529,
#  'normally': 2.6724253419714956,
#  'think': 3.0874628412503395,
#  'discussed,': 5.672425341971495,
#  'freeing': 5.672425341971495,
#  'hav-': 4.672425341971495,
#  'ing': 0.543142325026529,
#  'know': 2.6724253419714956,
#  'stores': 4.087462841250339,
#  'processes': 2.350497247084133,
#  'information.': 0.9175378398080271,
#  'present': 0.6724253419714956,
#  'implementation': 1.584962500721156,
#  'represents': 1.2129937233341985,
#  'major': 1.2801079191927351,
#  'effort': 1.765534746362977,
#  'bringing': 5.672425341971495,
#  'practical': 1.765534746362977,
#  'use.': 3.350497247084133,
#  'answer': 1.6724253419714956,
#  'queries': 1.9719856238304034,
#  'routes,': 5.672425341971495,
#  'stated': 3.350497247084133,
#  'texts,': 2.350497247084133,
#  'made': 0.7182290315846205,
#  'Internet': 4.672425341971495,
#  'World': 4.087462841250339,
#  'Wide': 5.672425341971495,
#  'Web': 4.087462841250339,
#  'http': 2.6724253419714956,
#  '//www.': 5.672425341971495,
#  'idi.': 5.672425341971495,
#  'no/bustuc/).': 5.672425341971495,
#  'small': 1.1488633859144828,
#  'city': 2.8650704199138914,
#  'university': 4.672425341971495,
#  '140000': 5.672425341971495,
#  'inhabitants.': 5.672425341971495,
#  'Its': 2.8650704199138914,
#  'central': 2.5025003405291835,
#  'systems': 0.42449782852791007,
#  '42': 3.0874628412503395,
#  'lines,': 4.672425341971495,
#  'serving': 4.672425341971495,
#  '590': 5.672425341971495,
#  'stations,': 5.672425341971495,
#  '1900': 5.672425341971495,
#  'depar-': 5.672425341971495,
#  'tures': 2.350497247084133,
#  'per': 1.2801079191927351,
#  'day': 2.8650704199138914,
#  '(in': 1.5025003405291832,
#  'average).': 5.672425341971495,
#  'That': 2.2129937233341983,
#  'gives': 1.6724253419714956,
#  'approximately': 1.8650704199138914,
#  '60000': 5.672425341971495,
#  'scheduled': 4.672425341971495,
#  'station': 4.672425341971495,
#  'passings': 5.672425341971495,
#  'day,': 5.672425341971495,
#  'somehow': 4.672425341971495,
#  'represented': 1.42449782852791,
#  'data': 0.6280312226130421,
#  'base.': 3.6724253419714956,
#  'starting': 1.8650704199138914,
#  'point': 1.0285691521967708,
#  'automate': 3.0874628412503395,
#  'function': 1.5025003405291832,
#  'agent.': 4.087462841250339,
#  'example': 0.5025003405291834,
#  'response': 2.5025003405291835,
#  'using': 0.11783649029385809,
#  'actual': 1.5025003405291832,
#  'request': 2.6724253419714956,
#  'telephone': 3.350497247084133,
#  'local': 1.8650704199138914,
#  'company:': 5.672425341971495,
#  'Hi,': 5.672425341971495,
#  'live': 3.6724253419714956,
#  'Nidarvoll': 5.672425341971495,
#  'tonight': 5.672425341971495,
#  'must': 0.9719856238304033,
#  'reach': 2.6724253419714956,
#  'train': 2.5025003405291835,
#  'Oslo': 5.672425341971495,
#  'oclock.': 5.672425341971495,
#  'typical': 1.42449782852791,
#  'follow': 1.8650704199138914,
#  'quickly:': 5.672425341971495,
#  'number': 0.14886338591448275,
#  '54': 3.350497247084133,
#  'passes': 4.087462841250339,
#  'skole': 5.672425341971495,
#  '1710': 5.672425341971495,
#  'arrives': 3.6724253419714956,
#  'Railway': 5.672425341971495,
#  'Station': 5.672425341971495,
#  '1725.': 5.672425341971495,
#  'In': 0.057715497856287434,
#  'pro-': 0.9719856238304033,
#  'cess': 2.350497247084133,
#  'lexical': 0.8650704199138914,
#  'analysis,': 2.2129937233341983,
#  'syntax': 2.5025003405291835,
#  'semantic': 0.6724253419714956,
#  'pragmatic': 3.6724253419714956,
#  'reasoning': 4.087462841250339,
#  'query': 1.9719856238304034,
#  'processing.': 1.3504972470841332,
#  'One': 0.9719856238304033,
#  'could': 0.7182290315846205,
#  'argue': 3.0874628412503395,
#  'content': 2.2129937233341983,
#  'solved': 4.087462841250339,
#  'interrogation,': 5.672425341971495,
#  'whereby': 4.087462841250339,
#  'customer': 3.6724253419714956,
#  'asked': 1.8650704199138914,
#  'produce': 1.2129937233341985,
#  '4': 0.14886338591448275,
#  'items:': 4.672425341971495,
#  'ta': 3.0874628412503395,
#  'departure,': 4.672425341971495,
#  'arrival,': 5.672425341971495,
#  'earliest': 5.672425341971495,
#  'departure': 4.087462841250339,
#  'timeand/or': 5.672425341971495,
#  'latest': 3.0874628412503395,
#  'arrival': 4.087462841250339,
#  'time.': 1.5025003405291832,
#  'It': 0.18057224564182084,
#  'myth': 5.672425341971495,
#  'better': 0.8650704199138914,
#  '"natural': 5.672425341971495,
#  'language".': 5.672425341971495,
#  'challenge': 3.6724253419714956,
#  'prove': 3.6724253419714956,
#  'demonstration': 4.672425341971495,
#  'NL': 3.0874628412503395,
#  'preferred': 3.350497247084133,
#  'interrogative': 4.087462841250339,
#  'mode.': 3.6724253419714956,
#  'To': 0.42449782852791007,
#  'that,': 2.2129937233341983,
#  'correct,': 3.6724253419714956,
#  'user': 0.9719856238304033,
#  'friendly': 5.672425341971495,
#  'almost': 1.8650704199138914,
#  'complete': 1.3504972470841332,
#  'within': 0.9719856238304033,
#  'domain.': 2.350497247084133,
#  'Previous': 3.350497247084133,
#  'Efforts,': 5.672425341971495,
#  'CHAT-80,': 5.672425341971495,
#  'PRAT-89': 5.672425341971495,
#  'HSQL': 5.672425341971495,
#  'called': 0.8144443468439234,
#  'built': 1.2801079191927351,
#  'upon': 2.2129937233341983,
#  'clas-': 2.6724253419714956,
#  'sical': 5.672425341971495,
#  'CHAT-80': 5.672425341971495,
#  '(Warren': 5.672425341971495,
#  'Pereira,': 4.087462841250339,
#  '1982).': 5.672425341971495,
#  'state': 1.0874628412503393,
#  'art': 3.6724253419714956,
#  'sys-': 0.8650704199138914,
#  'tem': 1.2129937233341985,
#  'impressive': 4.087462841250339,
#  'merits,': 5.672425341971495,
#  'also': 0.057715497856287434,
#  'established': 3.0874628412503395,
#  'Prolog': 3.6724253419714956,
#  'viable': 3.6724253419714956,
#  'competitive': 4.672425341971495,
#  'lan-': 2.2129937233341983,
#  'guage': 1.765534746362977,
#  'Artificial': 1.765534746362977,
#  'Intelligence': 2.6724253419714956,
#  'general.': 4.087462841250339,
#  'brilliant': 5.672425341971495,
#  'masterpiece': 5.672425341971495,
#  'software,': 5.672425341971495,
#  'efficient': 1.8650704199138914,
#  'sophisticated.': 5.672425341971495,
#  'connected': 3.0874628412503395,
#  'international': 4.672425341971495,
#  'geography.': 5.672425341971495,
#  'analysed': 4.087462841250339,
#  'answered': 2.8650704199138914,
#  'split': 2.5025003405291835,
#  'second:': 5.672425341971495,
#  'Which': 2.8650704199138914,
#  'country': 3.0874628412503395,
#  'bordering': 5.672425341971495,
#  'Mediterranean': 5.672425341971495,
#  'borders': 5.672425341971495,
#  'bordered': 5.672425341971495,
#  'whose': 1.2129937233341985,
#  'population': 4.087462841250339,
#  'exceeds': 3.350497247084133,
#  ...}

# %%
tf = termfrequency(d, v)  #term frequency by using dictionary and vacabulary
tf
# Out:
# {0: {'Association': 1,
#   'Computational': 1,
#   'Linguistics': 1,
#   '6': 16,
#   'th': 25,
#   'Applied': 2,
#   'Natural': 5,
#   'Language': 9,
#   'Processing': 5,
#   'Conference': 3,
#   'Proceedings': 1,
#   'April': 1,
#   '29--May': 1,
#   '4,': 1,
#   '2000': 4,
#   'Seattle,': 1,
#   'Washington,': 1,
#   'USA': 1,
#   'ANLP': 11,
#   '2000-PREFACE': 1,
#   '131': 1,
#   'papers': 5,
#   'submitted': 3,
#   'ANLP-2000.': 1,
#   '46': 1,
#   'accepted': 1,
#   'presentation': 2,
#   'conference.': 1,
#   'Papers': 1,
#   'came': 2,
#   '24': 3,
#   'countries:': 1,
#   'fifty': 1,
#   'eight': 2,
#   'United': 2,
#   'States': 1,
#   'America,': 1,
#   'eleven': 1,
#   'Germany': 1,
#   'Kingdom,': 1,
#   'nine': 2,
#   'Canada,': 1,
#   'Japan,': 1,
#   'four': 2,
#   'Italy': 1,
#   'Spain,': 1,
#   'three': 1,
#   'ach': 8,
#   'France,': 1,
#   'Korea': 1,
#   'Switzerland,': 1,
#   'two': 1,
#   'Australia,': 1,
#   'China,': 1,
#   'The': 5,
#   'Netherlands': 1,
#   'Sweden': 1,
#   'one': 3,
#   'Czech': 1,
#   'Republic,': 1,
#   'Denmark,': 1,
#   'Finland,': 1,
#   'Greece,': 1,
#   'India,': 1,
#   'Hong': 2,
#   'Kong,': 1,
#   'Malaysia,': 1,
#   'Norway,': 1,
#   'Russia': 1,
#   'Taiwan.': 1,
#   '40': 1,
#   'industry.': 1,
#   '85': 1,
#   'academia.': 1,
#   '2': 33,
#   'government': 1,
#   'organizations': 1,
#   'submissions': 1,
#   'combined.': 1,
#   'reviewing': 2,
#   'process': 2,
#   'supported': 1,
#   'web-based': 1,
#   'reviewer': 1,
#   'interface': 1,
#   'developed': 1,
#   'Elisha': 1,
#   'Kane': 1,
#   'New': 1,
#   'Mexico': 1,
#   'State': 2,
#   "University's": 1,
#   'Computing': 1,
#   'Research': 1,
#   'Lab.': 1,
#   'Linda': 1,
#   'Fresques': 1,
#   'CRL': 1,
#   'coordinated': 1,
#   'refereeing': 1,
#   'process.': 1,
#   'I': 32,
#   'would': 1,
#   'like': 1,
#   'express': 1,
#   'gratitude': 1,
#   'appreciation': 1,
#   'fthe': 1,
#   'Program': 3,
#   'Committee': 3,
#   'members': 1,
#   'responsible': 1,
#   'six': 1,
#   'areas:': 1,
#   'Lynn': 1,
#   'Carlson,': 1,
#   'Tools': 1,
#   'Resources': 1,
#   'Developing': 1,
#   'NLP': 14,
#   'Systems': 8,
#   'Subcommittee': 6,
#   'Eduard': 1,
#   'Hovy,': 1,
#   'Integrated': 1,
#   'Richard': 3,
#   'Kittredge,': 2,
#   'Multilingual': 3,
#   'Text': 6,
#   'Ray': 2,
#   'Perrault,': 1,
#   'Spoken': 2,
#   'Oliviero': 1,
#   'Stock,': 1,
#   'Monolingual': 1,
#   'John': 3,
#   'White,': 1,
#   'Evaluation': 2,
#   'following': 1,
#   'colleagues': 1,
#   'Doug': 1,
#   'Appelt': 1,
#   'Fabio': 1,
#   'Ciravegna': 1,
#   'Robert': 4,
#   'Dale': 1,
#   'Michael': 3,
#   'Elhadad': 1,
#   'Ralph': 4,
#   'G-rishman': 1,
#   'Lynette': 1,
#   'Hirschman': 1,
#   'Yuval': 1,
#   'Krymolowski': 1,
#   'Inderjeet': 1,
#   'Mani': 1,
#   'Zvi': 1,
#   'Marx': 1,
#   'Martha': 1,
#   'Palmer': 1,
#   'Harold': 1,
#   'Somers': 1,
#   'Toshiyuki': 1,
#   'Takezawa': 1,
#   'Takehito': 1,
#   'Utsuro': 1,
#   'Dekai': 1,
#   'Wu': 1,
#   'bulk': 1,
#   'reviewing:': 1,
#   'Igor': 1,
#   'Boguslavsky': 1,
#   'Jim': 2,
#   'Cowie': 1,
#   'Dowding': 1,
#   'Glass': 1,
#   'Jan': 4,
#   'Haji~': 2,
#   'Pierre': 1,
#   'IsabeIIe': 1,
#   'Alberto': 1,
#   'Lavelli': 1,
#   'Daniel': 1,
#   'Marcu': 1,
#   'David': 7,
#   'McDonald': 1,
#   'Owen': 2,
#   'Rainbow': 1,
#   'Tomek': 2,
#   'Strzalkowski': 2,
#   'Kathryn': 1,
#   'B.': 1,
#   'Taylor': 1,
#   'Pick': 1,
#   'Vossen': 1,
#   'R6mi': 1,
#   'Zajac': 1,
#   'Carter': 1,
#   'Ido': 1,
#   'Dagan': 1,
#   'Andreas': 1,
#   'Eiscle': 1,
#   'Oren': 1,
#   'Glikman': 1,
#   'Donna': 1,
#   'Harman': 1,
#   'Tanya': 2,
#   'Korelsky': 2,
#   'Chin-Yew': 1,
#   'Lin': 5,
#   'Paul': 2,
#   'Martin': 2,
#   'Teruko': 1,
#   'Mitamura': 1,
#   'Norbert': 2,
#   'Reithinger': 1,
#   'Beth': 2,
#   'Sundheim': 1,
#   'Hans': 1,
#   'Uszkoreit': 1,
#   'Weischedel': 2,
#   'We': 5,
#   'believe': 1,
#   'quality': 1,
#   'elected': 1,
#   'israther': 1,
#   'high': 1,
#   'hope': 1,
#   'conference': 2,
#   'success.': 1,
#   'Sergei': 2,
#   'Nirenburg': 2,
#   'Chair,': 1,
#   'ANLP-2000': 2,
#   'ANLPi': 4,
#   'Table': 1,
#   'Contents': 1,
#   'Section': 1,
#   '1:': 1,
#   '(ANLP)': 1,
#   'Preface': 1,
#   'List': 2,
#   'Reviewers': 1,
#   'Nirenburg,': 1,
#   'Chair': 2,
#   '...............................................................': 37,
#   'BusTUC--A': 1,
#   'Bus': 3,
#   'Route': 1,
#   'Oracle': 1,
#   'Tore': 1,
#   'Amble': 1,
#   '..............................................................................................................................': 1,
#   '1': 26,
#   'Machine': 1,
#   'Translation': 3,
#   'Very': 1,
#   'Close': 1,
#   'Languages': 1,
#   'Haji~,': 1,
#   'Hric,': 1,
#   'Vladislav': 1,
#   'Kubofi': 1,
#   '.......................................................................................': 20,
#   '7': 8,
#   'Cross-Language': 2,
#   'Multimedia': 1,
#   'Information': 7,
#   'Retrieval': 3,
#   'Sharon': 1,
#   'Flank': 1,
#   '..........................................................................................................................': 2,
#   '13': 3,
#   'Automatic': 4,
#   'Construction': 1,
#   'Parallel': 1,
#   'English-Chinese': 1,
#   'Corpus': 4,
#   'Jiang': 1,
#   'Chen,': 1,
#   'Jian-Yun': 1,
#   'Nie': 1,
#   '......................................................................................................': 16,
#   '21': 3,
#   'PartslD:': 1,
#   'A': 74,
#   'Dialogue-Based': 1,
#   'System': 16,
#   'Identifying': 1,
#   'Parts': 2,
#   'Medical': 1,
#   'Amit': 2,
#   'Bagga,': 1,
#   'Strzalkowski,': 1,
#   'G.': 2,
#   'Bowden': 1,
#   'Wise': 1,
#   '...........................................................': 48,
#   '29': 4,
#   'Using': 5,
#   'Dialogue': 8,
#   'Participants': 1,
#   'Setsuo': 1,
#   'Yamada,': 1,
#   'Eiichiro': 1,
#   'Sumita,': 1,
#   'Hideki': 1,
#   'Kashioka': 1,
#   '..............................................................': 39,
#   '37': 1,
#   'Distilling': 1,
#   'Dialogues--A': 1,
#   'Method': 1,
#   'Corpora': 1,
#   'Development': 1,
#   'Arne': 1,
#   'J6nsson,': 1,
#   'Nils': 1,
#   'Dahlb~ick': 1,
#   '.................................................................................................': 18,
#   '44': 1,
#   'Plan-Based': 1,
#   'Management': 2,
#   'ina': 5,
#   'Physics': 1,
#   'Tour': 1,
#   'Reva': 1,
#   'Freedman': 1,
#   '......................................................................................................................': 8,
#   '52': 1,
#   'Framework': 1,
#   'MT': 1,
#   'NLG': 1,
#   'Based': 7,
#   'Uniform': 1,
#   'Lexico-Structural': 1,
#   'Benoit': 1,
#   'Lavoie,': 1,
#   'Korelsky,': 1,
#   'Rambow': 1,
#   '...................................': 90,
#   '60': 1,
#   "Talk'N'Travel:": 1,
#   'Conversational': 1,
#   'Air': 1,
#   'Travel': 2,
#   'Planning': 1,
#   'Stallard': 1,
#   '........................................................................................................................': 5,
#   '68': 2,
#   'REES:': 1,
#   'Large-Scale': 2,
#   'Relation': 2,
#   'Event': 1,
#   'Extraction': 5,
#   'Chinatsu': 1,
#   'Aone,': 1,
#   'Mila': 1,
#   'Ramos-Santacruz': 1,
#   '.................................................................................': 26,
#   '76': 2,
#   'Experiments': 2,
#   'Sentence': 2,
#   'Boundary': 1,
#   'Detection': 1,
#   'Mark': 3,
#   'Stevenson,': 2,
#   'Gaizauskas': 2,
#   '.....................................................................................': 22,
#   '84': 1,
#   'DP:': 1,
#   'Detector': 1,
#   'Presuppositions': 1,
#   'Survey': 1,
#   'Questions': 2,
#   'Katja': 1,
#   'Wiemer-Hastings,': 2,
#   'Peter': 1,
#   'Sonya': 1,
#   'Rajan,': 2,
#   'Art': 1,
#   'Graesser,': 1,
#   'Roger': 1,
#   'Kreuz,': 1,
#   'Ashish': 1,
#   'Karnavat': 1,
#   '..............................................................................................': 19,
#   '90': 2,
#   'ANLPiii': 1,
#   'MIMIC:': 1,
#   'An': 11,
#   'Adaptive': 1,
#   'Mixed': 1,
#   'Initiative': 1,
#   'Queries': 1,
#   'Jennifer': 1,
#   'Chu-Carroll': 1,
#   '..............................................................................................................': 14,
#   '97': 1,
#   'Javox:': 1,
#   'Toolkit': 1,
#   'Building': 1,
#   'Speech-Enabled': 1,
#   'Applications': 1,
#   'S.': 1,
#   'Fulkerson,': 1,
#   'Alan': 1,
#   'W.': 1,
#   'Biermann': 1,
#   '...........................................................................': 30,
#   '105': 1,
#   'Compact': 1,
#   'Architecture': 1,
#   'Scripts': 1,
#   'Meta-Outputs': 1,
#   'Manny': 1,
#   'Rayner,': 1,
#   'Ann': 3,
#   'Hockey,': 1,
#   'Frankie': 1,
#   'James': 1,
#   '112': 1,
#   'Representation': 1,
#   'Complex': 1,
#   'Evolving': 1,
#   'Data': 2,
#   'Dependencies': 1,
#   'Generation': 1,
#   'C.': 3,
#   'Mellish,': 1,
#   'R.': 2,
#   'Evans,': 1,
#   'L.': 2,
#   'Cahill,': 1,
#   'Doran,': 1,
#   'D.': 2,
#   'Paiva,': 1,
#   'M.': 2,
#   'Reape,': 1,
#   'Scott,': 1,
#   'N.': 1,
#   'Tipper': 1,
#   '.............................................................................': 28,
#   '119': 1,
#   'Reviser:': 1,
#   'TransCheck': 1,
#   'Jean-Marc': 1,
#   'Jutras': 1,
#   '..................................................................................................................': 12,
#   '127': 1,
#   'Unit': 3,
#   'Completion': 1,
#   'Computer-Aided': 1,
#   'Typing': 1,
#   'Philippe': 1,
#   'Langlais,': 1,
#   'George': 1,
#   'Foster,': 1,
#   'Guy': 1,
#   'Lapalme': 1,
#   '.................................................................': 34,
#   '135': 1,
#   'Coreference': 1,
#   'Resolution': 1,
#   'Sanda': 1,
#   'Harabagiu,': 1,
#   'Steven': 4,
#   'J.': 2,
#   'Maiorano': 1,
#   '142': 1,
#   'Ranking': 1,
#   'Suspected': 1,
#   'Answers': 1,
#   'Predictive': 1,
#   'Annotation': 1,
#   'Dragomir': 1,
#   'Radev,': 1,
#   'Prager,': 1,
#   'Valerie': 1,
#   'Samn': 1,
#   '150': 1,
#   'Message': 1,
#   'Classification': 1,
#   'Call': 1,
#   'Center': 1,
#   'Stephan': 1,
#   'Busemann,': 1,
#   'Sven': 1,
#   'Schmeier,': 1,
#   'Roman': 2,
#   'Arens': 1,
#   '.......................................................': 56,
#   '158': 1,
#   'Question': 4,
#   'Answering': 2,
#   'Supported': 1,
#   'Rohini': 2,
#   'Srihari,': 2,
#   'Wei': 4,
#   'Li': 9,
#   '........................................................................................................': 15,
#   '166': 1,
#   'Categorizing': 1,
#   'Unknown': 1,
#   'Words:': 1,
#   'Decision': 1,
#   'Trees': 1,
#   'Identify': 2,
#   'Names': 1,
#   'Misspellings': 1,
#   'Janine': 1,
#   'Toole': 1,
#   '.........................................................................................................................': 4,
#   '173': 1,
#   'Examining': 1,
#   'Role': 1,
#   'Statistical': 2,
#   'Linguistic': 3,
#   'Knowledge': 4,
#   'Sources': 1,
#   'General-Knowledge': 1,
#   'Question-Answering': 1,
#   'Claire': 1,
#   'Cardie,': 1,
#   'Vincent': 1,
#   'Ng,': 1,
#   'Pierce,': 1,
#   'Chris': 3,
#   'Buckley': 1,
#   '....................................................': 58,
#   '180': 1,
#   'Extracting': 1,
#   'Molecular': 1,
#   'Binding': 1,
#   'Relationships': 1,
#   'Biomedical': 1,
#   'Thomas': 1,
#   'Rindflesch,': 1,
#   'Jayant': 1,
#   'V.': 1,
#   'Lawrence': 2,
#   'Hunter': 1,
#   '................................................': 62,
#   '188': 1,
#   'Compound': 1,
#   'Noun': 1,
#   'Segmentation': 1,
#   'Lexical': 2,
#   'Extracted': 1,
#   'Juntae': 1,
#   'Yoon': 1,
#   '196': 1,
#   'Corpus-Based': 1,
#   'LFG': 1,
#   'Specialization': 1,
#   'Nicola': 1,
#   'Cancedda,': 1,
#   'Christer': 1,
#   'Samuelsson': 1,
#   '...............................................................................': 27,
#   '204': 1,
#   'Tool': 4,
#   'Automated': 1,
#   'Revision': 1,
#   'Grammars': 1,
#   'Nanda': 1,
#   'Kambhatla,': 1,
#   'Wlodek': 1,
#   'Zadrozny': 1,
#   '210': 1,
#   'ANLPiv': 1,
#   'Aggressive': 1,
#   'Morphology': 1,
#   'Robust': 1,
#   'Coverage': 1,
#   'William': 2,
#   'A.': 3,
#   'Woods': 2,
#   '...............................................................................................................': 13,
#   '218': 1,
#   'TnT--A': 1,
#   'Part-of-Speech': 1,
#   'Tagger': 1,
#   'Thorsten': 1,
#   'Brants': 1,
#   '...................................................................................................................': 11,
#   '224': 1,
#   'Independent': 1,
#   'Morphological': 1,
#   'Analysis': 1,
#   'Tatsuo': 1,
#   'Yamashita,': 1,
#   'Yuji': 1,
#   'Matsumoto': 1,
#   '....................................................................................': 23,
#   '232': 1,
#   'Divide-and-Conquer': 1,
#   'Strategy': 1,
#   'Shallow': 1,
#   'Parsing': 1,
#   'German': 2,
#   'Free': 2,
#   'Texts': 1,
#   'Giinter': 1,
#   'Neumann,': 1,
#   'Christian': 1,
#   'Braun,': 1,
#   'Jakub': 1,
#   'Piskorski': 1,
#   '239': 1,
#   'Hybrid': 1,
#   'Approach': 1,
#   'Named': 4,
#   'Entity': 3,
#   'Sub-Type': 1,
#   'Tagging': 1,
#   'Cheng': 1,
#   'Niu,': 1,
#   '......................................................................................': 21,
#   '247': 1,
#   'Spelling': 1,
#   'Grammar': 2,
#   'Correction': 1,
#   'Danish': 1,
#   'SCARRIE': 1,
#   'Patrizia': 1,
#   'Paggio': 1,
#   '.....................................................................................................................': 10,
#   '255': 1,
#   'Can': 3,
#   'Improve': 1,
#   'Woods,': 1,
#   'Bookman,': 1,
#   'Houston,': 1,
#   'Kuhns,': 1,
#   'Martin,': 1,
#   'Stephen': 1,
#   'Green': 1,
#   '262': 1,
#   'Domain-Specific': 1,
#   'Acquisition': 1,
#   'Dan': 3,
#   'Moldovan,': 1,
#   'Roxana': 1,
#   'Girju,': 1,
#   'Vasile': 1,
#   'Rus': 2,
#   '..........................................................................': 31,
#   '268': 1,
#   'Controlled': 1,
#   'Vocabulary': 1,
#   'Indexing': 1,
#   'Entities': 1,
#   'Wasson': 1,
#   '.......................................................................................................................': 7,
#   '276': 1,
#   'Unsupervised': 1,
#   'Discovery': 1,
#   'Scenario-Level': 1,
#   'Patterns': 1,
#   'Yangarber,': 1,
#   'Grishman,': 1,
#   'Pasi': 1,
#   'Tapanainen,': 1,
#   'Silja': 1,
#   'Huttunen': 1,
#   '..............................': 108,
#   '282': 1,
#   'Corpus-Derived': 1,
#   'Name': 6,
#   'Lists': 1,
#   'Recognition': 1,
#   '...................................................................................': 24,
#   '290': 1,
#   'Answer': 4,
#   'Abney,': 1,
#   'Collins,': 1,
#   'Singhal': 1,
#   '....................................................................': 32,
#   '296': 1,
#   'Automatically': 1,
#   'Identified': 1,
#   'Index': 2,
#   'Terms': 1,
#   'Browsing': 1,
#   'Electronic': 1,
#   'Documents': 1,
#   'Nina': 1,
#   'Wacholder,': 1,
#   'Judith': 1,
#   'Klavans,': 1,
#   'K.': 1,
#   'Evans': 2,
#   '.........................................................': 53,
#   '302': 1,
#   'Reduction': 1,
#   'Summarization': 1,
#   'Hongyan': 1,
#   'Jing': 1,
#   '310': 1,
#   'Noisy': 1,
#   'Input:': 1,
#   'Speech': 3,
#   'OCR': 1,
#   'Miller,': 1,
#   'Sean': 1,
#   'Boisen,': 1,
#   'Schwartz,': 1,
#   'Rebecca': 1,
#   'Stone,': 1,
#   '...........': 337,
#   '316': 1,
#   'Improving': 1,
#   'Testsuites': 1,
#   'via': 1,
#   'Instrumentation': 1,
#   'Br6ker': 1,
#   '325': 1,
#   'Efficiency': 1,
#   'Multimodal': 1,
#   'Interaction': 1,
#   'Map-Based': 1,
#   'Task': 1,
#   'Philip': 2,
#   'Cohen,': 1,
#   'McGee,': 1,
#   'Josh': 1,
#   'Clow': 1,
#   '................................................................': 35,
#   '331': 1,
#   'ANLPv': 1,
#   'BusTUC': 1,
#   'natura': 0,
#   'l': 211,
#   'anguage': 9,
#   'bus': 1,
#   'route': 0,
#   'rac': 9,
#   'le': 30,
#   'Dept.': 0,
#   'computer': 0,
#   'information': 0,
#   'science': 0,
#   'University': 1,
#   'Trondheim': 0,
#   'N-7491': 0,
#   'amble@idi,': 0,
#   'ntnu.': 0,
#   'Abstract': 0,
#   'paper': 5,
#   'describes': 0,
#   'natural': 0,
#   'based': 1,
#   'expert': 0,
#   'system': 0,
#   'advisor': 0,
#   'public': 1,
#   'transport': 0,
#   'Trondheim,': 0,
#   'Norway.': 0,
#   'available': 0,
#   'Internet,and': 0,
#   'intstalled': 0,
#   'com-': 0,
#   "pany's": 0,
#   'web': 1,
#   'server': 0,
#   'since': 0,
#   'beginning': 0,
#   '1999.': 0,
#   'bilingual,': 0,
#   'relying': 0,
#   'internal': 0,
#   'independent': 0,
#   'logic': 1,
#   'representation.': 0,
#   'Introduct': 0,
#   'ion': 52,
#   'database': 0,
#   'provides': 0,
#   'users': 0,
#   'capability': 0,
#   'obtaining': 0,
#   'in-': 2,
#   'formation': 7,
#   'stored': 0,
#   'querying': 0,
#   'language': 0,
#   '(NL).': 0,
#   'With': 0,
#   'means': 0,
#   'communication': 0,
#   'puter': 1,
#   'system,': 0,
#   'make': 0,
#   'question': 0,
#   'statement': 0,
#   'way': 1,
#   'normally': 0,
#   'think': 0,
#   'discussed,': 0,
#   'freeing': 0,
#   'hav-': 0,
#   'ing': 52,
#   'know': 1,
#   'stores': 0,
#   'processes': 0,
#   'information.': 0,
#   'present': 2,
#   'implementation': 0,
#   'represents': 0,
#   'major': 0,
#   'effort': 0,
#   'bringing': 0,
#   'practical': 0,
#   'use.': 0,
#   'answer': 0,
#   'queries': 0,
#   'routes,': 0,
#   'stated': 0,
#   'texts,': 0,
#   'made': 0,
#   'Internet': 0,
#   'World': 0,
#   'Wide': 0,
#   'Web': 0,
#   'http': 0,
#   '//www.': 0,
#   'idi.': 0,
#   'no/bustuc/).': 0,
#   'small': 0,
#   'city': 0,
#   'university': 0,
#   '140000': 0,
#   'inhabitants.': 0,
#   'Its': 0,
#   'central': 0,
#   'systems': 0,
#   '42': 1,
#   'lines,': 0,
#   'serving': 0,
#   '590': 0,
#   'stations,': 0,
#   '1900': 0,
#   'depar-': 0,
#   'tures': 0,
#   'per': 10,
#   'day': 0,
#   '(in': 0,
#   'average).': 0,
#   'That': 0,
#   'gives': 0,
#   'approximately': 0,
#   '60000': 0,
#   'scheduled': 0,
#   'station': 0,
#   'passings': 0,
#   'day,': 0,
#   'somehow': 0,
#   'represented': 0,
#   'data': 0,
#   'base.': 0,
#   'starting': 0,
#   'point': 0,
#   'automate': 0,
#   'function': 0,
#   'agent.': 0,
#   'example': 0,
#   'response': 0,
#   'using': 0,
#   'actual': 0,
#   'request': 0,
#   'telephone': 0,
#   'local': 0,
#   'company:': 0,
#   'Hi,': 0,
#   'live': 0,
#   'Nidarvoll': 0,
#   'tonight': 0,
#   'must': 0,
#   'reach': 0,
#   'train': 0,
#   'Oslo': 0,
#   'oclock.': 0,
#   'typical': 0,
#   'follow': 1,
#   'quickly:': 0,
#   'number': 0,
#   '54': 0,
#   'passes': 0,
#   'skole': 0,
#   '1710': 0,
#   'arrives': 0,
#   'Railway': 0,
#   'Station': 0,
#   '1725.': 0,
#   'In': 17,
#   'pro-': 0,
#   'cess': 8,
#   'lexical': 0,
#   'analysis,': 0,
#   'syntax': 0,
#   'semantic': 0,
#   'pragmatic': 0,
#   'reasoning': 0,
#   'query': 0,
#   'processing.': 0,
#   'One': 0,
#   'could': 0,
#   'argue': 0,
#   'content': 0,
#   'solved': 0,
#   'interrogation,': 0,
#   'whereby': 0,
#   'customer': 0,
#   'asked': 0,
#   'produce': 0,
#   '4': 11,
#   'items:': 0,
#   'ta': 20,
#   'departure,': 0,
#   'arrival,': 0,
#   'earliest': 0,
#   'departure': 0,
#   'timeand/or': 0,
#   'latest': 0,
#   'arrival': 0,
#   'time.': 0,
#   'It': 1,
#   'myth': 0,
#   'better': 0,
#   '"natural': 0,
#   'language".': 0,
#   'challenge': 0,
#   'prove': 1,
#   'demonstration': 0,
#   'NL': 15,
#   'preferred': 0,
#   'interrogative': 0,
#   'mode.': 0,
#   'To': 9,
#   'that,': 0,
#   'correct,': 0,
#   'user': 0,
#   'friendly': 0,
#   'almost': 0,
#   'complete': 0,
#   'within': 0,
#   'domain.': 0,
#   'Previous': 0,
#   'Efforts,': 0,
#   'CHAT-80,': 0,
#   'PRAT-89': 0,
#   'HSQL': 0,
#   'called': 0,
#   'built': 0,
#   'upon': 0,
#   'clas-': 0,
#   'sical': 0,
#   'CHAT-80': 0,
#   '(Warren': 0,
#   'Pereira,': 0,
#   '1982).': 0,
#   'state': 0,
#   'art': 9,
#   'sys-': 0,
#   'tem': 16,
#   'impressive': 0,
#   'merits,': 0,
#   'also': 0,
#   'established': 0,
#   'Prolog': 0,
#   'viable': 0,
#   'competitive': 0,
#   'lan-': 1,
#   'guage': 9,
#   'Artificial': 0,
#   'Intelligence': 0,
#   'general.': 0,
#   'brilliant': 0,
#   'masterpiece': 0,
#   'software,': 0,
#   'efficient': 0,
#   'sophisticated.': 0,
#   'connected': 0,
#   'international': 0,
#   'geography.': 0,
#   'analysed': 0,
#   'answered': 0,
#   'split': 0,
#   'second:': 0,
#   'Which': 0,
#   'country': 0,
#   'bordering': 0,
#   'Mediterranean': 0,
#   'borders': 0,
#   'bordered': 0,
#   'whose': 0,
#   'population': 0,
#   'exceeds': 0,
#   ...},
#  1: {'Association': 0,
#   'Computational': 1,
#   'Linguistics': 0,
#   '6': 11,
#   'th': 294,
#   'Applied': 0,
#   'Natural': 3,
#   'Language': 2,
#   'Processing': 0,
#   'Conference': 0,
#   'Proceedings': 0,
#   'April': 0,
#   '29--May': 0,
#   '4,': 1,
#   '2000': 0,
#   'Seattle,': 0,
#   'Washington,': 0,
#   'USA': 0,
#   'ANLP': 0,
#   '2000-PREFACE': 0,
#   '131': 0,
#   'papers': 0,
#   'submitted': 0,
#   'ANLP-2000.': 0,
#   '46': 0,
#   'accepted': 0,
#   'presentation': 2,
#   'conference.': 0,
#   'Papers': 0,
#   'came': 1,
#   '24': 0,
#   'countries:': 0,
#   'fifty': 0,
#   'eight': 0,
#   'United': 0,
#   'States': 0,
#   'America,': 0,
#   'eleven': 0,
#   'Germany': 0,
#   'Kingdom,': 0,
#   'nine': 0,
#   'Canada,': 0,
#   'Japan,': 0,
#   'four': 0,
#   'Italy': 0,
#   'Spain,': 0,
#   'three': 0,
#   'ach': 9,
#   'France,': 0,
#   'Korea': 0,
#   'Switzerland,': 0,
#   'two': 2,
#   'Australia,': 0,
#   'China,': 0,
#   'The': 77,
#   'Netherlands': 0,
#   'Sweden': 0,
#   'one': 14,
#   'Czech': 0,
#   'Republic,': 0,
#   'Denmark,': 1,
#   'Finland,': 0,
#   'Greece,': 0,
#   'India,': 0,
#   'Hong': 0,
#   'Kong,': 0,
#   'Malaysia,': 0,
#   'Norway,': 1,
#   'Russia': 0,
#   'Taiwan.': 0,
#   '40': 2,
#   'industry.': 0,
#   '85': 1,
#   'academia.': 0,
#   '2': 20,
#   'government': 0,
#   'organizations': 0,
#   'submissions': 0,
#   'combined.': 0,
#   'reviewing': 0,
#   'process': 7,
#   'supported': 0,
#   'web-based': 0,
#   'reviewer': 0,
#   'interface': 10,
#   'developed': 3,
#   'Elisha': 0,
#   'Kane': 0,
#   'New': 1,
#   'Mexico': 0,
#   'State': 1,
#   "University's": 0,
#   'Computing': 1,
#   'Research': 0,
#   'Lab.': 0,
#   'Linda': 0,
#   'Fresques': 0,
#   'CRL': 0,
#   'coordinated': 0,
#   'refereeing': 0,
#   'process.': 0,
#   'I': 39,
#   'would': 9,
#   'like': 7,
#   'express': 5,
#   'gratitude': 0,
#   'appreciation': 0,
#   'fthe': 0,
#   'Program': 0,
#   'Committee': 0,
#   'members': 0,
#   'responsible': 0,
#   'six': 0,
#   'areas:': 0,
#   'Lynn': 0,
#   'Carlson,': 0,
#   'Tools': 0,
#   'Resources': 0,
#   'Developing': 0,
#   'NLP': 0,
#   'Systems': 0,
#   'Subcommittee': 0,
#   'Eduard': 0,
#   'Hovy,': 0,
#   'Integrated': 0,
#   'Richard': 0,
#   'Kittredge,': 0,
#   'Multilingual': 0,
#   'Text': 0,
#   'Ray': 0,
#   'Perrault,': 0,
#   'Spoken': 0,
#   'Oliviero': 0,
#   'Stock,': 0,
#   'Monolingual': 0,
#   'John': 3,
#   'White,': 0,
#   'Evaluation': 0,
#   'following': 6,
#   'colleagues': 0,
#   'Doug': 0,
#   'Appelt': 0,
#   'Fabio': 0,
#   'Ciravegna': 0,
#   'Robert': 0,
#   'Dale': 0,
#   'Michael': 0,
#   'Elhadad': 0,
#   'Ralph': 0,
#   'G-rishman': 0,
#   'Lynette': 0,
#   'Hirschman': 0,
#   'Yuval': 0,
#   'Krymolowski': 0,
#   'Inderjeet': 0,
#   'Mani': 0,
#   'Zvi': 0,
#   'Marx': 0,
#   'Martha': 0,
#   'Palmer': 0,
#   'Harold': 0,
#   'Somers': 0,
#   'Toshiyuki': 0,
#   'Takezawa': 0,
#   'Takehito': 0,
#   'Utsuro': 0,
#   'Dekai': 0,
#   'Wu': 0,
#   'bulk': 0,
#   'reviewing:': 0,
#   'Igor': 0,
#   'Boguslavsky': 0,
#   'Jim': 0,
#   'Cowie': 0,
#   'Dowding': 0,
#   'Glass': 0,
#   'Jan': 1,
#   'Haji~': 0,
#   'Pierre': 0,
#   'IsabeIIe': 0,
#   'Alberto': 0,
#   'Lavelli': 0,
#   'Daniel': 0,
#   'Marcu': 0,
#   'David': 0,
#   'McDonald': 0,
#   'Owen': 0,
#   'Rainbow': 0,
#   'Tomek': 0,
#   'Strzalkowski': 0,
#   'Kathryn': 0,
#   'B.': 0,
#   'Taylor': 0,
#   'Pick': 0,
#   'Vossen': 0,
#   'R6mi': 0,
#   'Zajac': 0,
#   'Carter': 0,
#   'Ido': 0,
#   'Dagan': 0,
#   'Andreas': 0,
#   'Eiscle': 0,
#   'Oren': 0,
#   'Glikman': 0,
#   'Donna': 0,
#   'Harman': 0,
#   'Tanya': 0,
#   'Korelsky': 0,
#   'Chin-Yew': 0,
#   'Lin': 2,
#   'Paul': 0,
#   'Martin': 0,
#   'Teruko': 0,
#   'Mitamura': 0,
#   'Norbert': 0,
#   'Reithinger': 0,
#   'Beth': 0,
#   'Sundheim': 0,
#   'Hans': 0,
#   'Uszkoreit': 0,
#   'Weischedel': 0,
#   'We': 3,
#   'believe': 5,
#   'quality': 0,
#   'elected': 1,
#   'israther': 0,
#   'high': 0,
#   'hope': 0,
#   'conference': 0,
#   'success.': 0,
#   'Sergei': 0,
#   'Nirenburg': 0,
#   'Chair,': 0,
#   'ANLP-2000': 0,
#   'ANLPi': 0,
#   'Table': 0,
#   'Contents': 0,
#   'Section': 0,
#   '1:': 0,
#   '(ANLP)': 0,
#   'Preface': 0,
#   'List': 0,
#   'Reviewers': 0,
#   'Nirenburg,': 0,
#   'Chair': 0,
#   '...............................................................': 0,
#   'BusTUC--A': 0,
#   'Bus': 11,
#   'Route': 0,
#   'Oracle': 0,
#   'Tore': 2,
#   'Amble': 3,
#   '..............................................................................................................................': 0,
#   '1': 40,
#   'Machine': 0,
#   'Translation': 0,
#   'Very': 0,
#   'Close': 0,
#   'Languages': 0,
#   'Haji~,': 0,
#   'Hric,': 0,
#   'Vladislav': 0,
#   'Kubofi': 0,
#   '.......................................................................................': 0,
#   '7': 7,
#   'Cross-Language': 0,
#   'Multimedia': 0,
#   'Information': 1,
#   'Retrieval': 0,
#   'Sharon': 0,
#   'Flank': 0,
#   '..........................................................................................................................': 0,
#   '13': 1,
#   'Automatic': 0,
#   'Construction': 0,
#   'Parallel': 0,
#   'English-Chinese': 0,
#   'Corpus': 0,
#   'Jiang': 0,
#   'Chen,': 0,
#   'Jian-Yun': 0,
#   'Nie': 0,
#   '......................................................................................................': 0,
#   '21': 0,
#   'PartslD:': 0,
#   'A': 73,
#   'Dialogue-Based': 0,
#   'System': 5,
#   'Identifying': 0,
#   'Parts': 0,
#   'Medical': 0,
#   'Amit': 0,
#   'Bagga,': 0,
#   'Strzalkowski,': 0,
#   'G.': 0,
#   'Bowden': 0,
#   'Wise': 0,
#   '...........................................................': 0,
#   '29': 0,
#   'Using': 0,
#   'Dialogue': 0,
#   'Participants': 0,
#   'Setsuo': 0,
#   'Yamada,': 0,
#   'Eiichiro': 0,
#   'Sumita,': 0,
#   'Hideki': 0,
#   'Kashioka': 0,
#   '..............................................................': 0,
#   '37': 0,
#   'Distilling': 0,
#   'Dialogues--A': 0,
#   'Method': 0,
#   'Corpora': 0,
#   'Development': 0,
#   'Arne': 0,
#   'J6nsson,': 0,
#   'Nils': 0,
#   'Dahlb~ick': 0,
#   '.................................................................................................': 0,
#   '44': 0,
#   'Plan-Based': 0,
#   'Management': 0,
#   'ina': 6,
#   'Physics': 0,
#   'Tour': 0,
#   'Reva': 0,
#   'Freedman': 0,
#   '......................................................................................................................': 0,
#   '52': 0,
#   'Framework': 0,
#   'MT': 0,
#   'NLG': 0,
#   'Based': 0,
#   'Uniform': 0,
#   'Lexico-Structural': 0,
#   'Benoit': 0,
#   'Lavoie,': 0,
#   'Korelsky,': 0,
#   'Rambow': 0,
#   '...................................': 0,
#   '60': 2,
#   "Talk'N'Travel:": 0,
#   'Conversational': 0,
#   'Air': 0,
#   'Travel': 0,
#   'Planning': 0,
#   'Stallard': 0,
#   '........................................................................................................................': 0,
#   '68': 0,
#   'REES:': 0,
#   'Large-Scale': 0,
#   'Relation': 1,
#   'Event': 2,
#   'Extraction': 0,
#   'Chinatsu': 0,
#   'Aone,': 0,
#   'Mila': 0,
#   'Ramos-Santacruz': 0,
#   '.................................................................................': 0,
#   '76': 0,
#   'Experiments': 0,
#   'Sentence': 0,
#   'Boundary': 0,
#   'Detection': 0,
#   'Mark': 0,
#   'Stevenson,': 0,
#   'Gaizauskas': 0,
#   '.....................................................................................': 0,
#   '84': 0,
#   'DP:': 0,
#   'Detector': 0,
#   'Presuppositions': 0,
#   'Survey': 0,
#   'Questions': 0,
#   'Katja': 0,
#   'Wiemer-Hastings,': 0,
#   'Peter': 0,
#   'Sonya': 0,
#   'Rajan,': 0,
#   'Art': 2,
#   'Graesser,': 0,
#   'Roger': 0,
#   'Kreuz,': 0,
#   'Ashish': 0,
#   'Karnavat': 0,
#   '..............................................................................................': 0,
#   '90': 4,
#   'ANLPiii': 0,
#   'MIMIC:': 0,
#   'An': 3,
#   'Adaptive': 0,
#   'Mixed': 0,
#   'Initiative': 0,
#   'Queries': 0,
#   'Jennifer': 0,
#   'Chu-Carroll': 0,
#   '..............................................................................................................': 0,
#   '97': 2,
#   'Javox:': 0,
#   'Toolkit': 0,
#   'Building': 0,
#   'Speech-Enabled': 0,
#   'Applications': 0,
#   'S.': 1,
#   'Fulkerson,': 0,
#   'Alan': 0,
#   'W.': 0,
#   'Biermann': 0,
#   '...........................................................................': 0,
#   '105': 0,
#   'Compact': 0,
#   'Architecture': 0,
#   'Scripts': 0,
#   'Meta-Outputs': 0,
#   'Manny': 0,
#   'Rayner,': 0,
#   'Ann': 0,
#   'Hockey,': 0,
#   'Frankie': 0,
#   'James': 0,
#   '112': 0,
#   'Representation': 0,
#   'Complex': 0,
#   'Evolving': 0,
#   'Data': 0,
#   'Dependencies': 0,
#   'Generation': 1,
#   'C.': 2,
#   'Mellish,': 0,
#   'R.': 1,
#   'Evans,': 0,
#   'L.': 2,
#   'Cahill,': 0,
#   'Doran,': 0,
#   'D.': 3,
#   'Paiva,': 0,
#   'M.': 1,
#   'Reape,': 0,
#   'Scott,': 0,
#   'N.': 2,
#   'Tipper': 0,
#   '.............................................................................': 0,
#   '119': 0,
#   'Reviser:': 0,
#   'TransCheck': 0,
#   'Jean-Marc': 0,
#   'Jutras': 0,
#   '..................................................................................................................': 0,
#   '127': 0,
#   'Unit': 0,
#   'Completion': 0,
#   'Computer-Aided': 0,
#   'Typing': 0,
#   'Philippe': 0,
#   'Langlais,': 0,
#   'George': 0,
#   'Foster,': 0,
#   'Guy': 0,
#   'Lapalme': 0,
#   '.................................................................': 0,
#   '135': 0,
#   'Coreference': 0,
#   'Resolution': 0,
#   'Sanda': 0,
#   'Harabagiu,': 0,
#   'Steven': 0,
#   'J.': 2,
#   'Maiorano': 0,
#   '142': 0,
#   'Ranking': 0,
#   'Suspected': 0,
#   'Answers': 0,
#   'Predictive': 0,
#   'Annotation': 0,
#   'Dragomir': 0,
#   'Radev,': 0,
#   'Prager,': 0,
#   'Valerie': 0,
#   'Samn': 0,
#   '150': 2,
#   'Message': 0,
#   'Classification': 0,
#   'Call': 0,
#   'Center': 0,
#   'Stephan': 0,
#   'Busemann,': 0,
#   'Sven': 0,
#   'Schmeier,': 0,
#   'Roman': 0,
#   'Arens': 0,
#   '.......................................................': 0,
#   '158': 0,
#   'Question': 0,
#   'Answering': 0,
#   'Supported': 0,
#   'Rohini': 0,
#   'Srihari,': 0,
#   'Wei': 0,
#   'Li': 3,
#   '........................................................................................................': 0,
#   '166': 0,
#   'Categorizing': 0,
#   'Unknown': 0,
#   'Words:': 0,
#   'Decision': 0,
#   'Trees': 0,
#   'Identify': 0,
#   'Names': 0,
#   'Misspellings': 0,
#   'Janine': 0,
#   'Toole': 0,
#   '.........................................................................................................................': 0,
#   '173': 0,
#   'Examining': 0,
#   'Role': 0,
#   'Statistical': 0,
#   'Linguistic': 0,
#   'Knowledge': 0,
#   'Sources': 0,
#   'General-Knowledge': 0,
#   'Question-Answering': 0,
#   'Claire': 0,
#   'Cardie,': 0,
#   'Vincent': 0,
#   'Ng,': 0,
#   'Pierce,': 0,
#   'Chris': 0,
#   'Buckley': 0,
#   '....................................................': 0,
#   '180': 0,
#   'Extracting': 0,
#   'Molecular': 0,
#   'Binding': 0,
#   'Relationships': 0,
#   'Biomedical': 0,
#   'Thomas': 0,
#   'Rindflesch,': 0,
#   'Jayant': 0,
#   'V.': 2,
#   'Lawrence': 0,
#   'Hunter': 0,
#   '................................................': 0,
#   '188': 0,
#   'Compound': 0,
#   'Noun': 1,
#   'Segmentation': 0,
#   'Lexical': 0,
#   'Extracted': 0,
#   'Juntae': 0,
#   'Yoon': 0,
#   '196': 0,
#   'Corpus-Based': 0,
#   'LFG': 0,
#   'Specialization': 0,
#   'Nicola': 0,
#   'Cancedda,': 0,
#   'Christer': 0,
#   'Samuelsson': 0,
#   '...............................................................................': 0,
#   '204': 0,
#   'Tool': 0,
#   'Automated': 0,
#   'Revision': 0,
#   'Grammars': 2,
#   'Nanda': 0,
#   'Kambhatla,': 0,
#   'Wlodek': 0,
#   'Zadrozny': 0,
#   '210': 0,
#   'ANLPiv': 0,
#   'Aggressive': 0,
#   'Morphology': 0,
#   'Robust': 0,
#   'Coverage': 0,
#   'William': 0,
#   'A.': 0,
#   'Woods': 0,
#   '...............................................................................................................': 0,
#   '218': 0,
#   'TnT--A': 0,
#   'Part-of-Speech': 0,
#   'Tagger': 0,
#   'Thorsten': 0,
#   'Brants': 0,
#   '...................................................................................................................': 0,
#   '224': 0,
#   'Independent': 0,
#   'Morphological': 0,
#   'Analysis': 0,
#   'Tatsuo': 0,
#   'Yamashita,': 0,
#   'Yuji': 0,
#   'Matsumoto': 0,
#   '....................................................................................': 0,
#   '232': 0,
#   'Divide-and-Conquer': 0,
#   'Strategy': 0,
#   'Shallow': 0,
#   'Parsing': 0,
#   'German': 0,
#   'Free': 0,
#   'Texts': 0,
#   'Giinter': 0,
#   'Neumann,': 0,
#   'Christian': 0,
#   'Braun,': 0,
#   'Jakub': 0,
#   'Piskorski': 0,
#   '239': 0,
#   'Hybrid': 0,
#   'Approach': 0,
#   'Named': 0,
#   'Entity': 1,
#   'Sub-Type': 0,
#   'Tagging': 0,
#   'Cheng': 0,
#   'Niu,': 0,
#   '......................................................................................': 0,
#   '247': 0,
#   'Spelling': 0,
#   'Grammar': 7,
#   'Correction': 0,
#   'Danish': 1,
#   'SCARRIE': 0,
#   'Patrizia': 0,
#   'Paggio': 0,
#   '.....................................................................................................................': 0,
#   '255': 0,
#   'Can': 0,
#   'Improve': 0,
#   'Woods,': 0,
#   'Bookman,': 0,
#   'Houston,': 0,
#   'Kuhns,': 0,
#   'Martin,': 0,
#   'Stephen': 0,
#   'Green': 0,
#   '262': 0,
#   'Domain-Specific': 0,
#   'Acquisition': 0,
#   'Dan': 1,
#   'Moldovan,': 0,
#   'Roxana': 0,
#   'Girju,': 0,
#   'Vasile': 0,
#   'Rus': 0,
#   '..........................................................................': 0,
#   '268': 0,
#   'Controlled': 0,
#   'Vocabulary': 0,
#   'Indexing': 0,
#   'Entities': 0,
#   'Wasson': 0,
#   '.......................................................................................................................': 0,
#   '276': 0,
#   'Unsupervised': 0,
#   'Discovery': 0,
#   'Scenario-Level': 0,
#   'Patterns': 0,
#   'Yangarber,': 0,
#   'Grishman,': 0,
#   'Pasi': 0,
#   'Tapanainen,': 0,
#   'Silja': 0,
#   'Huttunen': 0,
#   '..............................': 0,
#   '282': 0,
#   'Corpus-Derived': 0,
#   'Name': 0,
#   'Lists': 0,
#   'Recognition': 0,
#   '...................................................................................': 0,
#   '290': 0,
#   'Answer': 0,
#   'Abney,': 0,
#   'Collins,': 0,
#   'Singhal': 0,
#   '....................................................................': 0,
#   '296': 0,
#   'Automatically': 0,
#   'Identified': 0,
#   'Index': 0,
#   'Terms': 0,
#   'Browsing': 0,
#   'Electronic': 0,
#   'Documents': 0,
#   'Nina': 0,
#   'Wacholder,': 0,
#   'Judith': 0,
#   'Klavans,': 0,
#   'K.': 0,
#   'Evans': 0,
#   '.........................................................': 0,
#   '302': 0,
#   'Reduction': 0,
#   'Summarization': 0,
#   'Hongyan': 0,
#   'Jing': 0,
#   '310': 0,
#   'Noisy': 0,
#   'Input:': 0,
#   'Speech': 1,
#   'OCR': 0,
#   'Miller,': 0,
#   'Sean': 0,
#   'Boisen,': 0,
#   'Schwartz,': 0,
#   'Rebecca': 0,
#   'Stone,': 0,
#   '...........': 0,
#   '316': 0,
#   'Improving': 0,
#   'Testsuites': 0,
#   'via': 4,
#   'Instrumentation': 0,
#   'Br6ker': 0,
#   '325': 0,
#   'Efficiency': 0,
#   'Multimodal': 0,
#   'Interaction': 0,
#   'Map-Based': 0,
#   'Task': 0,
#   'Philip': 0,
#   'Cohen,': 0,
#   'McGee,': 0,
#   'Josh': 0,
#   'Clow': 0,
#   '................................................................': 0,
#   '331': 0,
#   'ANLPv': 0,
#   'BusTUC': 8,
#   'natura': 24,
#   'l': 677,
#   'anguage': 40,
#   'bus': 17,
#   'route': 15,
#   'rac': 10,
#   'le': 129,
#   'Dept.': 1,
#   'computer': 5,
#   'information': 11,
#   'science': 1,
#   'University': 3,
#   'Trondheim': 7,
#   'N-7491': 1,
#   'amble@idi,': 1,
#   'ntnu.': 2,
#   'Abstract': 1,
#   'paper': 1,
#   'describes': 1,
#   'natural': 23,
#   'based': 5,
#   'expert': 1,
#   'system': 43,
#   'advisor': 1,
#   'public': 6,
#   'transport': 3,
#   'Trondheim,': 1,
#   'Norway.': 1,
#   'available': 2,
#   'Internet,and': 1,
#   'intstalled': 1,
#   'com-': 3,
#   "pany's": 1,
#   'web': 1,
#   'server': 2,
#   'since': 1,
#   'beginning': 1,
#   '1999.': 1,
#   'bilingual,': 1,
#   'relying': 1,
#   'internal': 2,
#   'independent': 1,
#   'logic': 5,
#   'representation.': 1,
#   'Introduct': 1,
#   'ion': 109,
#   'database': 12,
#   'provides': 1,
#   'users': 2,
#   'capability': 1,
#   'obtaining': 1,
#   'in-': 3,
#   'formation': 13,
#   'stored': 1,
#   'querying': 1,
#   'language': 27,
#   '(NL).': 1,
#   'With': 1,
#   'means': 3,
#   'communication': 2,
#   'puter': 8,
#   'system,': 3,
#   'make': 6,
#   'question': 10,
#   'statement': 7,
#   'way': 9,
#   'normally': 1,
#   'think': 1,
#   'discussed,': 1,
#   'freeing': 1,
#   'hav-': 1,
#   'ing': 99,
#   'know': 11,
#   'stores': 1,
#   'processes': 1,
#   'information.': 1,
#   'present': 5,
#   'implementation': 1,
#   'represents': 1,
#   'major': 2,
#   'effort': 4,
#   'bringing': 1,
#   'practical': 1,
#   'use.': 1,
#   'answer': 13,
#   'queries': 6,
#   'routes,': 1,
#   'stated': 1,
#   'texts,': 1,
#   'made': 10,
#   'Internet': 5,
#   'World': 2,
#   'Wide': 2,
#   'Web': 2,
#   'http': 1,
#   '//www.': 1,
#   'idi.': 1,
#   'no/bustuc/).': 1,
#   'small': 4,
#   'city': 2,
#   'university': 1,
#   '140000': 1,
#   'inhabitants.': 1,
#   'Its': 1,
#   'central': 3,
#   'systems': 7,
#   '42': 2,
#   'lines,': 1,
#   'serving': 1,
#   '590': 1,
#   'stations,': 1,
#   '1900': 1,
#   'depar-': 1,
#   'tures': 2,
#   'per': 16,
#   'day': 9,
#   '(in': 2,
#   'average).': 1,
#   'That': 1,
#   'gives': 2,
#   'approximately': 1,
#   '60000': 1,
#   'scheduled': 1,
#   'station': 4,
#   'passings': 1,
#   'day,': 4,
#   'somehow': 1,
#   'represented': 1,
#   'data': 15,
#   'base.': 4,
#   'starting': 1,
#   'point': 3,
#   'automate': 2,
#   'function': 1,
#   'agent.': 2,
#   'example': 3,
#   'response': 2,
#   'using': 4,
#   'actual': 7,
#   'request': 1,
#   'telephone': 4,
#   'local': 3,
#   'company:': 1,
#   'Hi,': 1,
#   'live': 3,
#   'Nidarvoll': 2,
#   'tonight': 1,
#   'must': 1,
#   'reach': 2,
#   'train': 1,
#   'Oslo': 1,
#   'oclock.': 1,
#   'typical': 3,
#   'follow': 9,
#   'quickly:': 1,
#   'number': 3,
#   '54': 1,
#   'passes': 1,
#   'skole': 1,
#   '1710': 1,
#   'arrives': 1,
#   'Railway': 1,
#   'Station': 1,
#   '1725.': 1,
#   'In': 20,
#   'pro-': 2,
#   'cess': 11,
#   'lexical': 2,
#   'analysis,': 3,
#   'syntax': 2,
#   'semantic': 17,
#   'pragmatic': 2,
#   'reasoning': 5,
#   'query': 11,
#   'processing.': 1,
#   'One': 1,
#   'could': 10,
#   'argue': 1,
#   'content': 1,
#   'solved': 2,
#   'interrogation,': 1,
#   'whereby': 1,
#   'customer': 2,
#   'asked': 1,
#   'produce': 2,
#   '4': 19,
#   'items:': 1,
#   'ta': 85,
#   'departure,': 1,
#   'arrival,': 1,
#   'earliest': 1,
#   'departure': 2,
#   'timeand/or': 1,
#   'latest': 1,
#   'arrival': 2,
#   'time.': 3,
#   'It': 9,
#   'myth': 1,
#   'better': 1,
#   '"natural': 1,
#   'language".': 1,
#   'challenge': 1,
#   'prove': 8,
#   'demonstration': 1,
#   'NL': 2,
#   'preferred': 3,
#   'interrogative': 1,
#   'mode.': 1,
#   'To': 3,
#   'that,': 1,
#   'correct,': 2,
#   'user': 4,
#   'friendly': 1,
#   'almost': 2,
#   'complete': 5,
#   'within': 4,
#   'domain.': 1,
#   'Previous': 1,
#   'Efforts,': 1,
#   'CHAT-80,': 3,
#   'PRAT-89': 3,
#   'HSQL': 11,
#   'called': 7,
#   'built': 4,
#   'upon': 1,
#   'clas-': 1,
#   'sical': 5,
#   'CHAT-80': 10,
#   '(Warren': 1,
#   'Pereira,': 1,
#   '1982).': 1,
#   'state': 9,
#   'art': 11,
#   'sys-': 5,
#   'tem': 61,
#   'impressive': 1,
#   'merits,': 1,
#   'also': 7,
#   'established': 1,
#   'Prolog': 8,
#   'viable': 1,
#   'competitive': 1,
#   'lan-': 3,
#   'guage': 45,
#   'Artificial': 2,
#   'Intelligence': 2,
#   'general.': 1,
#   'brilliant': 1,
#   'masterpiece': 1,
#   'software,': 1,
#   'efficient': 2,
#   'sophisticated.': 1,
#   'connected': 2,
#   'international': 1,
#   'geography.': 1,
#   'analysed': 6,
#   'answered': 2,
#   'split': 1,
#   'second:': 1,
#   'Which': 3,
#   'country': 3,
#   'bordering': 1,
#   'Mediterranean': 1,
#   'borders': 1,
#   'bordered': 1,
#   'whose': 4,
#   'population': 2,
#   'exceeds': 1,
#   ...},
#  2: {'Association': 0,
#   'Computational': 0,
#   'Linguistics': 0,
#   '6': 16,
#   'th': 367,
#   'Applied': 0,
#   'Natural': 1,
#   'Language': 4,
#   'Processing': 1,
#   'Conference': 0,
#   'Proceedings': 1,
#   'April': 0,
#   '29--May': 0,
#   '4,': 0,
#   '2000': 1,
#   'Seattle,': 0,
#   'Washington,': 0,
#   'USA': 1,
#   'ANLP': 0,
#   '2000-PREFACE': 0,
#   '131': 0,
#   'papers': 0,
#   'submitted': 0,
#   'ANLP-2000.': 0,
#   '46': 0,
#   'accepted': 0,
#   'presentation': 0,
#   'conference.': 0,
#   'Papers': 0,
#   'came': 0,
#   '24': 0,
#   'countries:': 0,
#   'fifty': 0,
#   'eight': 1,
#   'United': 0,
#   'States': 0,
#   'America,': 0,
#   'eleven': 0,
#   'Germany': 0,
#   'Kingdom,': 0,
#   'nine': 1,
#   'Canada,': 1,
#   'Japan,': 0,
#   'four': 0,
#   'Italy': 0,
#   'Spain,': 0,
#   'three': 2,
#   'ach': 18,
#   'France,': 0,
#   'Korea': 0,
#   'Switzerland,': 0,
#   'two': 2,
#   'Australia,': 0,
#   'China,': 0,
#   'The': 70,
#   'Netherlands': 0,
#   'Sweden': 0,
#   'one': 18,
#   'Czech': 43,
#   'Republic,': 2,
#   'Denmark,': 0,
#   'Finland,': 0,
#   'Greece,': 0,
#   'India,': 0,
#   'Hong': 0,
#   'Kong,': 0,
#   'Malaysia,': 0,
#   'Norway,': 0,
#   'Russia': 14,
#   'Taiwan.': 0,
#   '40': 4,
#   'industry.': 0,
#   '85': 1,
#   'academia.': 0,
#   '2': 33,
#   'government': 0,
#   'organizations': 0,
#   'submissions': 0,
#   'combined.': 0,
#   'reviewing': 0,
#   'process': 2,
#   'supported': 1,
#   'web-based': 0,
#   'reviewer': 0,
#   'interface': 0,
#   'developed': 4,
#   'Elisha': 0,
#   'Kane': 0,
#   'New': 0,
#   'Mexico': 0,
#   'State': 0,
#   "University's": 0,
#   'Computing': 0,
#   'Research': 1,
#   'Lab.': 0,
#   'Linda': 0,
#   'Fresques': 0,
#   'CRL': 0,
#   'coordinated': 0,
#   'refereeing': 0,
#   'process.': 1,
#   'I': 43,
#   'would': 4,
#   'like': 1,
#   'express': 0,
#   'gratitude': 0,
#   'appreciation': 0,
#   'fthe': 0,
#   'Program': 0,
#   'Committee': 0,
#   'members': 0,
#   'responsible': 0,
#   'six': 0,
#   'areas:': 0,
#   'Lynn': 0,
#   'Carlson,': 0,
#   'Tools': 0,
#   'Resources': 0,
#   'Developing': 0,
#   'NLP': 0,
#   'Systems': 1,
#   'Subcommittee': 0,
#   'Eduard': 0,
#   'Hovy,': 0,
#   'Integrated': 0,
#   'Richard': 0,
#   'Kittredge,': 0,
#   'Multilingual': 0,
#   'Text': 2,
#   'Ray': 0,
#   'Perrault,': 0,
#   'Spoken': 0,
#   'Oliviero': 0,
#   'Stock,': 0,
#   'Monolingual': 0,
#   'John': 1,
#   'White,': 0,
#   'Evaluation': 1,
#   'following': 3,
#   'colleagues': 0,
#   'Doug': 1,
#   'Appelt': 0,
#   'Fabio': 0,
#   'Ciravegna': 0,
#   'Robert': 0,
#   'Dale': 0,
#   'Michael': 1,
#   'Elhadad': 0,
#   'Ralph': 0,
#   'G-rishman': 0,
#   'Lynette': 0,
#   'Hirschman': 0,
#   'Yuval': 0,
#   'Krymolowski': 0,
#   'Inderjeet': 0,
#   'Mani': 0,
#   'Zvi': 0,
#   'Marx': 0,
#   'Martha': 0,
#   'Palmer': 0,
#   'Harold': 0,
#   'Somers': 0,
#   'Toshiyuki': 0,
#   'Takezawa': 0,
#   'Takehito': 0,
#   'Utsuro': 0,
#   'Dekai': 0,
#   'Wu': 0,
#   'bulk': 0,
#   'reviewing:': 0,
#   'Igor': 0,
#   'Boguslavsky': 0,
#   'Jim': 0,
#   'Cowie': 0,
#   'Dowding': 0,
#   'Glass': 0,
#   'Jan': 6,
#   'Haji~': 5,
#   'Pierre': 0,
#   'IsabeIIe': 0,
#   'Alberto': 0,
#   'Lavelli': 0,
#   'Daniel': 1,
#   'Marcu': 0,
#   'David': 0,
#   'McDonald': 0,
#   'Owen': 0,
#   'Rainbow': 0,
#   'Tomek': 0,
#   'Strzalkowski': 0,
#   'Kathryn': 0,
#   'B.': 0,
#   'Taylor': 0,
#   'Pick': 0,
#   'Vossen': 0,
#   'R6mi': 0,
#   'Zajac': 0,
#   'Carter': 0,
#   'Ido': 0,
#   'Dagan': 0,
#   'Andreas': 0,
#   'Eiscle': 0,
#   'Oren': 1,
#   'Glikman': 0,
#   'Donna': 0,
#   'Harman': 0,
#   'Tanya': 0,
#   'Korelsky': 0,
#   'Chin-Yew': 0,
#   'Lin': 0,
#   'Paul': 0,
#   'Martin': 0,
#   'Teruko': 0,
#   'Mitamura': 0,
#   'Norbert': 0,
#   'Reithinger': 0,
#   'Beth': 0,
#   'Sundheim': 0,
#   'Hans': 0,
#   'Uszkoreit': 0,
#   'Weischedel': 0,
#   'We': 2,
#   'believe': 0,
#   'quality': 4,
#   'elected': 1,
#   'israther': 0,
#   'high': 5,
#   'hope': 1,
#   'conference': 1,
#   'success.': 0,
#   'Sergei': 0,
#   'Nirenburg': 0,
#   'Chair,': 0,
#   'ANLP-2000': 0,
#   'ANLPi': 0,
#   'Table': 0,
#   'Contents': 0,
#   'Section': 0,
#   '1:': 2,
#   '(ANLP)': 0,
#   'Preface': 0,
#   'List': 0,
#   'Reviewers': 0,
#   'Nirenburg,': 0,
#   'Chair': 0,
#   '...............................................................': 0,
#   'BusTUC--A': 0,
#   'Bus': 0,
#   'Route': 0,
#   'Oracle': 0,
#   'Tore': 0,
#   'Amble': 0,
#   '..............................................................................................................................': 0,
#   '1': 66,
#   'Machine': 4,
#   'Translation': 5,
#   'Very': 1,
#   'Close': 1,
#   'Languages': 3,
#   'Haji~,': 4,
#   'Hric,': 0,
#   'Vladislav': 2,
#   'Kubofi': 2,
#   '.......................................................................................': 0,
#   '7': 11,
#   'Cross-Language': 0,
#   'Multimedia': 0,
#   'Information': 0,
#   'Retrieval': 0,
#   'Sharon': 0,
#   'Flank': 0,
#   '..........................................................................................................................': 0,
#   '13': 1,
#   'Automatic': 0,
#   'Construction': 0,
#   'Parallel': 0,
#   'English-Chinese': 0,
#   'Corpus': 0,
#   'Jiang': 0,
#   'Chen,': 0,
#   'Jian-Yun': 0,
#   'Nie': 0,
#   '......................................................................................................': 0,
#   '21': 3,
#   'PartslD:': 0,
#   'A': 53,
#   'Dialogue-Based': 0,
#   'System': 4,
#   'Identifying': 0,
#   'Parts': 0,
#   'Medical': 0,
#   'Amit': 0,
#   'Bagga,': 0,
#   'Strzalkowski,': 0,
#   'G.': 0,
#   'Bowden': 0,
#   'Wise': 0,
#   '...........................................................': 0,
#   '29': 0,
#   'Using': 2,
#   'Dialogue': 0,
#   'Participants': 0,
#   'Setsuo': 0,
#   'Yamada,': 0,
#   'Eiichiro': 0,
#   'Sumita,': 0,
#   'Hideki': 0,
#   'Kashioka': 0,
#   '..............................................................': 0,
#   '37': 0,
#   'Distilling': 0,
#   'Dialogues--A': 0,
#   'Method': 0,
#   'Corpora': 0,
#   'Development': 0,
#   'Arne': 0,
#   'J6nsson,': 0,
#   'Nils': 0,
#   'Dahlb~ick': 0,
#   '.................................................................................................': 0,
#   '44': 0,
#   'Plan-Based': 0,
#   'Management': 0,
#   'ina': 14,
#   'Physics': 0,
#   'Tour': 0,
#   'Reva': 0,
#   'Freedman': 0,
#   '......................................................................................................................': 0,
#   '52': 0,
#   'Framework': 0,
#   'MT': 17,
#   'NLG': 0,
#   'Based': 0,
#   'Uniform': 0,
#   'Lexico-Structural': 0,
#   'Benoit': 0,
#   'Lavoie,': 0,
#   'Korelsky,': 0,
#   'Rambow': 0,
#   '...................................': 0,
#   '60': 0,
#   "Talk'N'Travel:": 0,
#   'Conversational': 0,
#   'Air': 0,
#   'Travel': 0,
#   'Planning': 0,
#   'Stallard': 0,
#   '........................................................................................................................': 0,
#   '68': 0,
#   'REES:': 0,
#   'Large-Scale': 0,
#   'Relation': 0,
#   'Event': 0,
#   'Extraction': 0,
#   'Chinatsu': 0,
#   'Aone,': 0,
#   'Mila': 0,
#   'Ramos-Santacruz': 0,
#   '.................................................................................': 0,
#   '76': 0,
#   'Experiments': 0,
#   'Sentence': 0,
#   'Boundary': 0,
#   'Detection': 0,
#   'Mark': 0,
#   'Stevenson,': 0,
#   'Gaizauskas': 0,
#   '.....................................................................................': 0,
#   '84': 0,
#   'DP:': 0,
#   'Detector': 0,
#   'Presuppositions': 0,
#   'Survey': 0,
#   'Questions': 0,
#   'Katja': 0,
#   'Wiemer-Hastings,': 0,
#   'Peter': 0,
#   'Sonya': 0,
#   'Rajan,': 0,
#   'Art': 0,
#   'Graesser,': 0,
#   'Roger': 0,
#   'Kreuz,': 0,
#   'Ashish': 0,
#   'Karnavat': 0,
#   '..............................................................................................': 0,
#   '90': 7,
#   'ANLPiii': 0,
#   'MIMIC:': 0,
#   'An': 5,
#   'Adaptive': 0,
#   'Mixed': 0,
#   'Initiative': 0,
#   'Queries': 0,
#   'Jennifer': 0,
#   'Chu-Carroll': 0,
#   '..............................................................................................................': 0,
#   '97': 0,
#   'Javox:': 0,
#   'Toolkit': 0,
#   'Building': 1,
#   'Speech-Enabled': 0,
#   'Applications': 0,
#   'S.': 0,
#   'Fulkerson,': 0,
#   'Alan': 0,
#   'W.': 0,
#   'Biermann': 0,
#   '...........................................................................': 0,
#   '105': 0,
#   'Compact': 0,
#   'Architecture': 0,
#   'Scripts': 0,
#   'Meta-Outputs': 0,
#   'Manny': 0,
#   'Rayner,': 0,
#   'Ann': 1,
#   'Hockey,': 0,
#   'Frankie': 0,
#   'James': 0,
#   '112': 0,
#   'Representation': 0,
#   'Complex': 0,
#   'Evolving': 0,
#   'Data': 0,
#   'Dependencies': 0,
#   'Generation': 0,
#   'C.': 0,
#   'Mellish,': 0,
#   'R.': 0,
#   'Evans,': 0,
#   'L.': 0,
#   'Cahill,': 0,
#   'Doran,': 0,
#   'D.': 0,
#   'Paiva,': 0,
#   'M.': 0,
#   'Reape,': 0,
#   'Scott,': 0,
#   'N.': 1,
#   'Tipper': 0,
#   '.............................................................................': 0,
#   '119': 0,
#   'Reviser:': 0,
#   'TransCheck': 0,
#   'Jean-Marc': 0,
#   'Jutras': 0,
#   '..................................................................................................................': 0,
#   '127': 0,
#   'Unit': 0,
#   'Completion': 0,
#   'Computer-Aided': 0,
#   'Typing': 0,
#   'Philippe': 0,
#   'Langlais,': 0,
#   'George': 0,
#   'Foster,': 0,
#   'Guy': 0,
#   'Lapalme': 0,
#   '.................................................................': 0,
#   '135': 0,
#   'Coreference': 0,
#   'Resolution': 0,
#   'Sanda': 0,
#   'Harabagiu,': 0,
#   'Steven': 0,
#   'J.': 1,
#   'Maiorano': 0,
#   '142': 0,
#   'Ranking': 0,
#   'Suspected': 0,
#   'Answers': 0,
#   'Predictive': 0,
#   'Annotation': 0,
#   'Dragomir': 0,
#   'Radev,': 0,
#   'Prager,': 0,
#   'Valerie': 0,
#   'Samn': 0,
#   '150': 0,
#   'Message': 0,
#   'Classification': 0,
#   'Call': 0,
#   'Center': 0,
#   'Stephan': 0,
#   'Busemann,': 0,
#   'Sven': 0,
#   'Schmeier,': 0,
#   'Roman': 0,
#   'Arens': 0,
#   '.......................................................': 0,
#   '158': 0,
#   'Question': 0,
#   'Answering': 0,
#   'Supported': 0,
#   'Rohini': 0,
#   'Srihari,': 0,
#   'Wei': 0,
#   'Li': 1,
#   '........................................................................................................': 0,
#   '166': 0,
#   'Categorizing': 0,
#   'Unknown': 0,
#   'Words:': 0,
#   'Decision': 0,
#   'Trees': 0,
#   'Identify': 0,
#   'Names': 0,
#   'Misspellings': 0,
#   'Janine': 0,
#   'Toole': 0,
#   '.........................................................................................................................': 0,
#   '173': 0,
#   'Examining': 0,
#   'Role': 0,
#   'Statistical': 0,
#   'Linguistic': 0,
#   'Knowledge': 0,
#   'Sources': 0,
#   'General-Knowledge': 0,
#   'Question-Answering': 0,
#   'Claire': 0,
#   'Cardie,': 0,
#   'Vincent': 0,
#   'Ng,': 0,
#   'Pierce,': 0,
#   'Chris': 1,
#   'Buckley': 0,
#   '....................................................': 0,
#   '180': 2,
#   'Extracting': 0,
#   'Molecular': 0,
#   'Binding': 0,
#   'Relationships': 0,
#   'Biomedical': 0,
#   'Thomas': 0,
#   'Rindflesch,': 0,
#   'Jayant': 0,
#   'V.': 0,
#   'Lawrence': 0,
#   'Hunter': 0,
# ...
#   'Dowding': 0,
#   'Glass': 0,
#   'Jan': 0,
#   'Haji~': 0,
#   'Pierre': 0,
#   'IsabeIIe': 0,
#   'Alberto': 0,
#   'Lavelli': 0,
#   'Daniel': 2,
#   'Marcu': 7,
#   'David': 1,
#   'McDonald': 0,
#   'Owen': 0,
#   'Rainbow': 0,
#   'Tomek': 0,
#   'Strzalkowski': 0,
#   'Kathryn': 0,
#   'B.': 0,
#   'Taylor': 0,
#   'Pick': 0,
#   'Vossen': 0,
#   'R6mi': 0,
#   'Zajac': 0,
#   'Carter': 0,
#   'Ido': 0,
#   'Dagan': 0,
#   'Andreas': 0,
#   'Eiscle': 0,
#   'Oren': 0,
#   'Glikman': 0,
#   'Donna': 0,
#   'Harman': 0,
#   'Tanya': 0,
#   'Korelsky': 0,
#   'Chin-Yew': 0,
#   'Lin': 2,
#   'Paul': 0,
#   'Martin': 0,
#   'Teruko': 0,
#   'Mitamura': 0,
#   'Norbert': 0,
#   'Reithinger': 0,
#   'Beth': 0,
#   'Sundheim': 0,
#   'Hans': 0,
#   'Uszkoreit': 0,
#   'Weischedel': 0,
#   'We': 21,
#   'believe': 0,
#   'quality': 1,
#   'elected': 1,
#   'israther': 0,
#   'high': 3,
#   'hope': 0,
#   'conference': 0,
#   'success.': 0,
#   'Sergei': 0,
#   'Nirenburg': 0,
#   'Chair,': 0,
#   'ANLP-2000': 0,
#   'ANLPi': 0,
#   'Table': 20,
#   'Contents': 0,
#   'Section': 4,
#   '1:': 2,
#   '(ANLP)': 0,
#   'Preface': 0,
#   'List': 1,
#   'Reviewers': 0,
#   'Nirenburg,': 0,
#   'Chair': 0,
#   '...............................................................': 1,
#   'BusTUC--A': 0,
#   'Bus': 0,
#   'Route': 0,
#   'Oracle': 0,
#   'Tore': 0,
#   'Amble': 0,
#   '..............................................................................................................................': 0,
#   '1': 258,
#   'Machine': 2,
#   'Translation': 2,
#   'Very': 0,
#   'Close': 0,
#   'Languages': 0,
#   'Haji~,': 0,
#   'Hric,': 0,
#   'Vladislav': 0,
#   'Kubofi': 0,
#   '.......................................................................................': 1,
#   '7': 75,
#   'Cross-Language': 0,
#   'Multimedia': 0,
#   'Information': 1,
#   'Retrieval': 0,
#   'Sharon': 0,
#   'Flank': 0,
#   '..........................................................................................................................': 0,
#   '13': 10,
#   'Automatic': 0,
#   'Construction': 0,
#   'Parallel': 0,
#   'English-Chinese': 0,
#   'Corpus': 1,
#   'Jiang': 0,
#   'Chen,': 0,
#   'Jian-Yun': 0,
#   'Nie': 0,
#   '......................................................................................................': 1,
#   '21': 3,
#   'PartslD:': 0,
#   'A': 176,
#   'Dialogue-Based': 0,
#   'System': 1,
#   'Identifying': 0,
#   'Parts': 0,
#   'Medical': 0,
#   'Amit': 0,
#   'Bagga,': 0,
#   'Strzalkowski,': 0,
#   'G.': 0,
#   'Bowden': 0,
#   'Wise': 0,
#   '...........................................................': 1,
#   '29': 5,
#   'Using': 0,
#   'Dialogue': 0,
#   'Participants': 0,
#   'Setsuo': 0,
#   'Yamada,': 0,
#   'Eiichiro': 0,
#   'Sumita,': 1,
#   'Hideki': 0,
#   'Kashioka': 0,
#   '..............................................................': 1,
#   '37': 5,
#   'Distilling': 0,
#   'Dialogues--A': 0,
#   'Method': 0,
#   'Corpora': 0,
#   'Development': 0,
#   'Arne': 0,
#   'J6nsson,': 0,
#   'Nils': 0,
#   'Dahlb~ick': 0,
#   '.................................................................................................': 1,
#   '44': 4,
#   'Plan-Based': 0,
#   'Management': 0,
#   'ina': 9,
#   'Physics': 0,
#   'Tour': 0,
#   'Reva': 0,
#   'Freedman': 0,
#   '......................................................................................................................': 0,
#   '52': 0,
#   'Framework': 0,
#   'MT': 6,
#   'NLG': 0,
#   'Based': 1,
#   'Uniform': 0,
#   'Lexico-Structural': 0,
#   'Benoit': 0,
#   'Lavoie,': 0,
#   'Korelsky,': 0,
#   'Rambow': 0,
#   '...................................': 3,
#   '60': 3,
#   "Talk'N'Travel:": 0,
#   'Conversational': 0,
#   'Air': 0,
#   'Travel': 0,
#   'Planning': 0,
#   'Stallard': 0,
#   '........................................................................................................................': 0,
#   '68': 0,
#   'REES:': 0,
#   'Large-Scale': 0,
#   'Relation': 7,
#   'Event': 0,
#   'Extraction': 0,
#   'Chinatsu': 0,
#   'Aone,': 0,
#   'Mila': 0,
#   'Ramos-Santacruz': 0,
#   '.................................................................................': 1,
#   '76': 3,
#   'Experiments': 1,
#   'Sentence': 10,
#   'Boundary': 0,
#   'Detection': 0,
#   'Mark': 0,
#   'Stevenson,': 0,
#   'Gaizauskas': 0,
#   '.....................................................................................': 1,
#   '84': 1,
#   'DP:': 0,
#   'Detector': 0,
#   'Presuppositions': 0,
#   'Survey': 0,
#   'Questions': 0,
#   'Katja': 0,
#   'Wiemer-Hastings,': 0,
#   'Peter': 0,
#   'Sonya': 0,
#   'Rajan,': 0,
#   'Art': 0,
#   'Graesser,': 0,
#   'Roger': 0,
#   'Kreuz,': 0,
#   'Ashish': 0,
#   'Karnavat': 0,
#   '..............................................................................................': 1,
#   '90': 3,
#   'ANLPiii': 0,
#   'MIMIC:': 0,
#   'An': 3,
#   'Adaptive': 0,
#   'Mixed': 0,
#   'Initiative': 0,
#   'Queries': 0,
#   'Jennifer': 0,
#   'Chu-Carroll': 0,
#   '..............................................................................................................': 1,
#   '97': 3,
#   'Javox:': 0,
#   'Toolkit': 0,
#   'Building': 0,
#   'Speech-Enabled': 0,
#   'Applications': 0,
#   'S.': 1,
#   'Fulkerson,': 0,
#   'Alan': 0,
#   'W.': 1,
#   'Biermann': 0,
#   '...........................................................................': 1,
#   '105': 0,
#   'Compact': 0,
#   'Architecture': 0,
#   'Scripts': 0,
#   'Meta-Outputs': 0,
#   'Manny': 0,
#   'Rayner,': 0,
#   'Ann': 0,
#   'Hockey,': 0,
#   'Frankie': 0,
#   'James': 0,
#   '112': 2,
#   'Representation': 0,
#   'Complex': 0,
#   'Evolving': 0,
#   'Data': 0,
#   'Dependencies': 0,
#   'Generation': 0,
#   'C.': 2,
#   'Mellish,': 0,
#   'R.': 0,
#   'Evans,': 0,
#   'L.': 0,
#   'Cahill,': 0,
#   'Doran,': 0,
#   'D.': 1,
#   'Paiva,': 0,
#   'M.': 1,
#   'Reape,': 0,
#   'Scott,': 0,
#   'N.': 1,
#   'Tipper': 0,
#   '.............................................................................': 1,
#   '119': 0,
#   'Reviser:': 0,
#   'TransCheck': 0,
#   'Jean-Marc': 0,
#   'Jutras': 0,
#   '..................................................................................................................': 1,
#   '127': 1,
#   'Unit': 8,
#   'Completion': 0,
#   'Computer-Aided': 0,
#   'Typing': 0,
#   'Philippe': 0,
#   'Langlais,': 0,
#   'George': 0,
#   'Foster,': 0,
#   'Guy': 0,
#   'Lapalme': 0,
#   '.................................................................': 1,
#   '135': 1,
#   'Coreference': 0,
#   'Resolution': 0,
#   'Sanda': 0,
#   'Harabagiu,': 0,
#   'Steven': 0,
#   'J.': 6,
#   'Maiorano': 0,
#   '142': 0,
#   'Ranking': 0,
#   'Suspected': 0,
#   'Answers': 0,
#   'Predictive': 0,
#   'Annotation': 0,
#   'Dragomir': 0,
#   'Radev,': 0,
#   'Prager,': 0,
#   'Valerie': 0,
#   'Samn': 0,
#   '150': 0,
#   'Message': 0,
#   'Classification': 0,
#   'Call': 0,
#   'Center': 0,
#   'Stephan': 0,
#   'Busemann,': 0,
#   'Sven': 0,
#   'Schmeier,': 0,
#   'Roman': 0,
#   'Arens': 0,
#   '.......................................................': 2,
#   '158': 0,
#   'Question': 0,
#   'Answering': 0,
#   'Supported': 0,
#   'Rohini': 0,
#   'Srihari,': 0,
#   'Wei': 5,
#   'Li': 3,
#   '........................................................................................................': 1,
#   '166': 0,
#   'Categorizing': 0,
#   'Unknown': 0,
#   'Words:': 0,
#   'Decision': 0,
#   'Trees': 0,
#   'Identify': 0,
#   'Names': 0,
#   'Misspellings': 0,
#   'Janine': 0,
#   'Toole': 0,
#   '.........................................................................................................................': 0,
#   '173': 0,
#   'Examining': 0,
#   'Role': 0,
#   'Statistical': 1,
#   'Linguistic': 2,
#   'Knowledge': 0,
#   'Sources': 0,
#   'General-Knowledge': 0,
#   'Question-Answering': 0,
#   'Claire': 0,
#   'Cardie,': 0,
#   'Vincent': 0,
#   'Ng,': 0,
#   'Pierce,': 0,
#   'Chris': 0,
#   'Buckley': 0,
#   '....................................................': 2,
#   '180': 0,
#   'Extracting': 0,
#   'Molecular': 0,
#   'Binding': 0,
#   'Relationships': 0,
#   'Biomedical': 0,
#   'Thomas': 0,
#   'Rindflesch,': 0,
#   'Jayant': 0,
#   'V.': 0,
#   'Lawrence': 0,
#   'Hunter': 0,
#   '................................................': 2,
#   '188': 0,
#   'Compound': 0,
#   'Noun': 0,
#   'Segmentation': 0,
#   'Lexical': 0,
#   'Extracted': 0,
#   'Juntae': 0,
#   'Yoon': 0,
#   '196': 0,
#   'Corpus-Based': 0,
#   'LFG': 0,
#   'Specialization': 0,
#   'Nicola': 0,
#   'Cancedda,': 0,
#   'Christer': 0,
#   'Samuelsson': 0,
#   '...............................................................................': 1,
#   '204': 0,
#   'Tool': 1,
#   'Automated': 0,
#   'Revision': 0,
#   'Grammars': 0,
#   'Nanda': 0,
#   'Kambhatla,': 0,
#   'Wlodek': 0,
#   'Zadrozny': 0,
#   '210': 0,
#   'ANLPiv': 0,
#   'Aggressive': 0,
#   'Morphology': 0,
#   'Robust': 0,
#   'Coverage': 0,
#   'William': 2,
#   'A.': 2,
#   'Woods': 0,
#   '...............................................................................................................': 1,
#   '218': 0,
#   'TnT--A': 0,
#   'Part-of-Speech': 0,
#   'Tagger': 0,
#   'Thorsten': 0,
#   'Brants': 0,
#   '...................................................................................................................': 1,
#   '224': 0,
#   'Independent': 7,
#   'Morphological': 0,
#   'Analysis': 0,
#   'Tatsuo': 0,
#   'Yamashita,': 0,
#   'Yuji': 0,
#   'Matsumoto': 0,
#   '....................................................................................': 1,
#   '232': 0,
#   'Divide-and-Conquer': 0,
#   'Strategy': 0,
#   'Shallow': 0,
#   'Parsing': 0,
#   'German': 0,
#   'Free': 0,
#   'Texts': 0,
#   'Giinter': 0,
#   'Neumann,': 0,
#   'Christian': 0,
#   'Braun,': 0,
#   'Jakub': 0,
#   'Piskorski': 0,
#   '239': 0,
#   'Hybrid': 0,
#   'Approach': 0,
#   'Named': 0,
#   'Entity': 0,
#   'Sub-Type': 0,
#   'Tagging': 2,
#   'Cheng': 0,
#   'Niu,': 0,
#   '......................................................................................': 1,
#   '247': 0,
#   'Spelling': 0,
#   'Grammar': 0,
#   'Correction': 0,
#   'Danish': 0,
#   'SCARRIE': 0,
#   'Patrizia': 0,
#   'Paggio': 0,
#   '.....................................................................................................................': 0,
#   '255': 0,
#   'Can': 0,
#   'Improve': 0,
#   'Woods,': 0,
#   'Bookman,': 0,
#   'Houston,': 0,
#   'Kuhns,': 0,
#   'Martin,': 0,
#   'Stephen': 0,
#   'Green': 0,
#   '262': 0,
#   'Domain-Specific': 0,
#   'Acquisition': 0,
#   'Dan': 3,
#   'Moldovan,': 0,
#   'Roxana': 0,
#   'Girju,': 0,
#   'Vasile': 0,
#   'Rus': 0,
#   '..........................................................................': 1,
#   '268': 0,
#   'Controlled': 0,
#   'Vocabulary': 0,
#   'Indexing': 0,
#   'Entities': 0,
#   'Wasson': 0,
#   '.......................................................................................................................': 0,
#   '276': 1,
#   'Unsupervised': 0,
#   'Discovery': 0,
#   'Scenario-Level': 0,
#   'Patterns': 0,
#   'Yangarber,': 0,
#   'Grishman,': 0,
#   'Pasi': 0,
#   'Tapanainen,': 0,
#   'Silja': 0,
#   'Huttunen': 0,
#   '..............................': 3,
#   '282': 0,
#   'Corpus-Derived': 0,
#   'Name': 0,
#   'Lists': 0,
#   'Recognition': 0,
#   '...................................................................................': 1,
#   '290': 0,
#   'Answer': 0,
#   'Abney,': 0,
#   'Collins,': 0,
#   'Singhal': 0,
#   '....................................................................': 1,
#   '296': 0,
#   'Automatically': 0,
#   'Identified': 0,
#   'Index': 0,
#   'Terms': 0,
#   'Browsing': 0,
#   'Electronic': 0,
#   'Documents': 0,
#   'Nina': 0,
#   'Wacholder,': 0,
#   'Judith': 0,
#   'Klavans,': 0,
#   'K.': 1,
#   'Evans': 0,
#   '.........................................................': 2,
#   '302': 0,
#   'Reduction': 0,
#   'Summarization': 0,
#   'Hongyan': 0,
#   'Jing': 0,
#   '310': 0,
#   'Noisy': 0,
#   'Input:': 0,
#   'Speech': 0,
#   'OCR': 0,
#   'Miller,': 0,
#   'Sean': 0,
#   'Boisen,': 0,
#   'Schwartz,': 0,
#   'Rebecca': 0,
#   'Stone,': 0,
#   '...........': 12,
#   '316': 0,
#   'Improving': 0,
#   'Testsuites': 0,
#   'via': 0,
#   'Instrumentation': 0,
#   'Br6ker': 0,
#   '325': 0,
#   'Efficiency': 0,
#   'Multimodal': 0,
#   'Interaction': 0,
#   'Map-Based': 0,
#   'Task': 0,
#   'Philip': 0,
#   'Cohen,': 0,
#   'McGee,': 0,
#   'Josh': 0,
#   'Clow': 0,
#   '................................................................': 1,
#   '331': 0,
#   'ANLPv': 0,
#   'BusTUC': 0,
#   'natura': 7,
#   'l': 1057,
#   'anguage': 21,
#   'bus': 0,
#   'route': 0,
#   'rac': 8,
#   'le': 198,
#   'Dept.': 0,
#   'computer': 0,
#   'information': 12,
#   'science': 0,
#   'University': 2,
#   'Trondheim': 0,
#   'N-7491': 0,
#   'amble@idi,': 0,
#   'ntnu.': 0,
#   'Abstract': 0,
#   'paper': 1,
#   'describes': 0,
#   'natural': 7,
#   'based': 9,
#   'expert': 0,
#   'system': 9,
#   'advisor': 0,
#   'public': 2,
#   'transport': 0,
#   'Trondheim,': 0,
#   'Norway.': 0,
#   'available': 1,
#   'Internet,and': 0,
#   'intstalled': 0,
#   'com-': 0,
#   "pany's": 0,
#   'web': 0,
#   'server': 0,
#   'since': 0,
#   'beginning': 1,
#   '1999.': 2,
#   'bilingual,': 0,
#   'relying': 0,
#   'internal': 1,
#   'independent': 1,
#   'logic': 0,
#   'representation.': 0,
#   'Introduct': 0,
#   'ion': 226,
#   'database': 0,
#   'provides': 0,
#   'users': 0,
#   'capability': 0,
#   'obtaining': 0,
#   'in-': 4,
#   'formation': 13,
#   'stored': 0,
#   'querying': 0,
#   'language': 20,
#   '(NL).': 0,
#   'With': 0,
#   'means': 0,
#   'communication': 0,
#   'puter': 2,
#   'system,': 0,
#   'make': 2,
#   'question': 0,
#   'statement': 0,
#   'way': 8,
#   'normally': 0,
#   'think': 0,
#   'discussed,': 0,
#   'freeing': 0,
#   'hav-': 0,
#   'ing': 126,
#   'know': 2,
#   'stores': 0,
#   'processes': 0,
#   'information.': 0,
#   'present': 7,
#   'implementation': 0,
#   'represents': 0,
#   'major': 1,
#   'effort': 0,
#   'bringing': 0,
#   'practical': 0,
#   'use.': 1,
#   'answer': 0,
#   'queries': 0,
#   'routes,': 0,
#   'stated': 0,
#   'texts,': 1,
#   'made': 3,
#   'Internet': 0,
#   'World': 0,
#   'Wide': 0,
#   'Web': 0,
#   'http': 1,
#   '//www.': 1,
#   'idi.': 0,
#   'no/bustuc/).': 0,
#   'small': 1,
#   'city': 0,
#   'university': 0,
#   '140000': 0,
#   'inhabitants.': 0,
#   'Its': 0,
#   'central': 0,
#   'systems': 4,
#   '42': 3,
#   'lines,': 0,
#   'serving': 0,
#   '590': 0,
#   'stations,': 0,
#   '1900': 0,
#   'depar-': 0,
#   'tures': 28,
#   'per': 55,
#   'day': 0,
#   '(in': 2,
#   'average).': 0,
#   'That': 2,
#   'gives': 0,
#   'approximately': 0,
#   '60000': 0,
#   'scheduled': 0,
#   'station': 0,
#   'passings': 0,
#   'day,': 0,
#   'somehow': 0,
#   'represented': 1,
#   'data': 4,
#   'base.': 0,
#   'starting': 1,
#   'point': 3,
#   'automate': 0,
#   'function': 2,
#   'agent.': 0,
#   'example': 10,
#   'response': 0,
#   'using': 10,
#   'actual': 0,
#   'request': 0,
#   'telephone': 0,
#   'local': 0,
#   'company:': 0,
#   'Hi,': 0,
#   'live': 0,
#   'Nidarvoll': 0,
#   'tonight': 0,
#   'must': 0,
#   'reach': 0,
#   'train': 5,
#   'Oslo': 0,
#   'oclock.': 0,
#   'typical': 1,
#   'follow': 5,
#   'quickly:': 0,
#   'number': 11,
#   '54': 1,
#   'passes': 0,
#   'skole': 0,
#   '1710': 0,
#   'arrives': 0,
#   'Railway': 0,
#   'Station': 0,
#   '1725.': 0,
#   'In': 37,
#   'pro-': 1,
#   'cess': 6,
#   'lexical': 0,
#   'analysis,': 0,
#   'syntax': 0,
#   'semantic': 4,
#   'pragmatic': 0,
#   'reasoning': 0,
#   'query': 0,
#   'processing.': 0,
#   'One': 0,
#   'could': 2,
#   'argue': 0,
#   'content': 0,
#   'solved': 0,
#   'interrogation,': 0,
#   'whereby': 0,
#   'customer': 0,
#   'asked': 0,
#   'produce': 2,
#   '4': 136,
#   'items:': 0,
#   'ta': 104,
#   'departure,': 0,
#   'arrival,': 0,
#   'earliest': 0,
#   'departure': 0,
#   'timeand/or': 0,
#   'latest': 0,
#   'arrival': 0,
#   'time.': 2,
#   'It': 0,
#   'myth': 0,
#   'better': 7,
#   '"natural': 0,
#   'language".': 0,
#   'challenge': 0,
#   'prove': 5,
#   'demonstration': 0,
#   'NL': 0,
#   'preferred': 1,
#   'interrogative': 0,
#   'mode.': 0,
#   'To': 6,
#   'that,': 4,
#   'correct,': 0,
#   'user': 0,
#   'friendly': 0,
#   'almost': 0,
#   'complete': 0,
#   'within': 1,
#   'domain.': 0,
#   'Previous': 0,
#   'Efforts,': 0,
#   'CHAT-80,': 0,
#   'PRAT-89': 0,
#   'HSQL': 0,
#   'called': 0,
#   'built': 9,
#   'upon': 0,
#   'clas-': 1,
#   'sical': 0,
#   'CHAT-80': 0,
#   '(Warren': 0,
#   'Pereira,': 0,
#   '1982).': 0,
#   'state': 0,
#   'art': 8,
#   'sys-': 1,
#   'tem': 15,
#   'impressive': 0,
#   'merits,': 0,
#   'also': 11,
#   'established': 0,
#   'Prolog': 0,
#   'viable': 0,
#   'competitive': 0,
#   'lan-': 0,
#   'guage': 21,
#   'Artificial': 0,
#   'Intelligence': 0,
#   'general.': 0,
#   'brilliant': 0,
#   'masterpiece': 0,
#   'software,': 0,
#   'efficient': 0,
#   'sophisticated.': 0,
#   'connected': 0,
#   'international': 0,
#   'geography.': 0,
#   'analysed': 0,
#   'answered': 0,
#   'split': 0,
#   'second:': 0,
#   'Which': 0,
#   'country': 0,
#   'bordering': 0,
#   'Mediterranean': 0,
#   'borders': 0,
#   'bordered': 0,
#   'whose': 5,
#   'population': 2,
#   'exceeds': 0,
#   ...}}

# %%
x = tfidf_corpus(v, tf, i, d)   #Tf-Idf find by the formula as given on internet
x
# Out:
# {0: {'Association': 1.2129937233341985,
#   'Computational': 0.543142325026529,
#   'Linguistics': 1.5025003405291832,
#   '6': 6.791965256446561,
#   'th': 55.324843083354956,
#   'Applied': 2.7009944941682664,
#   'Natural': 1.7524862354206658,
#   'Language': 2.2154452854245803,
#   'Processing': 5.437314206251696,
#   'Conference': 0.6389811700025954,
#   'Proceedings': 0.11783649029385809,
#   'April': 4.672425341971495,
#   '29--May': 4.672425341971495,
#   '4,': 1.584962500721156,
#   '2000': 11.460281679655566,
#   'Seattle,': 3.6724253419714956,
#   'Washington,': 1.765534746362977,
#   'USA': 2.350497247084133,
#   'ANLP': 40.39667876168645,
#   '2000-PREFACE': 4.672425341971495,
#   '131': 4.087462841250339,
#   'papers': 23.362126709857478,
#   'submitted': 8.595211259741674,
#   'ANLP-2000.': 5.672425341971495,
#   '46': 4.087462841250339,
#   'accepted': 2.5025003405291835,
#   'presentation': 6.174925682500679,
#   'conference.': 4.087462841250339,
#   'Papers': 5.672425341971495,
#   'came': 6.700994494168266,
#   '24': 8.595211259741674,
#   'countries:': 5.672425341971495,
#   'fifty': 4.087462841250339,
#   'eight': 4.700994494168266,
#   'United': 5.005000681058367,
#   'States': 3.0874628412503395,
#   'America,': 5.672425341971495,
#   'eleven': 4.672425341971495,
#   'Germany': 3.6724253419714956,
#   'Kingdom,': 5.672425341971495,
#   'nine': 7.344850683942991,
#   'Canada,': 2.350497247084133,
#   'Japan,': 4.672425341971495,
#   'four': 2.0571383043935416,
#   'Italy': 5.672425341971495,
#   'Spain,': 5.672425341971495,
#   'three': 0.35049724708413316,
#   'ach': 29.379402735771965,
#   'France,': 4.087462841250339,
#   'Korea': 5.672425341971495,
#   'Switzerland,': 5.672425341971495,
#   'two': 0.02856915219677092,
#   'Australia,': 4.672425341971495,
#   'China,': 5.672425341971495,
#   'The': 0.1428457609838546,
#   'Netherlands': 5.672425341971495,
#   'Sweden': 5.672425341971495,
#   'one': 0.1731464935688623,
#   'Czech': 4.087462841250339,
#   'Republic,': 4.672425341971495,
#   'Denmark,': 4.087462841250339,
#   'Finland,': 4.672425341971495,
#   'Greece,': 5.672425341971495,
#   'India,': 5.672425341971495,
#   'Hong': 8.174925682500678,
#   'Kong,': 5.672425341971495,
#   'Malaysia,': 4.672425341971495,
#   'Norway,': 4.672425341971495,
#   'Russia': 5.672425341971495,
#   'Taiwan.': 5.672425341971495,
#   '40': 2.5025003405291835,
#   'industry.': 4.672425341971495,
#   '85': 3.0874628412503395,
#   'academia.': 5.672425341971495,
#   '2': 1.9046114292574854,
#   'government': 3.0874628412503395,
#   'organizations': 4.087462841250339,
#   'submissions': 4.672425341971495,
#   'combined.': 4.087462841250339,
#   'reviewing': 11.34485068394299,
#   'process': 1.436458063169241,
#   'supported': 1.5025003405291832,
#   'web-based': 4.672425341971495,
#   'reviewer': 5.672425341971495,
#   'interface': 2.2129937233341983,
#   'developed': 0.6724253419714956,
#   'Elisha': 5.672425341971495,
#   'Kane': 4.672425341971495,
#   'New': 0.8650704199138914,
#   'Mexico': 4.087462841250339,
#   'State': 4.174925682500679,
#   "University's": 5.672425341971495,
#   'Computing': 2.2129937233341983,
#   'Research': 0.765534746362977,
#   'Lab.': 5.672425341971495,
#   'Linda': 4.672425341971495,
#   'Fresques': 4.672425341971495,
#   'CRL': 5.672425341971495,
#   'coordinated': 5.672425341971495,
#   'refereeing': 5.672425341971495,
#   'process.': 1.6724253419714956,
#   'I': 7.8771387926207295,
#   'would': 0.0874628412503394,
#   'like': 0.38702312310924725,
#   'express': 2.350497247084133,
#   'gratitude': 4.672425341971495,
#   'appreciation': 5.672425341971495,
#   'fthe': 5.672425341971495,
#   'Program': 8.595211259741674,
#   'Committee': 12.262388523751017,
#   'members': 3.6724253419714956,
#   'responsible': 2.5025003405291835,
#   'six': 2.6724253419714956,
#   'areas:': 5.672425341971495,
#   'Lynn': 4.087462841250339,
#   'Carlson,': 4.672425341971495,
#   'Tools': 3.6724253419714956,
#   'Resources': 3.0874628412503395,
#   'Developing': 3.6724253419714956,
#   'NLP': 21.035004767408566,
#   'Systems': 13.379402735771965,
#   'Subcommittee': 34.03455205182897,
#   'Eduard': 5.672425341971495,
#   'Hovy,': 4.672425341971495,
#   'Integrated': 3.6724253419714956,
#   'Richard': 7.0514917412523985,
#   'Kittredge,': 9.34485068394299,
#   'Multilingual': 8.595211259741674,
#   'Text': 6.171414913180625,
#   'Ray': 9.34485068394299,
#   'Perrault,': 5.672425341971495,
#   'Spoken': 4.700994494168266,
#   'Oliviero': 5.672425341971495,
#   'Stock,': 4.672425341971495,
#   'Monolingual': 5.672425341971495,
#   'John': 5.017276025914487,
#   'White,': 4.087462841250339,
#   'Evaluation': 3.169925001442312,
#   'following': 0.2801079191927352,
#   'colleagues': 3.0874628412503395,
#   'Doug': 3.6724253419714956,
#   'Appelt': 3.6724253419714956,
#   'Fabio': 4.672425341971495,
#   'Ciravegna': 5.672425341971495,
#   'Robert': 11.460281679655566,
#   'Dale': 5.672425341971495,
#   'Michael': 7.507501021587551,
#   'Elhadad': 5.672425341971495,
#   'Ralph': 12.349851365001358,
#   'G-rishman': 5.672425341971495,
#   'Lynette': 4.087462841250339,
#   'Hirschman': 4.672425341971495,
#   'Yuval': 4.672425341971495,
#   'Krymolowski': 5.672425341971495,
#   'Inderjeet': 4.087462841250339,
#   'Mani': 5.672425341971495,
#   'Zvi': 4.672425341971495,
#   'Marx': 5.672425341971495,
#   'Martha': 4.672425341971495,
#   'Palmer': 3.350497247084133,
#   'Harold': 5.672425341971495,
#   'Somers': 5.672425341971495,
#   'Toshiyuki': 4.087462841250339,
#   'Takezawa': 4.672425341971495,
#   'Takehito': 4.672425341971495,
#   'Utsuro': 5.672425341971495,
#   'Dekai': 4.087462841250339,
#   'Wu': 3.6724253419714956,
#   'bulk': 5.672425341971495,
#   'reviewing:': 5.672425341971495,
#   'Igor': 5.672425341971495,
#   'Boguslavsky': 5.672425341971495,
#   'Jim': 8.174925682500678,
#   'Cowie': 5.672425341971495,
#   'Dowding': 5.672425341971495,
#   'Glass': 4.672425341971495,
#   'Jan': 13.401988988336532,
#   'Haji~': 8.174925682500678,
#   'Pierre': 4.087462841250339,
#   'IsabeIIe': 5.672425341971495,
#   'Alberto': 4.672425341971495,
#   'Lavelli': 5.672425341971495,
#   'Daniel': 3.6724253419714956,
#   'Marcu': 4.672425341971495,
#   'David': 8.49095606333939,
#   'McDonald': 4.087462841250339,
#   'Owen': 8.174925682500678,
#   'Rainbow': 5.672425341971495,
#   'Tomek': 9.34485068394299,
#   'Strzalkowski': 9.34485068394299,
#   'Kathryn': 5.672425341971495,
#   'B.': 1.42449782852791,
#   'Taylor': 4.672425341971495,
#   'Pick': 4.087462841250339,
#   'Vossen': 5.672425341971495,
#   'R6mi': 5.672425341971495,
#   'Zajac': 5.672425341971495,
#   'Carter': 4.672425341971495,
#   'Ido': 3.6724253419714956,
#   'Dagan': 4.087462841250339,
#   'Andreas': 4.672425341971495,
#   'Eiscle': 5.672425341971495,
#   'Oren': 4.672425341971495,
#   'Glikman': 5.672425341971495,
#   'Donna': 4.672425341971495,
#   'Harman': 4.087462841250339,
#   'Tanya': 9.34485068394299,
#   'Korelsky': 9.34485068394299,
#   'Chin-Yew': 5.672425341971495,
#   'Lin': 23.362126709857478,
#   'Paul': 5.730140839827783,
#   'Martin': 6.174925682500679,
#   'Teruko': 4.672425341971495,
#   'Mitamura': 4.672425341971495,
#   'Norbert': 11.34485068394299,
#   'Reithinger': 5.672425341971495,
#   'Beth': 8.174925682500678,
#   'Sundheim': 5.672425341971495,
#   'Hans': 3.6724253419714956,
#   'Uszkoreit': 4.672425341971495,
#   'Weischedel': 7.344850683942991,
#   'We': 0.1428457609838546,
#   'believe': 1.8650704199138914,
#   'quality': 1.5025003405291832,
#   'elected': 3.6724253419714956,
#   'israther': 5.672425341971495,
#   'high': 0.7182290315846205,
#   'hope': 3.350497247084133,
#   'conference': 7.344850683942991,
#   'success.': 5.672425341971495,
#   'Sergei': 11.34485068394299,
#   'Nirenburg': 11.34485068394299,
#   'Chair,': 5.672425341971495,
#   'ANLP-2000': 11.34485068394299,
#   'ANLPi': 22.68970136788598,
#   'Table': 0.8650704199138914,
#   'Contents': 4.672425341971495,
#   'Section': 0.9719856238304033,
#   '1:': 0.5025003405291834,
#   '(ANLP)': 5.672425341971495,
#   'Preface': 4.672425341971495,
#   'List': 6.174925682500679,
#   'Reviewers': 4.672425341971495,
#   'Nirenburg,': 5.672425341971495,
#   'Chair': 9.34485068394299,
#   '...............................................................': 209.87973765294532,
#   'BusTUC--A': 5.672425341971495,
#   'Bus': 14.017276025914486,
#   'Route': 5.672425341971495,
#   'Oracle': 5.672425341971495,
#   'Tore': 4.672425341971495,
#   'Amble': 4.672425341971495,
#   '..............................................................................................................................': 5.672425341971495,
#   '1': 2.2740338725088245,
#   'Machine': 1.765534746362977,
#   'Translation': 6.262388523751019,
#   'Very': 2.2129937233341983,
#   'Close': 3.6724253419714956,
#   'Languages': 3.6724253419714956,
#   'Haji~,': 4.087462841250339,
#   'Hric,': 5.672425341971495,
#   'Vladislav': 3.6724253419714956,
#   'Kubofi': 4.672425341971495,
#   '.......................................................................................': 93.44850683942991,
#   '7': 7.775884990643227,
#   'Cross-Language': 9.34485068394299,
#   'Multimedia': 4.087462841250339,
#   'Information': 4.396218558291295,
#   'Retrieval': 5.595211259741674,
#   'Sharon': 3.6724253419714956,
#   'Flank': 4.672425341971495,
#   '..........................................................................................................................': 11.34485068394299,
#   '13': 7.507501021587551,
#   'Automatic': 6.010001362116733,
#   'Construction': 4.672425341971495,
#   'Parallel': 4.087462841250339,
#   'English-Chinese': 4.672425341971495,
#   'Corpus': 7.062138985451908,
#   'Jiang': 5.672425341971495,
#   'Chen,': 3.350497247084133,
#   'Jian-Yun': 5.672425341971495,
#   'Nie': 5.672425341971495,
#   '......................................................................................................': 90.75880547154392,
#   '21': 7.507501021587551,
#   'PartslD:': 4.672425341971495,
#   'A': 2.114117262561048,
#   'Dialogue-Based': 4.087462841250339,
#   'System': 16.457106435148333,
#   'Identifying': 2.5025003405291835,
#   'Parts': 8.174925682500678,
#   'Medical': 3.6724253419714956,
#   'Amit': 8.174925682500678,
#   'Bagga,': 4.672425341971495,
#   'Strzalkowski,': 4.087462841250339,
#   'G.': 2.5602158383854703,
#   'Bowden': 4.672425341971495,
#   'Wise': 5.672425341971495,
#   '...........................................................': 272.27641641463174,
#   '29': 11.460281679655566,
#   'Using': 3.591145157923102,
#   'Dialogue': 18.803977976673064,
#   'Participants': 4.087462841250339,
#   'Setsuo': 4.672425341971495,
#   'Yamada,': 4.672425341971495,
#   'Eiichiro': 4.672425341971495,
#   'Sumita,': 4.672425341971495,
#   'Hideki': 4.672425341971495,
#   'Kashioka': 4.672425341971495,
#   '..............................................................': 221.2245883368883,
#   '37': 2.6724253419714956,
#   'Distilling': 4.672425341971495,
#   'Dialogues--A': 5.672425341971495,
#   'Method': 2.8650704199138914,
#   'Corpora': 3.6724253419714956,
#   'Development': 2.350497247084133,
#   'Arne': 4.087462841250339,
#   'J6nsson,': 5.672425341971495,
#   'Nils': 4.672425341971495,
#   'Dahlb~ick': 4.672425341971495,
#   '.................................................................................................': 84.10365615548692,
#   '44': 3.0874628412503395,
#   'Plan-Based': 4.672425341971495,
#   'Management': 6.700994494168266,
#   'ina': 23.362126709857478,
#   'Physics': 4.672425341971495,
#   'Tour': 5.672425341971495,
#   'Reva': 4.672425341971495,
#   'Freedman': 4.672425341971495,
#   '......................................................................................................................': 45.37940273577196,
#   '52': 3.6724253419714956,
#   'Framework': 3.0874628412503395,
#   'MT': 3.0874628412503395,
#   'NLG': 4.087462841250339,
#   'Based': 11.094737505048093,
#   'Uniform': 4.672425341971495,
#   'Lexico-Structural': 4.672425341971495,
#   'Benoit': 4.672425341971495,
#   'Lavoie,': 4.672425341971495,
#   'Korelsky,': 4.672425341971495,
#   'Rambow': 4.672425341971495,
#   '...................................': 510.51828077743454,
#   '60': 1.9719856238304034,
#   "Talk'N'Travel:": 5.672425341971495,
#   'Conversational': 3.6724253419714956,
#   'Air': 3.6724253419714956,
#   'Travel': 9.34485068394299,
#   'Planning': 3.6724253419714956,
#   'Stallard': 4.672425341971495,
#   '........................................................................................................................': 28.362126709857478,
#   '68': 6.700994494168266,
#   'REES:': 4.672425341971495,
#   'Large-Scale': 9.34485068394299,
#   'Relation': 8.174925682500678,
#   'Event': 3.0874628412503395,
#   'Extraction': 10.437314206251697,
#   'Chinatsu': 4.087462841250339,
#   'Aone,': 3.6724253419714956,
#   'Mila': 4.672425341971495,
#   'Ramos-Santacruz': 4.672425341971495,
#   '.................................................................................': 147.48305889125888,
#   '76': 6.700994494168266,
#   'Experiments': 4.174925682500679,
#   'Sentence': 5.005000681058367,
#   'Boundary': 4.672425341971495,
#   'Detection': 3.0874628412503395,
#   'Mark': 7.0514917412523985,
#   'Stevenson,': 8.174925682500678,
#   'Gaizauskas': 11.34485068394299,
#   '.....................................................................................': 124.79335752337289,
#   '84': 3.6724253419714956,
#   'DP:': 4.672425341971495,
#   'Detector': 4.672425341971495,
#   'Presuppositions': 4.672425341971495,
#   'Survey': 3.6724253419714956,
#   'Questions': 8.174925682500678,
#   'Katja': 4.672425341971495,
#   'Wiemer-Hastings,': 9.34485068394299,
#   'Peter': 2.350497247084133,
#   'Sonya': 4.672425341971495,
#   'Rajan,': 11.34485068394299,
#   'Art': 3.350497247084133,
#   'Graesser,': 4.672425341971495,
#   'Roger': 3.350497247084133,
#   'Kreuz,': 4.672425341971495,
#   'Ashish': 4.672425341971495,
#   'Karnavat': 5.672425341971495,
#   '..............................................................................................': 88.7760814974584,
#   '90': 5.344850683942991,
#   'ANLPiii': 5.672425341971495,
#   'MIMIC:': 4.672425341971495,
#   'An': 4.66947611380701,
#   'Adaptive': 3.6724253419714956,
#   'Mixed': 3.6724253419714956,
#   'Initiative': 4.087462841250339,
#   'Queries': 3.350497247084133,
#   'Jennifer': 4.087462841250339,
#   'Chu-Carroll': 4.087462841250339,
#   '..............................................................................................................': 79.41395478760093,
#   '97': 2.8650704199138914,
#   'Javox:': 5.672425341971495,
#   'Toolkit': 4.672425341971495,
#   'Building': 2.5025003405291835,
#   'Speech-Enabled': 4.672425341971495,
#   'Applications': 3.0874628412503395,
#   'S.': 0.8650704199138914,
#   'Fulkerson,': 4.672425341971495,
#   'Alan': 3.350497247084133,
#   'W.': 1.0874628412503393,
#   'Biermann': 5.672425341971495,
#   '...........................................................................': 170.17276025914487,
#   '105': 4.672425341971495,
#   'Compact': 4.672425341971495,
#   'Architecture': 2.350497247084133,
#   'Scripts': 4.672425341971495,
#   'Meta-Outputs': 4.672425341971495,
#   'Manny': 3.6724253419714956,
#   'Rayner,': 4.087462841250339,
#   'Ann': 9.262388523751019,
#   'Hockey,': 4.672425341971495,
#   'Frankie': 5.672425341971495,
#   'James': 3.350497247084133,
#   '112': 4.087462841250339,
#   'Representation': 2.8650704199138914,
#   'Complex': 4.087462841250339,
#   'Evolving': 4.672425341971495,
#   'Data': 3.730140839827783,
#   'Dependencies': 4.087462841250339,
#   'Generation': 2.6724253419714956,
#   'C.': 3.262388523751018,
#   'Mellish,': 4.672425341971495,
#   'R.': 1.3448506839429912,
#   'Evans,': 4.087462841250339,
#   'L.': 2.2977267718289656,
#   'Cahill,': 4.672425341971495,
#   'Doran,': 4.087462841250339,
#   'D.': 2.0571383043935416,
#   'Paiva,': 4.672425341971495,
#   'M.': 1.8350756796160541,
#   'Reape,': 4.672425341971495,
#   'Scott,': 3.6724253419714956,
#   'N.': 1.6724253419714956,
#   'Tipper': 5.672425341971495,
#   '.............................................................................': 158.82790957520186,
#   '119': 4.672425341971495,
#   'Reviser:': 4.672425341971495,
#   'TransCheck': 4.672425341971495,
#   'Jean-Marc': 4.672425341971495,
#   'Jutras': 4.672425341971495,
#   '..................................................................................................................': 56.06910410365794,
#   '127': 4.087462841250339,
#   'Unit': 11.017276025914487,
#   'Completion': 4.672425341971495,
#   'Computer-Aided': 5.672425341971495,
#   'Typing': 4.672425341971495,
#   'Philippe': 5.672425341971495,
#   'Langlais,': 4.672425341971495,
#   'George': 2.8650704199138914,
#   'Foster,': 4.087462841250339,
#   'Guy': 4.087462841250339,
#   'Lapalme': 4.672425341971495,
#   '.................................................................': 192.86246162703083,
#   '135': 4.087462841250339,
#   'Coreference': 4.087462841250339,
#   'Resolution': 3.6724253419714956,
#   'Sanda': 4.087462841250339,
#   'Harabagiu,': 4.672425341971495,
#   'Steven': 11.460281679655566,
#   'J.': 0.6297466747068238,
#   'Maiorano': 5.672425341971495,
#   '142': 4.672425341971495,
#   'Ranking': 3.350497247084133,
#   'Suspected': 5.672425341971495,
#   'Answers': 4.672425341971495,
#   'Predictive': 3.6724253419714956,
#   'Annotation': 3.6724253419714956,
#   'Dragomir': 4.087462841250339,
#   'Radev,': 3.6724253419714956,
#   'Prager,': 4.087462841250339,
#   'Valerie': 4.672425341971495,
#   'Samn': 5.672425341971495,
#   '150': 3.6724253419714956,
#   'Message': 2.2129937233341983,
#   'Classification': 3.350497247084133,
#   'Call': 4.087462841250339,
#   'Center': 2.350497247084133,
#   'Stephan': 4.087462841250339,
#   'Busemann,': 4.672425341971495,
#   'Sven': 4.672425341971495,
#   'Schmeier,': 4.672425341971495,
#   'Roman': 6.174925682500679,
#   'Arens': 4.672425341971495,
#   '.......................................................': 317.6558191504037,
#   '158': 4.672425341971495,
#   'Question': 11.460281679655566,
#   'Answering': 6.700994494168266,
#   'Supported': 4.087462841250339,
#   'Rohini': 8.174925682500678,
#   'Srihari,': 7.344850683942991,
#   'Wei': 16.349851365001356,
#   'Li': 30.154475223757196,
#   '........................................................................................................': 70.08638012957243,
#   '166': 2.8650704199138914,
#   'Categorizing': 4.672425341971495,
#   'Unknown': 3.6724253419714956,
#   'Words:': 4.672425341971495,
#   'Decision': 3.6724253419714956,
#   'Trees': 4.672425341971495,
#   'Identify': 6.700994494168266,
#   'Names': 3.6724253419714956,
#   'Misspellings': 4.672425341971495,
#   'Janine': 5.672425341971495,
#   'Toole': 4.672425341971495,
#   '.........................................................................................................................': 18.68970136788598,
#   '173': 4.672425341971495,
#   'Examining': 4.087462841250339,
#   'Role': 3.0874628412503395,
#   'Statistical': 3.730140839827783,
#   'Linguistic': 6.6389811700025945,
#   'Knowledge': 9.401988988336532,
#   'Sources': 4.672425341971495,
#   'General-Knowledge': 4.672425341971495,
#   'Question-Answering': 4.672425341971495,
#   'Claire': 4.087462841250339,
#   'Cardie,': 3.6724253419714956,
#   'Vincent': 4.672425341971495,
#   'Ng,': 4.672425341971495,
#   'Pierce,': 4.672425341971495,
#   'Chris': 8.595211259741674,
#   'Buckley': 4.087462841250339,
#   '....................................................': 329.0006698343467,
#   '180': 3.6724253419714956,
#   'Extracting': 3.6724253419714956,
#   'Molecular': 4.672425341971495,
#   'Binding': 4.672425341971495,
#   'Relationships': 4.087462841250339,
#   'Biomedical': 4.672425341971495,
#   'Thomas': 3.350497247084133,
#   'Rindflesch,': 5.672425341971495,
#   'Jayant': 4.672425341971495,
#   'V.': 2.2129937233341983,
#   'Lawrence': 5.730140839827783,
#   'Hunter': 4.672425341971495,
#   '................................................': 351.6903712022327,
#   '188': 4.672425341971495,
#   'Compound': 4.672425341971495,
#   'Noun': 2.6724253419714956,
#   'Segmentation': 3.350497247084133,
#   'Lexical': 4.174925682500679,
#   'Extracted': 4.672425341971495,
#   'Juntae': 5.672425341971495,
#   'Yoon': 4.672425341971495,
#   '196': 5.672425341971495,
#   'Corpus-Based': 4.087462841250339,
#   'LFG': 4.087462841250339,
#   'Specialization': 4.672425341971495,
#   'Nicola': 5.672425341971495,
#   'Cancedda,': 5.672425341971495,
#   'Christer': 4.087462841250339,
#   'Samuelsson': 4.672425341971495,
#   '...............................................................................': 153.15548423323037,
#   '204': 4.672425341971495,
#   'Tool': 13.401988988336532,
#   'Automated': 3.6724253419714956,
#   'Revision': 4.672425341971495,
#   'Grammars': 3.0874628412503395,
#   'Nanda': 4.672425341971495,
#   'Kambhatla,': 5.672425341971495,
#   'Wlodek': 4.087462841250339,
#   'Zadrozny': 4.087462841250339,
#   '210': 4.087462841250339,
#   'ANLPiv': 5.672425341971495,
#   'Aggressive': 4.087462841250339,
#   'Morphology': 3.350497247084133,
#   'Robust': 2.2129937233341983,
#   'Coverage': 3.350497247084133,
#   'William': 4.425987446668397,
#   'A.': 1.7548875021634687,
#   'Woods': 7.344850683942991,
#   '...............................................................................................................': 73.74152944562944,
#   '218': 4.087462841250339,
#   'TnT--A': 5.672425341971495,
#   'Part-of-Speech': 4.087462841250339,
#   'Tagger': 4.672425341971495,
#   'Thorsten': 4.087462841250339,
#   'Brants': 4.672425341971495,
#   '...................................................................................................................': 51.396678761686445,
#   '224': 4.672425341971495,
#   'Independent': 3.350497247084133,
#   'Morphological': 2.6724253419714956,
#   'Analysis': 2.0874628412503395,
#   'Tatsuo': 4.672425341971495,
#   'Yamashita,': 4.672425341971495,
#   'Yuji': 4.087462841250339,
#   'Matsumoto': 4.672425341971495,
#   '....................................................................................': 107.4657828653444,
#   '232': 4.672425341971495,
#   'Divide-and-Conquer': 4.672425341971495,
#   'Strategy': 3.6724253419714956,
#   'Shallow': 3.6724253419714956,
#   'Parsing': 2.5025003405291835,
#   'German': 5.005000681058367,
#   'Free': 9.34485068394299,
#   'Texts': 4.087462841250339,
#   'Giinter': 4.672425341971495,
#   'Neumann,': 4.087462841250339,
#   'Christian': 4.672425341971495,
#   'Braun,': 5.672425341971495,
#   'Jakub': 4.087462841250339,
#   'Piskorski': 4.672425341971495,
#   '239': 4.672425341971495,
#   'Hybrid': 4.087462841250339,
#   'Approach': 1.8650704199138914,
#   'Named': 9.401988988336532,
#   'Entity': 6.6389811700025945,
#   'Sub-Type': 4.672425341971495,
#   'Tagging': 2.350497247084133,
#   'Cheng': 4.672425341971495,
#   'Niu,': 5.672425341971495,
#   '......................................................................................': 98.1209321814014,
#   '247': 4.672425341971495,
#   'Spelling': 3.350497247084133,
#   'Grammar': 5.344850683942991,
#   'Correction': 4.087462841250339,
#   'Danish': 4.087462841250339,
#   'SCARRIE': 4.672425341971495,
#   'Patrizia': 4.672425341971495,
#   'Paggio': 4.672425341971495,
#   '.....................................................................................................................': 46.724253419714955,
#   '255': 4.672425341971495,
#   'Can': 12.262388523751017,
#   'Improve': 4.087462841250339,
#   'Woods,': 4.087462841250339,
#   'Bookman,': 4.672425341971495,
#   'Houston,': 4.672425341971495,
#   'Kuhns,': 4.672425341971495,
#   'Martin,': 2.8650704199138914,
#   'Stephen': 2.8650704199138914,
#   'Green': 4.087462841250339,
#   '262': 4.672425341971495,
#   'Domain-Specific': 3.6724253419714956,
#   'Acquisition': 3.6724253419714956,
#   'Dan': 9.262388523751019,
#   'Moldovan,': 4.672425341971495,
#   'Roxana': 4.672425341971495,
#   'Girju,': 4.672425341971495,
#   'Vasile': 5.672425341971495,
#   'Rus': 9.34485068394299,
#   '..........................................................................': 175.84518560111636,
#   '268': 4.672425341971495,
#   'Controlled': 4.672425341971495,
#   'Vocabulary': 4.087462841250339,
#   'Indexing': 3.6724253419714956,
#   'Entities': 4.672425341971495,
#   'Wasson': 4.672425341971495,
#   '.......................................................................................................................': 32.706977393800464,
#   '276': 4.672425341971495,
#   'Unsupervised': 4.087462841250339,
#   'Discovery': 4.087462841250339,
#   'Scenario-Level': 4.672425341971495,
#   'Patterns': 3.6724253419714956,
#   'Yangarber,': 4.672425341971495,
#   'Grishman,': 4.087462841250339,
#   'Pasi': 4.672425341971495,
#   'Tapanainen,': 4.672425341971495,
#   'Silja': 5.672425341971495,
#   'Huttunen': 5.672425341971495,
#   '..............................': 612.6219369329215,
#   '282': 4.087462841250339,
#   'Corpus-Derived': 5.672425341971495,
#   'Name': 15.015002043175102,
#   'Lists': 4.087462841250339,
#   'Recognition': 2.5025003405291835,
#   '...................................................................................': 136.13820820731587,
#   '290': 4.672425341971495,
#   'Answer': 12.349851365001358,
#   'Abney,': 3.6724253419714956,
#   'Collins,': 3.6724253419714956,
#   'Singhal': 5.672425341971495,
#   '....................................................................': 149.51761094308785,
#   '296': 4.087462841250339,
#   'Automatically': 3.6724253419714956,
#   'Identified': 4.672425341971495,
#   'Index': 8.174925682500678,
#   'Terms': 4.087462841250339,
#   'Browsing': 4.087462841250339,
#   'Electronic': 3.350497247084133,
#   'Documents': 3.0874628412503395,
#   'Nina': 4.087462841250339,
#   'Wacholder,': 4.087462841250339,
#   'Judith': 3.6724253419714956,
#   'Klavans,': 4.087462841250339,
#   'K.': 1.2129937233341985,
#   'Evans': 6.700994494168266,
#   '.........................................................': 247.63854312448925,
#   '302': 5.672425341971495,
#   'Reduction': 4.087462841250339,
#   'Summarization': 4.087462841250339,
#   'Hongyan': 4.087462841250339,
#   'Jing': 4.672425341971495,
#   '310': 4.087462841250339,
#   'Noisy': 4.672425341971495,
#   'Input:': 4.087462841250339,
#   'Speech': 5.017276025914487,
#   'OCR': 4.672425341971495,
#   'Miller,': 2.6724253419714956,
#   'Sean': 5.672425341971495,
#   'Boisen,': 4.672425341971495,
#   'Schwartz,': 3.350497247084133,
#   'Rebecca': 3.6724253419714956,
#   'Stone,': 3.6724253419714956,
#   '...........': 1574.607340244394,
#   '316': 4.672425341971495,
#   'Improving': 3.0874628412503395,
#   'Testsuites': 4.672425341971495,
#   'via': 1.6724253419714956,
#   'Instrumentation': 4.672425341971495,
#   'Br6ker': 5.672425341971495,
#   '325': 4.672425341971495,
#   'Efficiency': 4.672425341971495,
#   'Multimodal': 4.672425341971495,
#   'Interaction': 4.087462841250339,
#   'Map-Based': 5.672425341971495,
#   'Task': 2.5025003405291835,
#   'Philip': 5.344850683942991,
#   'Cohen,': 2.8650704199138914,
#   'McGee,': 4.672425341971495,
#   'Josh': 4.672425341971495,
#   'Clow': 5.672425341971495,
#   '................................................................': 198.53488696900234,
#   '331': 4.087462841250339,
#   'ANLPv': 5.672425341971495,
#   'BusTUC': 5.672425341971495,
#   'natura': 0.0,
#   'l': 89.56904181938903,
#   'anguage': 11.520971272734617,
#   'bus': 4.087462841250339,
#   'route': 0.0,
#   'rac': 15.05182807774346,
#   'le': 47.548875021634686,
#   'Dept.': 0.0,
#   'computer': 0.0,
#   'information': 0.0,
#   'science': 0.0,
#   'University': 0.5849625007211562,
#   'Trondheim': 0.0,
#   'N-7491': 0.0,
#   'amble@idi,': 0.0,
#   'ntnu.': 0.0,
#   'Abstract': 0.0,
#   'paper': 1.400539595963676,
#   'describes': 0.0,
#   'natural': 0.0,
#   'based': 0.18057224564182084,
#   'expert': 0.0,
#   'system': 0.0,
#   'advisor': 0.0,
#   'public': 3.0874628412503395,
#   'transport': 0.0,
#   'Trondheim,': 0.0,
#   'Norway.': 0.0,
#   'available': 0.0,
#   'Internet,and': 0.0,
#   'intstalled': 0.0,
#   'com-': 0.0,
#   "pany's": 0.0,
#   'web': 3.6724253419714956,
#   'server': 0.0,
#   'since': 0.0,
#   'beginning': 0.0,
#   '1999.': 0.0,
#   'bilingual,': 0.0,
#   'relying': 0.0,
#   'internal': 0.0,
#   'independent': 0.0,
#   'logic': 3.6724253419714956,
#   'representation.': 0.0,
#   'Introduct': 0.0,
#   'ion': 24.07454276981238,
#   'database': 0.0,
#   'provides': 0.0,
#   'users': 0.0,
#   'capability': 0.0,
#   'obtaining': 0.0,
#   'in-': 1.3448506839429912,
#   'formation': 14.612239888752377,
#   'stored': 0.0,
#   'querying': 0.0,
#   'language': 0.0,
#   '(NL).': 0.0,
#   'With': 0.0,
#   'means': 0.0,
#   'communication': 0.0,
#   'puter': 4.087462841250339,
#   'system,': 0.0,
#   'make': 0.0,
#   'question': 0.0,
#   'statement': 0.0,
#   'way': 0.543142325026529,
#   'normally': 0.0,
#   'think': 0.0,
#   'discussed,': 0.0,
#   'freeing': 0.0,
#   'hav-': 0.0,
#   'ing': 28.24340090137951,
#   'know': 2.6724253419714956,
#   'stores': 0.0,
#   'processes': 0.0,
#   'information.': 0.0,
#   'present': 1.3448506839429912,
#   'implementation': 0.0,
#   'represents': 0.0,
#   'major': 0.0,
#   'effort': 0.0,
#   'bringing': 0.0,
#   'practical': 0.0,
#   'use.': 0.0,
#   'answer': 0.0,
#   'queries': 0.0,
#   'routes,': 0.0,
#   'stated': 0.0,
#   'texts,': 0.0,
#   'made': 0.0,
#   'Internet': 0.0,
#   'World': 0.0,
#   'Wide': 0.0,
#   'Web': 0.0,
#   'http': 0.0,
#   '//www.': 0.0,
#   'idi.': 0.0,
#   'no/bustuc/).': 0.0,
#   'small': 0.0,
#   'city': 0.0,
#   'university': 0.0,
#   '140000': 0.0,
#   'inhabitants.': 0.0,
#   'Its': 0.0,
#   'central': 0.0,
#   'systems': 0.0,
#   '42': 3.0874628412503395,
#   'lines,': 0.0,
#   'serving': 0.0,
#   '590': 0.0,
#   'stations,': 0.0,
#   '1900': 0.0,
#   'depar-': 0.0,
#   'tures': 0.0,
#   'per': 12.801079191927352,
#   'day': 0.0,
#   '(in': 0.0,
#   'average).': 0.0,
#   'That': 0.0,
#   'gives': 0.0,
#   'approximately': 0.0,
#   '60000': 0.0,
#   'scheduled': 0.0,
#   'station': 0.0,
#   'passings': 0.0,
#   'day,': 0.0,
#   'somehow': 0.0,
#   'represented': 0.0,
#   'data': 0.0,
#   'base.': 0.0,
#   'starting': 0.0,
#   'point': 0.0,
#   'automate': 0.0,
#   'function': 0.0,
#   'agent.': 0.0,
#   'example': 0.0,
#   'response': 0.0,
#   'using': 0.0,
#   'actual': 0.0,
#   'request': 0.0,
#   'telephone': 0.0,
#   'local': 0.0,
#   'company:': 0.0,
#   'Hi,': 0.0,
#   'live': 0.0,
#   'Nidarvoll': 0.0,
#   'tonight': 0.0,
#   'must': 0.0,
#   'reach': 0.0,
#   'train': 0.0,
#   'Oslo': 0.0,
#   'oclock.': 0.0,
#   'typical': 0.0,
#   'follow': 1.8650704199138914,
#   'quickly:': 0.0,
#   'number': 0.0,
#   '54': 0.0,
#   'passes': 0.0,
#   'skole': 0.0,
#   '1710': 0.0,
#   'arrives': 0.0,
#   'Railway': 0.0,
#   'Station': 0.0,
#   '1725.': 0.0,
#   'In': 0.9811634635568864,
#   'pro-': 0.0,
#   'cess': 18.803977976673064,
#   'lexical': 0.0,
#   'analysis,': 0.0,
#   'syntax': 0.0,
#   'semantic': 0.0,
#   'pragmatic': 0.0,
#   'reasoning': 0.0,
#   'query': 0.0,
#   'processing.': 0.0,
#   'One': 0.0,
#   'could': 0.0,
#   'argue': 0.0,
#   'content': 0.0,
#   'solved': 0.0,
#   'interrogation,': 0.0,
#   'whereby': 0.0,
#   'customer': 0.0,
#   'asked': 0.0,
#   'produce': 0.0,
#   '4': 1.6374972450593104,
#   'items:': 0.0,
#   'ta': 61.74925682500679,
#   'departure,': 0.0,
#   'arrival,': 0.0,
#   'earliest': 0.0,
#   'departure': 0.0,
#   'timeand/or': 0.0,
#   'latest': 0.0,
#   'arrival': 0.0,
#   'time.': 0.0,
#   'It': 0.18057224564182084,
#   'myth': 0.0,
#   'better': 0.0,
#   '"natural': 0.0,
#   'language".': 0.0,
#   'challenge': 0.0,
#   'prove': 3.6724253419714956,
#   'demonstration': 0.0,
#   'NL': 46.31194261875509,
#   'preferred': 0.0,
#   'interrogative': 0.0,
#   'mode.': 0.0,
#   'To': 3.8204804567511905,
#   'that,': 0.0,
#   'correct,': 0.0,
#   'user': 0.0,
#   'friendly': 0.0,
#   'almost': 0.0,
#   'complete': 0.0,
#   'within': 0.0,
#   'domain.': 0.0,
#   'Previous': 0.0,
#   'Efforts,': 0.0,
#   'CHAT-80,': 0.0,
#   'PRAT-89': 0.0,
#   'HSQL': 0.0,
#   'called': 0.0,
#   'built': 0.0,
#   'upon': 0.0,
#   'clas-': 0.0,
#   'sical': 0.0,
#   'CHAT-80': 0.0,
#   '(Warren': 0.0,
#   'Pereira,': 0.0,
#   '1982).': 0.0,
#   'state': 0.0,
#   'art': 33.05182807774346,
#   'sys-': 0.0,
#   'tem': 19.407899573347176,
#   'impressive': 0.0,
#   'merits,': 0.0,
#   'also': 0.0,
#   'established': 0.0,
#   'Prolog': 0.0,
#   'viable': 0.0,
#   'competitive': 0.0,
#   'lan-': 2.2129937233341983,
#   'guage': 15.889812717266793,
#   'Artificial': 0.0,
#   'Intelligence': 0.0,
#   'general.': 0.0,
#   'brilliant': 0.0,
#   'masterpiece': 0.0,
#   'software,': 0.0,
#   'efficient': 0.0,
#   'sophisticated.': 0.0,
#   'connected': 0.0,
#   'international': 0.0,
#   'geography.': 0.0,
#   'analysed': 0.0,
#   'answered': 0.0,
#   'split': 0.0,
#   'second:': 0.0,
#   'Which': 0.0,
#   'country': 0.0,
#   'bordering': 0.0,
#   'Mediterranean': 0.0,
#   'borders': 0.0,
#   'bordered': 0.0,
#   'whose': 0.0,
#   'population': 0.0,
#   'exceeds': 0.0,
#   ...},
#  1: {'Association': 0.0,
#   'Computational': 0.543142325026529,
#   'Linguistics': 0.0,
#   '6': 4.66947611380701,
#   'th': 650.6201546602543,
#   'Applied': 0.0,
#   'Natural': 1.0514917412523994,
#   'Language': 0.4923211745387956,
#   'Processing': 0.0,
#   'Conference': 0.0,
#   'Proceedings': 0.0,
#   'April': 0.0,
#   '29--May': 0.0,
#   '4,': 1.584962500721156,
#   '2000': 0.0,
#   'Seattle,': 0.0,
#   'Washington,': 0.0,
#   'USA': 0.0,
#   'ANLP': 0.0,
#   '2000-PREFACE': 0.0,
#   '131': 0.0,
#   'papers': 0.0,
#   'submitted': 0.0,
#   'ANLP-2000.': 0.0,
#   '46': 0.0,
#   'accepted': 0.0,
#   'presentation': 6.174925682500679,
#   'conference.': 0.0,
#   'Papers': 0.0,
#   'came': 3.350497247084133,
#   '24': 0.0,
#   'countries:': 0.0,
#   'fifty': 0.0,
#   'eight': 0.0,
#   'United': 0.0,
#   'States': 0.0,
#   'America,': 0.0,
#   'eleven': 0.0,
#   'Germany': 0.0,
#   'Kingdom,': 0.0,
#   'nine': 0.0,
#   'Canada,': 0.0,
#   'Japan,': 0.0,
#   'four': 0.0,
#   'Italy': 0.0,
#   'Spain,': 0.0,
#   'three': 0.0,
#   'ach': 33.05182807774346,
#   'France,': 0.0,
#   'Korea': 0.0,
#   'Switzerland,': 0.0,
#   'two': 0.05713830439354184,
#   'Australia,': 0.0,
#   'China,': 0.0,
#   'The': 2.1998247191513607,
#   'Netherlands': 0.0,
#   'Sweden': 0.0,
#   'one': 0.8080169699880241,
#   'Czech': 0.0,
#   'Republic,': 0.0,
#   'Denmark,': 4.087462841250339,
#   'Finland,': 0.0,
#   'Greece,': 0.0,
#   'India,': 0.0,
#   'Hong': 0.0,
#   'Kong,': 0.0,
#   'Malaysia,': 0.0,
#   'Norway,': 4.672425341971495,
#   'Russia': 0.0,
#   'Taiwan.': 0.0,
#   '40': 5.005000681058367,
#   'industry.': 0.0,
#   '85': 3.0874628412503395,
#   'academia.': 0.0,
#   '2': 1.1543099571257487,
#   'government': 0.0,
#   'organizations': 0.0,
#   'submissions': 0.0,
#   'combined.': 0.0,
#   'reviewing': 0.0,
#   'process': 5.027603221092344,
#   'supported': 0.0,
#   'web-based': 0.0,
#   'reviewer': 0.0,
#   'interface': 22.129937233341984,
#   'developed': 2.017276025914487,
#   'Elisha': 0.0,
#   'Kane': 0.0,
#   'New': 0.8650704199138914,
#   'Mexico': 0.0,
#   'State': 2.0874628412503395,
#   "University's": 0.0,
#   'Computing': 2.2129937233341983,
#   'Research': 0.0,
#   'Lab.': 0.0,
#   'Linda': 0.0,
#   'Fresques': 0.0,
#   'CRL': 0.0,
#   'coordinated': 0.0,
#   'refereeing': 0.0,
#   'process.': 0.0,
#   'I': 9.600262903506515,
#   'would': 0.7871655712530546,
#   'like': 2.7091618617647306,
#   'express': 11.752486235420665,
#   'gratitude': 0.0,
#   'appreciation': 0.0,
#   'fthe': 0.0,
#   'Program': 0.0,
#   'Committee': 0.0,
#   'members': 0.0,
#   'responsible': 0.0,
#   'six': 0.0,
#   'areas:': 0.0,
#   'Lynn': 0.0,
#   'Carlson,': 0.0,
#   'Tools': 0.0,
#   'Resources': 0.0,
#   'Developing': 0.0,
#   'NLP': 0.0,
#   'Systems': 0.0,
#   'Subcommittee': 0.0,
#   'Eduard': 0.0,
#   'Hovy,': 0.0,
#   'Integrated': 0.0,
#   'Richard': 0.0,
#   'Kittredge,': 0.0,
#   'Multilingual': 0.0,
#   'Text': 0.0,
#   'Ray': 0.0,
#   'Perrault,': 0.0,
#   'Spoken': 0.0,
#   'Oliviero': 0.0,
#   'Stock,': 0.0,
#   'Monolingual': 0.0,
#   'John': 5.017276025914487,
#   'White,': 0.0,
#   'Evaluation': 0.0,
#   'following': 1.6806475151564113,
#   'colleagues': 0.0,
#   'Doug': 0.0,
#   'Appelt': 0.0,
#   'Fabio': 0.0,
#   'Ciravegna': 0.0,
#   'Robert': 0.0,
#   'Dale': 0.0,
#   'Michael': 0.0,
#   'Elhadad': 0.0,
#   'Ralph': 0.0,
#   'G-rishman': 0.0,
#   'Lynette': 0.0,
#   'Hirschman': 0.0,
#   'Yuval': 0.0,
#   'Krymolowski': 0.0,
#   'Inderjeet': 0.0,
#   'Mani': 0.0,
#   'Zvi': 0.0,
#   'Marx': 0.0,
#   'Martha': 0.0,
#   'Palmer': 0.0,
#   'Harold': 0.0,
#   'Somers': 0.0,
#   'Toshiyuki': 0.0,
#   'Takezawa': 0.0,
#   'Takehito': 0.0,
#   'Utsuro': 0.0,
#   'Dekai': 0.0,
#   'Wu': 0.0,
#   'bulk': 0.0,
#   'reviewing:': 0.0,
#   'Igor': 0.0,
#   'Boguslavsky': 0.0,
#   'Jim': 0.0,
#   'Cowie': 0.0,
#   'Dowding': 0.0,
#   'Glass': 0.0,
#   'Jan': 3.350497247084133,
#   'Haji~': 0.0,
#   'Pierre': 0.0,
#   'IsabeIIe': 0.0,
#   'Alberto': 0.0,
#   'Lavelli': 0.0,
#   'Daniel': 0.0,
#   'Marcu': 0.0,
#   'David': 0.0,
#   'McDonald': 0.0,
#   'Owen': 0.0,
#   'Rainbow': 0.0,
#   'Tomek': 0.0,
#   'Strzalkowski': 0.0,
#   'Kathryn': 0.0,
#   'B.': 0.0,
#   'Taylor': 0.0,
#   'Pick': 0.0,
#   'Vossen': 0.0,
#   'R6mi': 0.0,
#   'Zajac': 0.0,
#   'Carter': 0.0,
#   'Ido': 0.0,
#   'Dagan': 0.0,
#   'Andreas': 0.0,
#   'Eiscle': 0.0,
#   'Oren': 0.0,
#   'Glikman': 0.0,
#   'Donna': 0.0,
#   'Harman': 0.0,
#   'Tanya': 0.0,
#   'Korelsky': 0.0,
#   'Chin-Yew': 0.0,
#   'Lin': 9.34485068394299,
#   'Paul': 0.0,
#   'Martin': 0.0,
#   'Teruko': 0.0,
#   'Mitamura': 0.0,
#   'Norbert': 0.0,
#   'Reithinger': 0.0,
#   'Beth': 0.0,
#   'Sundheim': 0.0,
#   'Hans': 0.0,
#   'Uszkoreit': 0.0,
#   'Weischedel': 0.0,
#   'We': 0.08570745659031276,
#   'believe': 9.325352099569457,
#   'quality': 0.0,
#   'elected': 3.6724253419714956,
#   'israther': 0.0,
#   'high': 0.0,
#   'hope': 0.0,
#   'conference': 0.0,
#   'success.': 0.0,
#   'Sergei': 0.0,
#   'Nirenburg': 0.0,
#   'Chair,': 0.0,
#   'ANLP-2000': 0.0,
#   'ANLPi': 0.0,
#   'Table': 0.0,
#   'Contents': 0.0,
#   'Section': 0.0,
#   '1:': 0.0,
#   '(ANLP)': 0.0,
#   'Preface': 0.0,
#   'List': 0.0,
#   'Reviewers': 0.0,
#   'Nirenburg,': 0.0,
#   'Chair': 0.0,
#   '...............................................................': 0.0,
#   'BusTUC--A': 0.0,
#   'Bus': 51.396678761686445,
#   'Route': 0.0,
#   'Oracle': 0.0,
#   'Tore': 9.34485068394299,
#   'Amble': 14.017276025914486,
#   '..............................................................................................................................': 0.0,
#   '1': 3.4985136500135763,
#   'Machine': 0.0,
#   'Translation': 0.0,
#   'Very': 0.0,
#   'Close': 0.0,
#   'Languages': 0.0,
#   'Haji~,': 0.0,
#   'Hric,': 0.0,
#   'Vladislav': 0.0,
#   'Kubofi': 0.0,
#   '.......................................................................................': 0.0,
#   '7': 6.803899366812823,
#   'Cross-Language': 0.0,
#   'Multimedia': 0.0,
#   'Information': 0.6280312226130421,
#   'Retrieval': 0.0,
#   'Sharon': 0.0,
#   'Flank': 0.0,
#   '..........................................................................................................................': 0.0,
#   '13': 2.5025003405291835,
#   'Automatic': 0.0,
#   'Construction': 0.0,
#   'Parallel': 0.0,
#   'English-Chinese': 0.0,
#   'Corpus': 0.0,
#   'Jiang': 0.0,
#   'Chen,': 0.0,
#   'Jian-Yun': 0.0,
#   'Nie': 0.0,
#   '......................................................................................................': 0.0,
#   '21': 0.0,
#   'PartslD:': 0.0,
#   'A': 2.085548110364277,
#   'Dialogue-Based': 0.0,
#   'System': 5.142845760983854,
#   'Identifying': 0.0,
#   'Parts': 0.0,
#   'Medical': 0.0,
#   'Amit': 0.0,
#   'Bagga,': 0.0,
#   'Strzalkowski,': 0.0,
#   'G.': 0.0,
#   'Bowden': 0.0,
#   'Wise': 0.0,
#   '...........................................................': 0.0,
#   '29': 0.0,
#   'Using': 0.0,
#   'Dialogue': 0.0,
#   'Participants': 0.0,
#   'Setsuo': 0.0,
#   'Yamada,': 0.0,
#   'Eiichiro': 0.0,
#   'Sumita,': 0.0,
#   'Hideki': 0.0,
#   'Kashioka': 0.0,
#   '..............................................................': 0.0,
#   '37': 0.0,
#   'Distilling': 0.0,
#   'Dialogues--A': 0.0,
#   'Method': 0.0,
#   'Corpora': 0.0,
#   'Development': 0.0,
#   'Arne': 0.0,
#   'J6nsson,': 0.0,
#   'Nils': 0.0,
#   'Dahlb~ick': 0.0,
#   '.................................................................................................': 0.0,
#   '44': 0.0,
#   'Plan-Based': 0.0,
#   'Management': 0.0,
#   'ina': 28.03455205182897,
#   'Physics': 0.0,
#   'Tour': 0.0,
#   'Reva': 0.0,
#   'Freedman': 0.0,
#   '......................................................................................................................': 0.0,
#   '52': 0.0,
#   'Framework': 0.0,
#   'MT': 0.0,
#   'NLG': 0.0,
#   'Based': 0.0,
#   'Uniform': 0.0,
#   'Lexico-Structural': 0.0,
#   'Benoit': 0.0,
#   'Lavoie,': 0.0,
#   'Korelsky,': 0.0,
#   'Rambow': 0.0,
#   '...................................': 0.0,
#   '60': 3.943971247660807,
#   "Talk'N'Travel:": 0.0,
#   'Conversational': 0.0,
#   'Air': 0.0,
#   'Travel': 0.0,
#   'Planning': 0.0,
#   'Stallard': 0.0,
#   '........................................................................................................................': 0.0,
#   '68': 0.0,
#   'REES:': 0.0,
#   'Large-Scale': 0.0,
#   'Relation': 4.087462841250339,
#   'Event': 6.174925682500679,
#   'Extraction': 0.0,
#   'Chinatsu': 0.0,
#   'Aone,': 0.0,
#   'Mila': 0.0,
#   'Ramos-Santacruz': 0.0,
#   '.................................................................................': 0.0,
#   '76': 0.0,
#   'Experiments': 0.0,
#   'Sentence': 0.0,
#   'Boundary': 0.0,
#   'Detection': 0.0,
#   'Mark': 0.0,
#   'Stevenson,': 0.0,
#   'Gaizauskas': 0.0,
#   '.....................................................................................': 0.0,
#   '84': 0.0,
#   'DP:': 0.0,
#   'Detector': 0.0,
#   'Presuppositions': 0.0,
#   'Survey': 0.0,
#   'Questions': 0.0,
#   'Katja': 0.0,
#   'Wiemer-Hastings,': 0.0,
#   'Peter': 0.0,
#   'Sonya': 0.0,
#   'Rajan,': 0.0,
#   'Art': 6.700994494168266,
#   'Graesser,': 0.0,
#   'Roger': 0.0,
#   'Kreuz,': 0.0,
#   'Ashish': 0.0,
#   'Karnavat': 0.0,
#   '..............................................................................................': 0.0,
#   '90': 10.689701367885982,
#   'ANLPiii': 0.0,
#   'MIMIC:': 0.0,
#   'An': 1.2734934855837303,
#   'Adaptive': 0.0,
#   'Mixed': 0.0,
#   'Initiative': 0.0,
#   'Queries': 0.0,
#   'Jennifer': 0.0,
#   'Chu-Carroll': 0.0,
#   '..............................................................................................................': 0.0,
#   '97': 5.730140839827783,
#   'Javox:': 0.0,
#   'Toolkit': 0.0,
#   'Building': 0.0,
#   'Speech-Enabled': 0.0,
#   'Applications': 0.0,
#   'S.': 0.8650704199138914,
#   'Fulkerson,': 0.0,
#   'Alan': 0.0,
#   'W.': 0.0,
#   'Biermann': 0.0,
#   '...........................................................................': 0.0,
#   '105': 0.0,
#   'Compact': 0.0,
#   'Architecture': 0.0,
#   'Scripts': 0.0,
#   'Meta-Outputs': 0.0,
#   'Manny': 0.0,
#   'Rayner,': 0.0,
#   'Ann': 0.0,
#   'Hockey,': 0.0,
#   'Frankie': 0.0,
#   'James': 0.0,
#   '112': 0.0,
#   'Representation': 0.0,
#   'Complex': 0.0,
#   'Evolving': 0.0,
#   'Data': 0.0,
#   'Dependencies': 0.0,
#   'Generation': 2.6724253419714956,
#   'C.': 2.1749256825006786,
#   'Mellish,': 0.0,
#   'R.': 0.6724253419714956,
#   'Evans,': 0.0,
#   'L.': 2.2977267718289656,
#   'Cahill,': 0.0,
#   'Doran,': 0.0,
#   'D.': 3.0857074565903124,
#   'Paiva,': 0.0,
#   'M.': 0.9175378398080271,
#   'Reape,': 0.0,
#   'Scott,': 0.0,
#   'N.': 3.3448506839429912,
#   'Tipper': 0.0,
#   '.............................................................................': 0.0,
#   '119': 0.0,
#   'Reviser:': 0.0,
#   'TransCheck': 0.0,
#   'Jean-Marc': 0.0,
#   'Jutras': 0.0,
#   '..................................................................................................................': 0.0,
#   '127': 0.0,
#   'Unit': 0.0,
#   'Completion': 0.0,
#   'Computer-Aided': 0.0,
#   'Typing': 0.0,
#   'Philippe': 0.0,
#   'Langlais,': 0.0,
#   'George': 0.0,
#   'Foster,': 0.0,
#   'Guy': 0.0,
#   'Lapalme': 0.0,
#   '.................................................................': 0.0,
#   '135': 0.0,
#   'Coreference': 0.0,
#   'Resolution': 0.0,
#   'Sanda': 0.0,
#   'Harabagiu,': 0.0,
#   'Steven': 0.0,
#   'J.': 0.6297466747068238,
#   'Maiorano': 0.0,
#   '142': 0.0,
#   'Ranking': 0.0,
#   'Suspected': 0.0,
#   'Answers': 0.0,
#   'Predictive': 0.0,
#   'Annotation': 0.0,
#   'Dragomir': 0.0,
#   'Radev,': 0.0,
#   'Prager,': 0.0,
#   'Valerie': 0.0,
#   'Samn': 0.0,
#   '150': 7.344850683942991,
#   'Message': 0.0,
#   'Classification': 0.0,
#   'Call': 0.0,
#   'Center': 0.0,
#   'Stephan': 0.0,
#   'Busemann,': 0.0,
#   'Sven': 0.0,
#   'Schmeier,': 0.0,
#   'Roman': 0.0,
#   'Arens': 0.0,
#   '.......................................................': 0.0,
#   '158': 0.0,
#   'Question': 0.0,
#   'Answering': 0.0,
#   'Supported': 0.0,
#   'Rohini': 0.0,
#   'Srihari,': 0.0,
#   'Wei': 0.0,
#   'Li': 10.051491741252399,
#   '........................................................................................................': 0.0,
#   '166': 0.0,
#   'Categorizing': 0.0,
#   'Unknown': 0.0,
#   'Words:': 0.0,
#   'Decision': 0.0,
#   'Trees': 0.0,
#   'Identify': 0.0,
#   'Names': 0.0,
#   'Misspellings': 0.0,
#   'Janine': 0.0,
#   'Toole': 0.0,
#   '.........................................................................................................................': 0.0,
#   '173': 0.0,
#   'Examining': 0.0,
#   'Role': 0.0,
#   'Statistical': 0.0,
#   'Linguistic': 0.0,
#   'Knowledge': 0.0,
#   'Sources': 0.0,
#   'General-Knowledge': 0.0,
#   'Question-Answering': 0.0,
#   'Claire': 0.0,
#   'Cardie,': 0.0,
#   'Vincent': 0.0,
#   'Ng,': 0.0,
#   'Pierce,': 0.0,
#   'Chris': 0.0,
#   'Buckley': 0.0,
#   '....................................................': 0.0,
#   '180': 0.0,
#   'Extracting': 0.0,
#   'Molecular': 0.0,
#   'Binding': 0.0,
#   'Relationships': 0.0,
#   'Biomedical': 0.0,
#   'Thomas': 0.0,
#   'Rindflesch,': 0.0,
#   'Jayant': 0.0,
#   'V.': 4.425987446668397,
#   'Lawrence': 0.0,
#   'Hunter': 0.0,
#   '................................................': 0.0,
#   '188': 0.0,
#   'Compound': 0.0,
#   'Noun': 2.6724253419714956,
#   'Segmentation': 0.0,
#   'Lexical': 0.0,
#   'Extracted': 0.0,
#   'Juntae': 0.0,
#   'Yoon': 0.0,
#   '196': 0.0,
#   'Corpus-Based': 0.0,
#   'LFG': 0.0,
#   'Specialization': 0.0,
#   'Nicola': 0.0,
#   'Cancedda,': 0.0,
#   'Christer': 0.0,
#   'Samuelsson': 0.0,
#   '...............................................................................': 0.0,
#   '204': 0.0,
#   'Tool': 0.0,
#   'Automated': 0.0,
#   'Revision': 0.0,
#   'Grammars': 6.174925682500679,
#   'Nanda': 0.0,
#   'Kambhatla,': 0.0,
#   'Wlodek': 0.0,
#   'Zadrozny': 0.0,
#   '210': 0.0,
#   'ANLPiv': 0.0,
#   'Aggressive': 0.0,
#   'Morphology': 0.0,
#   'Robust': 0.0,
#   'Coverage': 0.0,
#   'William': 0.0,
#   'A.': 0.0,
#   'Woods': 0.0,
#   '...............................................................................................................': 0.0,
#   '218': 0.0,
#   'TnT--A': 0.0,
#   'Part-of-Speech': 0.0,
#   'Tagger': 0.0,
#   'Thorsten': 0.0,
#   'Brants': 0.0,
#   '...................................................................................................................': 0.0,
#   '224': 0.0,
#   'Independent': 0.0,
#   'Morphological': 0.0,
#   'Analysis': 0.0,
#   'Tatsuo': 0.0,
#   'Yamashita,': 0.0,
#   'Yuji': 0.0,
#   'Matsumoto': 0.0,
#   '....................................................................................': 0.0,
#   '232': 0.0,
#   'Divide-and-Conquer': 0.0,
#   'Strategy': 0.0,
#   'Shallow': 0.0,
#   'Parsing': 0.0,
#   'German': 0.0,
#   'Free': 0.0,
#   'Texts': 0.0,
#   'Giinter': 0.0,
#   'Neumann,': 0.0,
#   'Christian': 0.0,
#   'Braun,': 0.0,
#   'Jakub': 0.0,
#   'Piskorski': 0.0,
#   '239': 0.0,
#   'Hybrid': 0.0,
#   'Approach': 0.0,
#   'Named': 0.0,
#   'Entity': 2.2129937233341983,
#   'Sub-Type': 0.0,
#   'Tagging': 0.0,
#   'Cheng': 0.0,
#   'Niu,': 0.0,
#   '......................................................................................': 0.0,
#   '247': 0.0,
#   'Spelling': 0.0,
#   'Grammar': 18.706977393800468,
#   'Correction': 0.0,
#   'Danish': 4.087462841250339,
#   'SCARRIE': 0.0,
#   'Patrizia': 0.0,
#   'Paggio': 0.0,
#   '.....................................................................................................................': 0.0,
#   '255': 0.0,
#   'Can': 0.0,
#   'Improve': 0.0,
#   'Woods,': 0.0,
#   'Bookman,': 0.0,
#   'Houston,': 0.0,
#   'Kuhns,': 0.0,
#   'Martin,': 0.0,
#   'Stephen': 0.0,
#   'Green': 0.0,
#   '262': 0.0,
#   'Domain-Specific': 0.0,
#   'Acquisition': 0.0,
#   'Dan': 3.0874628412503395,
#   'Moldovan,': 0.0,
#   'Roxana': 0.0,
#   'Girju,': 0.0,
#   'Vasile': 0.0,
#   'Rus': 0.0,
#   '..........................................................................': 0.0,
#   '268': 0.0,
#   'Controlled': 0.0,
#   'Vocabulary': 0.0,
#   'Indexing': 0.0,
#   'Entities': 0.0,
#   'Wasson': 0.0,
#   '.......................................................................................................................': 0.0,
#   '276': 0.0,
#   'Unsupervised': 0.0,
#   'Discovery': 0.0,
#   'Scenario-Level': 0.0,
#   'Patterns': 0.0,
#   'Yangarber,': 0.0,
#   'Grishman,': 0.0,
#   'Pasi': 0.0,
#   'Tapanainen,': 0.0,
#   'Silja': 0.0,
#   'Huttunen': 0.0,
#   '..............................': 0.0,
#   '282': 0.0,
#   'Corpus-Derived': 0.0,
#   'Name': 0.0,
#   'Lists': 0.0,
#   'Recognition': 0.0,
#   '...................................................................................': 0.0,
#   '290': 0.0,
#   'Answer': 0.0,
#   'Abney,': 0.0,
#   'Collins,': 0.0,
#   'Singhal': 0.0,
#   '....................................................................': 0.0,
#   '296': 0.0,
#   'Automatically': 0.0,
#   'Identified': 0.0,
#   'Index': 0.0,
#   'Terms': 0.0,
#   'Browsing': 0.0,
#   'Electronic': 0.0,
#   'Documents': 0.0,
#   'Nina': 0.0,
#   'Wacholder,': 0.0,
#   'Judith': 0.0,
#   'Klavans,': 0.0,
#   'K.': 0.0,
#   'Evans': 0.0,
#   '.........................................................': 0.0,
#   '302': 0.0,
#   'Reduction': 0.0,
#   'Summarization': 0.0,
#   'Hongyan': 0.0,
#   'Jing': 0.0,
#   '310': 0.0,
#   'Noisy': 0.0,
#   'Input:': 0.0,
# ...
#   'Based': 1.584962500721156,
#   'Uniform': 0.0,
#   'Lexico-Structural': 0.0,
#   'Benoit': 0.0,
#   'Lavoie,': 0.0,
#   'Korelsky,': 0.0,
#   'Rambow': 0.0,
#   '...................................': 17.017276025914484,
#   '60': 5.91595687149121,
#   "Talk'N'Travel:": 0.0,
#   'Conversational': 0.0,
#   'Air': 0.0,
#   'Travel': 0.0,
#   'Planning': 0.0,
#   'Stallard': 0.0,
#   '........................................................................................................................': 0.0,
#   '68': 0.0,
#   'REES:': 0.0,
#   'Large-Scale': 0.0,
#   'Relation': 28.612239888752374,
#   'Event': 0.0,
#   'Extraction': 0.0,
#   'Chinatsu': 0.0,
#   'Aone,': 0.0,
#   'Mila': 0.0,
#   'Ramos-Santacruz': 0.0,
#   '.................................................................................': 5.672425341971495,
#   '76': 10.051491741252399,
#   'Experiments': 2.0874628412503395,
#   'Sentence': 25.025003405291834,
#   'Boundary': 0.0,
#   'Detection': 0.0,
#   'Mark': 0.0,
#   'Stevenson,': 0.0,
#   'Gaizauskas': 0.0,
#   '.....................................................................................': 5.672425341971495,
#   '84': 3.6724253419714956,
#   'DP:': 0.0,
#   'Detector': 0.0,
#   'Presuppositions': 0.0,
#   'Survey': 0.0,
#   'Questions': 0.0,
#   'Katja': 0.0,
#   'Wiemer-Hastings,': 0.0,
#   'Peter': 0.0,
#   'Sonya': 0.0,
#   'Rajan,': 0.0,
#   'Art': 0.0,
#   'Graesser,': 0.0,
#   'Roger': 0.0,
#   'Kreuz,': 0.0,
#   'Ashish': 0.0,
#   'Karnavat': 0.0,
#   '..............................................................................................': 4.672425341971495,
#   '90': 8.017276025914487,
#   'ANLPiii': 0.0,
#   'MIMIC:': 0.0,
#   'An': 1.2734934855837303,
#   'Adaptive': 0.0,
#   'Mixed': 0.0,
#   'Initiative': 0.0,
#   'Queries': 0.0,
#   'Jennifer': 0.0,
#   'Chu-Carroll': 0.0,
#   '..............................................................................................................': 5.672425341971495,
#   '97': 8.595211259741674,
#   'Javox:': 0.0,
#   'Toolkit': 0.0,
#   'Building': 0.0,
#   'Speech-Enabled': 0.0,
#   'Applications': 0.0,
#   'S.': 0.8650704199138914,
#   'Fulkerson,': 0.0,
#   'Alan': 0.0,
#   'W.': 1.0874628412503393,
#   'Biermann': 0.0,
#   '...........................................................................': 5.672425341971495,
#   '105': 0.0,
#   'Compact': 0.0,
#   'Architecture': 0.0,
#   'Scripts': 0.0,
#   'Meta-Outputs': 0.0,
#   'Manny': 0.0,
#   'Rayner,': 0.0,
#   'Ann': 0.0,
#   'Hockey,': 0.0,
#   'Frankie': 0.0,
#   'James': 0.0,
#   '112': 8.174925682500678,
#   'Representation': 0.0,
#   'Complex': 0.0,
#   'Evolving': 0.0,
#   'Data': 0.0,
#   'Dependencies': 0.0,
#   'Generation': 0.0,
#   'C.': 2.1749256825006786,
#   'Mellish,': 0.0,
#   'R.': 0.0,
#   'Evans,': 0.0,
#   'L.': 0.0,
#   'Cahill,': 0.0,
#   'Doran,': 0.0,
#   'D.': 1.0285691521967708,
#   'Paiva,': 0.0,
#   'M.': 0.9175378398080271,
#   'Reape,': 0.0,
#   'Scott,': 0.0,
#   'N.': 1.6724253419714956,
#   'Tipper': 0.0,
#   '.............................................................................': 5.672425341971495,
#   '119': 0.0,
#   'Reviser:': 0.0,
#   'TransCheck': 0.0,
#   'Jean-Marc': 0.0,
#   'Jutras': 0.0,
#   '..................................................................................................................': 4.672425341971495,
#   '127': 4.087462841250339,
#   'Unit': 29.379402735771965,
#   'Completion': 0.0,
#   'Computer-Aided': 0.0,
#   'Typing': 0.0,
#   'Philippe': 0.0,
#   'Langlais,': 0.0,
#   'George': 0.0,
#   'Foster,': 0.0,
#   'Guy': 0.0,
#   'Lapalme': 0.0,
#   '.................................................................': 5.672425341971495,
#   '135': 4.087462841250339,
#   'Coreference': 0.0,
#   'Resolution': 0.0,
#   'Sanda': 0.0,
#   'Harabagiu,': 0.0,
#   'Steven': 0.0,
#   'J.': 1.8892400241204714,
#   'Maiorano': 0.0,
#   '142': 0.0,
#   'Ranking': 0.0,
#   'Suspected': 0.0,
#   'Answers': 0.0,
#   'Predictive': 0.0,
#   'Annotation': 0.0,
#   'Dragomir': 0.0,
#   'Radev,': 0.0,
#   'Prager,': 0.0,
#   'Valerie': 0.0,
#   'Samn': 0.0,
#   '150': 0.0,
#   'Message': 0.0,
#   'Classification': 0.0,
#   'Call': 0.0,
#   'Center': 0.0,
#   'Stephan': 0.0,
#   'Busemann,': 0.0,
#   'Sven': 0.0,
#   'Schmeier,': 0.0,
#   'Roman': 0.0,
#   'Arens': 0.0,
#   '.......................................................': 11.34485068394299,
#   '158': 0.0,
#   'Question': 0.0,
#   'Answering': 0.0,
#   'Supported': 0.0,
#   'Rohini': 0.0,
#   'Srihari,': 0.0,
#   'Wei': 20.437314206251695,
#   'Li': 10.051491741252399,
#   '........................................................................................................': 4.672425341971495,
#   '166': 0.0,
#   'Categorizing': 0.0,
#   'Unknown': 0.0,
#   'Words:': 0.0,
#   'Decision': 0.0,
#   'Trees': 0.0,
#   'Identify': 0.0,
#   'Names': 0.0,
#   'Misspellings': 0.0,
#   'Janine': 0.0,
#   'Toole': 0.0,
#   '.........................................................................................................................': 0.0,
#   '173': 0.0,
#   'Examining': 0.0,
#   'Role': 0.0,
#   'Statistical': 1.8650704199138914,
#   'Linguistic': 4.425987446668397,
#   'Knowledge': 0.0,
#   'Sources': 0.0,
#   'General-Knowledge': 0.0,
#   'Question-Answering': 0.0,
#   'Claire': 0.0,
#   'Cardie,': 0.0,
#   'Vincent': 0.0,
#   'Ng,': 0.0,
#   'Pierce,': 0.0,
#   'Chris': 0.0,
#   'Buckley': 0.0,
#   '....................................................': 11.34485068394299,
#   '180': 0.0,
#   'Extracting': 0.0,
#   'Molecular': 0.0,
#   'Binding': 0.0,
#   'Relationships': 0.0,
#   'Biomedical': 0.0,
#   'Thomas': 0.0,
#   'Rindflesch,': 0.0,
#   'Jayant': 0.0,
#   'V.': 0.0,
#   'Lawrence': 0.0,
#   'Hunter': 0.0,
#   '................................................': 11.34485068394299,
#   '188': 0.0,
#   'Compound': 0.0,
#   'Noun': 0.0,
#   'Segmentation': 0.0,
#   'Lexical': 0.0,
#   'Extracted': 0.0,
#   'Juntae': 0.0,
#   'Yoon': 0.0,
#   '196': 0.0,
#   'Corpus-Based': 0.0,
#   'LFG': 0.0,
#   'Specialization': 0.0,
#   'Nicola': 0.0,
#   'Cancedda,': 0.0,
#   'Christer': 0.0,
#   'Samuelsson': 0.0,
#   '...............................................................................': 5.672425341971495,
#   '204': 0.0,
#   'Tool': 3.350497247084133,
#   'Automated': 0.0,
#   'Revision': 0.0,
#   'Grammars': 0.0,
#   'Nanda': 0.0,
#   'Kambhatla,': 0.0,
#   'Wlodek': 0.0,
#   'Zadrozny': 0.0,
#   '210': 0.0,
#   'ANLPiv': 0.0,
#   'Aggressive': 0.0,
#   'Morphology': 0.0,
#   'Robust': 0.0,
#   'Coverage': 0.0,
#   'William': 4.425987446668397,
#   'A.': 1.1699250014423124,
#   'Woods': 0.0,
#   '...............................................................................................................': 5.672425341971495,
#   '218': 0.0,
#   'TnT--A': 0.0,
#   'Part-of-Speech': 0.0,
#   'Tagger': 0.0,
#   'Thorsten': 0.0,
#   'Brants': 0.0,
#   '...................................................................................................................': 4.672425341971495,
#   '224': 0.0,
#   'Independent': 23.453480729588932,
#   'Morphological': 0.0,
#   'Analysis': 0.0,
#   'Tatsuo': 0.0,
#   'Yamashita,': 0.0,
#   'Yuji': 0.0,
#   'Matsumoto': 0.0,
#   '....................................................................................': 4.672425341971495,
#   '232': 0.0,
#   'Divide-and-Conquer': 0.0,
#   'Strategy': 0.0,
#   'Shallow': 0.0,
#   'Parsing': 0.0,
#   'German': 0.0,
#   'Free': 0.0,
#   'Texts': 0.0,
#   'Giinter': 0.0,
#   'Neumann,': 0.0,
#   'Christian': 0.0,
#   'Braun,': 0.0,
#   'Jakub': 0.0,
#   'Piskorski': 0.0,
#   '239': 0.0,
#   'Hybrid': 0.0,
#   'Approach': 0.0,
#   'Named': 0.0,
#   'Entity': 0.0,
#   'Sub-Type': 0.0,
#   'Tagging': 4.700994494168266,
#   'Cheng': 0.0,
#   'Niu,': 0.0,
#   '......................................................................................': 4.672425341971495,
#   '247': 0.0,
#   'Spelling': 0.0,
#   'Grammar': 0.0,
#   'Correction': 0.0,
#   'Danish': 0.0,
#   'SCARRIE': 0.0,
#   'Patrizia': 0.0,
#   'Paggio': 0.0,
#   '.....................................................................................................................': 0.0,
#   '255': 0.0,
#   'Can': 0.0,
#   'Improve': 0.0,
#   'Woods,': 0.0,
#   'Bookman,': 0.0,
#   'Houston,': 0.0,
#   'Kuhns,': 0.0,
#   'Martin,': 0.0,
#   'Stephen': 0.0,
#   'Green': 0.0,
#   '262': 0.0,
#   'Domain-Specific': 0.0,
#   'Acquisition': 0.0,
#   'Dan': 9.262388523751019,
#   'Moldovan,': 0.0,
#   'Roxana': 0.0,
#   'Girju,': 0.0,
#   'Vasile': 0.0,
#   'Rus': 0.0,
#   '..........................................................................': 5.672425341971495,
#   '268': 0.0,
#   'Controlled': 0.0,
#   'Vocabulary': 0.0,
#   'Indexing': 0.0,
#   'Entities': 0.0,
#   'Wasson': 0.0,
#   '.......................................................................................................................': 0.0,
#   '276': 4.672425341971495,
#   'Unsupervised': 0.0,
#   'Discovery': 0.0,
#   'Scenario-Level': 0.0,
#   'Patterns': 0.0,
#   'Yangarber,': 0.0,
#   'Grishman,': 0.0,
#   'Pasi': 0.0,
#   'Tapanainen,': 0.0,
#   'Silja': 0.0,
#   'Huttunen': 0.0,
#   '..............................': 17.017276025914484,
#   '282': 0.0,
#   'Corpus-Derived': 0.0,
#   'Name': 0.0,
#   'Lists': 0.0,
#   'Recognition': 0.0,
#   '...................................................................................': 5.672425341971495,
#   '290': 0.0,
#   'Answer': 0.0,
#   'Abney,': 0.0,
#   'Collins,': 0.0,
#   'Singhal': 0.0,
#   '....................................................................': 4.672425341971495,
#   '296': 0.0,
#   'Automatically': 0.0,
#   'Identified': 0.0,
#   'Index': 0.0,
#   'Terms': 0.0,
#   'Browsing': 0.0,
#   'Electronic': 0.0,
#   'Documents': 0.0,
#   'Nina': 0.0,
#   'Wacholder,': 0.0,
#   'Judith': 0.0,
#   'Klavans,': 0.0,
#   'K.': 1.2129937233341985,
#   'Evans': 0.0,
#   '.........................................................': 9.34485068394299,
#   '302': 0.0,
#   'Reduction': 0.0,
#   'Summarization': 0.0,
#   'Hongyan': 0.0,
#   'Jing': 0.0,
#   '310': 0.0,
#   'Noisy': 0.0,
#   'Input:': 0.0,
#   'Speech': 0.0,
#   'OCR': 0.0,
#   'Miller,': 0.0,
#   'Sean': 0.0,
#   'Boisen,': 0.0,
#   'Schwartz,': 0.0,
#   'Rebecca': 0.0,
#   'Stone,': 0.0,
#   '...........': 56.06910410365794,
#   '316': 0.0,
#   'Improving': 0.0,
#   'Testsuites': 0.0,
#   'via': 0.0,
#   'Instrumentation': 0.0,
#   'Br6ker': 0.0,
#   '325': 0.0,
#   'Efficiency': 0.0,
#   'Multimodal': 0.0,
#   'Interaction': 0.0,
#   'Map-Based': 0.0,
#   'Task': 0.0,
#   'Philip': 0.0,
#   'Cohen,': 0.0,
#   'McGee,': 0.0,
#   'Josh': 0.0,
#   'Clow': 0.0,
#   '................................................................': 5.672425341971495,
#   '331': 0.0,
#   'ANLPv': 0.0,
#   'BusTUC': 0.0,
#   'natura': 39.706977393800464,
#   'l': 448.69420475400096,
#   'anguage': 26.882266303047437,
#   'bus': 0.0,
#   'route': 0.0,
#   'rac': 13.379402735771965,
#   'le': 313.8225751427889,
#   'Dept.': 0.0,
#   'computer': 0.0,
#   'information': 1.414037883526297,
#   'science': 0.0,
#   'University': 1.1699250014423124,
#   'Trondheim': 0.0,
#   'N-7491': 0.0,
#   'amble@idi,': 0.0,
#   'ntnu.': 0.0,
#   'Abstract': 0.0,
#   'paper': 0.2801079191927352,
#   'describes': 0.0,
#   'natural': 4.094737505048093,
#   'based': 1.6251502107763875,
#   'expert': 0.0,
#   'system': 0.7871655712530546,
#   'advisor': 0.0,
#   'public': 6.174925682500679,
#   'transport': 0.0,
#   'Trondheim,': 0.0,
#   'Norway.': 0.0,
#   'available': 1.0285691521967708,
#   'Internet,and': 0.0,
#   'intstalled': 0.0,
#   'com-': 0.0,
#   "pany's": 0.0,
#   'web': 0.0,
#   'server': 0.0,
#   'since': 0.0,
#   'beginning': 2.0874628412503395,
#   '1999.': 1.3448506839429912,
#   'bilingual,': 0.0,
#   'relying': 0.0,
#   'internal': 2.0874628412503395,
#   'independent': 1.42449782852791,
#   'logic': 0.0,
#   'representation.': 0.0,
#   'Introduct': 0.0,
#   'ion': 104.63166665341534,
#   'database': 0.0,
#   'provides': 0.0,
#   'users': 0.0,
#   'capability': 0.0,
#   'obtaining': 0.0,
#   'in-': 2.6897013678859825,
#   'formation': 27.137016936254415,
#   'stored': 0.0,
#   'querying': 0.0,
#   'language': 4.259874466683969,
#   '(NL).': 0.0,
#   'With': 0.0,
#   'means': 0.0,
#   'communication': 0.0,
#   'puter': 8.174925682500678,
#   'system,': 0.0,
#   'make': 0.7009944941682663,
#   'question': 0.0,
#   'statement': 0.0,
#   'way': 4.345138600212232,
#   'normally': 0.0,
#   'think': 0.0,
#   'discussed,': 0.0,
#   'freeing': 0.0,
#   'hav-': 0.0,
#   'ing': 68.43593295334266,
#   'know': 5.344850683942991,
#   'stores': 0.0,
#   'processes': 0.0,
#   'information.': 0.0,
#   'present': 4.70697739380047,
#   'implementation': 0.0,
#   'represents': 0.0,
#   'major': 1.2801079191927351,
#   'effort': 0.0,
#   'bringing': 0.0,
#   'practical': 0.0,
#   'use.': 3.350497247084133,
#   'answer': 0.0,
#   'queries': 0.0,
#   'routes,': 0.0,
#   'stated': 0.0,
#   'texts,': 2.350497247084133,
#   'made': 2.1546870947538617,
#   'Internet': 0.0,
#   'World': 0.0,
#   'Wide': 0.0,
#   'Web': 0.0,
#   'http': 2.6724253419714956,
#   '//www.': 5.672425341971495,
#   'idi.': 0.0,
#   'no/bustuc/).': 0.0,
#   'small': 1.1488633859144828,
#   'city': 0.0,
#   'university': 0.0,
#   '140000': 0.0,
#   'inhabitants.': 0.0,
#   'Its': 0.0,
#   'central': 0.0,
#   'systems': 1.6979913141116403,
#   '42': 9.262388523751019,
#   'lines,': 0.0,
#   'serving': 0.0,
#   '590': 0.0,
#   'stations,': 0.0,
#   '1900': 0.0,
#   'depar-': 0.0,
#   'tures': 65.81392291835573,
#   'per': 70.40593555560044,
#   'day': 0.0,
#   '(in': 3.0050006810583665,
#   'average).': 0.0,
#   'That': 4.425987446668397,
#   'gives': 0.0,
#   'approximately': 0.0,
#   '60000': 0.0,
#   'scheduled': 0.0,
#   'station': 0.0,
#   'passings': 0.0,
#   'day,': 0.0,
#   'somehow': 0.0,
#   'represented': 1.42449782852791,
#   'data': 2.5121248904521685,
#   'base.': 0.0,
#   'starting': 1.8650704199138914,
#   'point': 3.0857074565903124,
#   'automate': 0.0,
#   'function': 3.0050006810583665,
#   'agent.': 0.0,
#   'example': 5.025003405291834,
#   'response': 0.0,
#   'using': 1.178364902938581,
#   'actual': 0.0,
#   'request': 0.0,
#   'telephone': 0.0,
#   'local': 0.0,
#   'company:': 0.0,
#   'Hi,': 0.0,
#   'live': 0.0,
#   'Nidarvoll': 0.0,
#   'tonight': 0.0,
#   'must': 0.0,
#   'reach': 0.0,
#   'train': 12.512501702645917,
#   'Oslo': 0.0,
#   'oclock.': 0.0,
#   'typical': 1.42449782852791,
#   'follow': 9.325352099569457,
#   'quickly:': 0.0,
#   'number': 1.6374972450593104,
#   '54': 3.350497247084133,
#   'passes': 0.0,
#   'skole': 0.0,
#   '1710': 0.0,
#   'arrives': 0.0,
#   'Railway': 0.0,
#   'Station': 0.0,
#   '1725.': 0.0,
#   'In': 2.135473420682635,
#   'pro-': 0.9719856238304033,
#   'cess': 14.102983482504797,
#   'lexical': 0.0,
#   'analysis,': 0.0,
#   'syntax': 0.0,
#   'semantic': 2.6897013678859825,
#   'pragmatic': 0.0,
#   'reasoning': 0.0,
#   'query': 0.0,
#   'processing.': 0.0,
#   'One': 0.0,
#   'could': 1.436458063169241,
#   'argue': 0.0,
#   'content': 0.0,
#   'solved': 0.0,
#   'interrogation,': 0.0,
#   'whereby': 0.0,
#   'customer': 0.0,
#   'asked': 0.0,
#   'produce': 2.425987446668397,
#   '4': 20.245420484369653,
#   'items:': 0.0,
#   'ta': 321.0961354900353,
#   'departure,': 0.0,
#   'arrival,': 0.0,
#   'earliest': 0.0,
#   'departure': 0.0,
#   'timeand/or': 0.0,
#   'latest': 0.0,
#   'arrival': 0.0,
#   'time.': 3.0050006810583665,
#   'It': 0.0,
#   'myth': 0.0,
#   'better': 6.05549293939724,
#   '"natural': 0.0,
#   'language".': 0.0,
#   'challenge': 0.0,
#   'prove': 18.362126709857478,
#   'demonstration': 0.0,
#   'NL': 0.0,
#   'preferred': 3.350497247084133,
#   'interrogative': 0.0,
#   'mode.': 0.0,
#   'To': 2.5469869711674606,
#   'that,': 8.851974893336793,
#   'correct,': 0.0,
#   'user': 0.0,
#   'friendly': 0.0,
#   'almost': 0.0,
#   'complete': 0.0,
#   'within': 0.9719856238304033,
#   'domain.': 0.0,
#   'Previous': 0.0,
#   'Efforts,': 0.0,
#   'CHAT-80,': 0.0,
#   'PRAT-89': 0.0,
#   'HSQL': 0.0,
#   'called': 0.0,
#   'built': 11.520971272734617,
#   'upon': 0.0,
#   'clas-': 2.6724253419714956,
#   'sical': 0.0,
#   'CHAT-80': 0.0,
#   '(Warren': 0.0,
#   'Pereira,': 0.0,
#   '1982).': 0.0,
#   'state': 0.0,
#   'art': 29.379402735771965,
#   'sys-': 0.8650704199138914,
#   'tem': 18.19490585001298,
#   'impressive': 0.0,
#   'merits,': 0.0,
#   'also': 0.6348704764191617,
#   'established': 0.0,
#   'Prolog': 0.0,
#   'viable': 0.0,
#   'competitive': 0.0,
#   'lan-': 0.0,
#   'guage': 37.076229673622514,
#   'Artificial': 0.0,
#   'Intelligence': 0.0,
#   'general.': 0.0,
#   'brilliant': 0.0,
#   'masterpiece': 0.0,
#   'software,': 0.0,
#   'efficient': 0.0,
#   'sophisticated.': 0.0,
#   'connected': 0.0,
#   'international': 0.0,
#   'geography.': 0.0,
#   'analysed': 0.0,
#   'answered': 0.0,
#   'split': 0.0,
#   'second:': 0.0,
#   'Which': 0.0,
#   'country': 0.0,
#   'bordering': 0.0,
#   'Mediterranean': 0.0,
#   'borders': 0.0,
#   'bordered': 0.0,
#   'whose': 6.064968616670993,
#   'population': 8.174925682500678,
#   'exceeds': 0.0,
#   ...}}

# %%
query = 'language processing conference'
vectorSpaceModel(query, d, x)
# Out:
# {9: 19.938755137230917,
#  32: 16.99569807717766,
#  2: 16.015111347965455,
#  22: 12.997561846318792,
#  33: 11.943543177037352}
